# %% [markdown]
# Video about beginner mistakes:
# https://youtu.be/_gaAoJBMJ_Q

# %% [markdown]
# ## Class Exercise: Read Titanic dataset and do some munging
# 1. **Part 1 (25 min)** (plus presentation: 5 min).
#     1. read titanic data from the data/titanic_train.csv file into a pandas dataframe
#     2. set index of the dataframe to passenger id
#     3. sort the dataframe by 'fare' (price of ticket)
# 2. **Part 2 (30 min (str.find() / df.apply()))** plus 5 min.
#     4. write a function to reformat a name to only contain "firstname lastname" (look for current format in the name column)
#     5. use df.apply() to Change all names to the "firstname lastname" format
# ### Pause 10 min
# 3. **Pat 3 (10 min(df.str.split()))** plus 5 min.
#     6. Get only last name by the use of str method split() on comma. https://pandas.pydata.org/docs/user_guide/text.html#splitting-and-replacing-strings
# 4. **Part 4 (20 min (df.isin() / .notna()))** plus 5 min.
#     7. Get only those passengers that had one of these ticket numbers: `[350406,248706,382652,244373,345763,2649,239865]`
#     8. Remove all rows without an age
# 4. **Part 5: (20 min (df.astype('int'))** plus 5 min.
#     9. Convert age values to integer
#     10. get only the children from the dataset
# ### Pause 10 min
# 5. **Part 6: 20 (.notna() / .replace(current,new))** plus 5 min.
#     11. Filter to get only passengers with a valid cabin
#     12. Change Embarked to full name of port: C = Cherbourg; Q = Queenstown; S = Southampton
# 6. **Part 7: 30 min (.groupby)** plus 5 min.
#     13. create new column: 'relations' that adds sibling/spouse value with parent/child values
#     14. Is there a relationship between how many relations and chances of survival?
# ## Total: 3 timer, 30 min

# %% [markdown]
# ### 1A read titanic data from the data/titanic_train.csv file into a pandas dataframe

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
df = pd.read_csv('../data/titanic_train.csv', delimiter=',', index_col=0)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### 1B set index of the dataframe to passenger id

# %%
# Done

# %% [markdown]
# ### 1C sort the dataframe by 'fare' (price of ticket)

# %%
df.sort_values(by='Fare', ascending=False) # Show the 5 most expensive tickets
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 738                 1       1              Lesurer, Mr. Gustave J    male
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 89                  1       1          Fortune, Miss. Mabel Helen  female
# 28                  0       1      Fortune, Mr. Charles Alexander    male
# ...               ...     ...                                 ...     ...
# 634                 0       1       Parr, Mr. William Henry Marsh    male
# 414                 0       2      Cunningham, Mr. Alfred Fleming    male
# 823                 0       1     Reuchlin, Jonkheer. John George    male
# 733                 0       2                Knight, Mr. Robert J    male
# 675                 0       2          Watson, Mr. Ennis Hastings    male
#
# ...

# %% [markdown]
# ## Part 2 (str.find() / df.apply())

# %% [markdown]
# ### 2A write a function to reformat a name to only contain "firstname lastname" (look for current format in the name column)

# %%
def change_name(name):
    name = name.split(", ")
    if '.' in name[1]:
        first_name = name[1].split('. ')[1]
    else:
        first_name = name[1]
    return f'{first_name} {name[0]}'



for i in range(len(df)):
    df.iloc[i, 2] = change_name(df.iloc[i, 2])

df.head()
# Out:
#              Survived  Pclass                                           Name  \
# PassengerId
# 1                   0       3                             Owen Harris Braund
# 2                   1       1  John Bradley (Florence Briggs Thayer) Cumings
# 3                   1       3                                Laina Heikkinen
# 4                   1       1         Jacques Heath (Lily May Peel) Futrelle
# 5                   0       3                            William Henry Allen
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked
# PassengerId
# ...

# %%
# Didnt get it to wotk with str.find...
names = df.loc[1:,'Name']   

find_result = names.str.find(',')


find_result.name = "Founded"
find_result
# Out:
# PassengerId
# 1      6
# 2      7
# 3      9
# 4      8
# 5      5
#       ..
# 887    8
# 888    6
# 889    8
# 890    4
# 891    6
# Name: Founded, Length: 891, dtype: int64

# %% [markdown]
# ### 2B use df.apply() to Change all names to the "firstname lastname" format

# %%
def change_name(name):
    if ',' in name:
        name = name.split(", ")
        if '.' in name[1]:
            first_name = name[1].split('. ')[1]
        else:
            first_name = name[1]
        return f'{first_name} {name[0]}'
    else:
        return name


    
df['Name'] = df.apply(lambda name: change_name(name['Name']), axis=1)


df.head()
# Out:
#              Survived  Pclass                                           Name  \
# PassengerId
# 1                   0       3                             Owen Harris Braund
# 2                   1       1  John Bradley (Florence Briggs Thayer) Cumings
# 3                   1       3                                Laina Heikkinen
# 4                   1       1         Jacques Heath (Lily May Peel) Futrelle
# 5                   0       3                            William Henry Allen
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked
# PassengerId
# ...

# %% [markdown]
# ### 3A Get only last name by the use of str method split() on comma.

# %%
def only_last_name(name):
    if ',' in name:
        name = name.split(", ")
        return name[0]
    else:
        return name
    
df['Name'] = df.apply(lambda name: only_last_name(name['Name']), axis=1)


df.head()
# Out:
#              Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 1                   0       3     Braund    male  22.0      1      0
# 2                   1       1    Cumings  female  38.0      1      0
# 3                   1       3  Heikkinen  female  26.0      0      0
# 4                   1       1   Futrelle  female  35.0      1      0
# 5                   0       3      Allen    male  35.0      0      0
#
#                        Ticket     Fare Cabin Embarked
# PassengerId
# 1                   A/5 21171   7.2500   NaN        S
# 2                    PC 17599  71.2833   C85        C
# 3            STON/O2. 3101282   7.9250   NaN        S
# 4                      113803  53.1000  C123        S
# 5                      373450   8.0500   NaN        S

# %% [markdown]
# ### 4A Get only those passengers that had one of these ticket numbers: [350406,248706,382652,244373,345763,2649,239865]

# %%
tickets = ['350406','248706','382652','244373','345763','2649','239865']
df[df['Ticket'].isin(tickets)]
# Out:
#              Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 15                  0       3        Vestrom  female  14.0      0      0
# 16                  1       2        Hewlett  female  55.0      0      0
# 17                  0       3           Rice    male   2.0      4      1
# 18                  1       2       Williams    male   NaN      0      0
# 19                  0       3  Vander Planke  female  31.0      1      0
# 20                  1       3     Masselmani  female   NaN      0      0
# 21                  0       2         Fynney    male  35.0      0      0
# 172                 0       3           Rice    male   4.0      4      1
# 279                 0       3           Rice    male   7.0      4      1
# 788                 0       3           Rice    male   8.0      4      1
# 792                 0       2        Gaskell    male  16.0      0      0
# 886                 0       3           Rice  female  39.0      0      5
#
# ...

# %% [markdown]
# ### 4B Remove all rows without an age

# %%
df = df[df['Age'].notnull()]
df
# Out:
#              Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 1                   0       3     Braund    male  22.0      1      0
# 2                   1       1    Cumings  female  38.0      1      0
# 3                   1       3  Heikkinen  female  26.0      0      0
# 4                   1       1   Futrelle  female  35.0      1      0
# 5                   0       3      Allen    male  35.0      0      0
# ...               ...     ...        ...     ...   ...    ...    ...
# 886                 0       3       Rice  female  39.0      0      5
# 887                 0       2   Montvila    male  27.0      0      0
# 888                 1       1     Graham  female  19.0      0      0
# 890                 1       1       Behr    male  26.0      0      0
# 891                 0       3     Dooley    male  32.0      0      0
#
#                        Ticket     Fare Cabin Embarked
# PassengerId
# 1                   A/5 21171   7.2500   NaN        S
# ...

# %% [markdown]
# ### 5A Convert age values to integer

# %%
df["Age"] = df["Age"].astype(int)
df
# Out:
#              Survived  Pclass       Name     Sex  Age  SibSp  Parch  \
# PassengerId
# 1                   0       3     Braund    male   22      1      0
# 2                   1       1    Cumings  female   38      1      0
# 3                   1       3  Heikkinen  female   26      0      0
# 4                   1       1   Futrelle  female   35      1      0
# 5                   0       3      Allen    male   35      0      0
# ...               ...     ...        ...     ...  ...    ...    ...
# 886                 0       3       Rice  female   39      0      5
# 887                 0       2   Montvila    male   27      0      0
# 888                 1       1     Graham  female   19      0      0
# 890                 1       1       Behr    male   26      0      0
# 891                 0       3     Dooley    male   32      0      0
#
#                        Ticket     Fare Cabin Embarked
# PassengerId
# 1                   A/5 21171   7.2500   NaN        S
# ...

# %% [markdown]
# ### 5B get only the children from the dataset

# %%
df[df['Age'] < 18]
# Out:
#              Survived  Pclass                            Name     Sex  Age  \
# PassengerId
# 8                   0       3           Gosta Leonard Palsson    male    2
# 10                  1       2   Nicholas (Adele Achem) Nasser  female   14
# 11                  1       3        Marguerite Rut Sandstrom  female    4
# 15                  0       3   Hulda Amanda Adolfina Vestrom  female   14
# 17                  0       3                     Eugene Rice    male    2
# ...               ...     ...                             ...     ...  ...
# 851                 0       3  Sigvard Harald Elias Andersson    male    4
# 853                 0       3                Nourelain Boulos  female    9
# 854                 1       1              Mary Conover Lines  female   16
# 870                 1       3          Harold Theodor Johnson    male    4
# 876                 1       3       Adele Kiamie "Jane" Najib  female   15
#
# ...

# %% [markdown]
# ### 6A Filter to get only passengers with a valid cabin

# %%
df[df['Cabin'].notnull()]
# Out:
#              Survived  Pclass       Name     Sex  Age  SibSp  Parch    Ticket  \
# PassengerId
# 2                   1       1    Cumings  female   38      1      0  PC 17599
# 4                   1       1   Futrelle  female   35      1      0    113803
# 7                   0       1   McCarthy    male   54      0      0     17463
# 11                  1       3  Sandstrom  female    4      1      1   PP 9549
# 12                  1       1    Bonnell  female   58      0      0    113783
# ...               ...     ...        ...     ...  ...    ...    ...       ...
# 872                 1       1   Beckwith  female   47      1      1     11751
# 873                 0       1   Carlsson    male   33      0      0       695
# 880                 1       1     Potter  female   56      0      1     11767
# 888                 1       1     Graham  female   19      0      0    112053
# 890                 1       1       Behr    male   26      0      0    111369
#
# ...

# %% [markdown]
# ### 6B Change Embarked to full name of port: C = Cherbourg; Q = Queenstown; S = Southampton

# %%
#def full_name_embarked(name):
    

#df['Embarked'] = df.apply(lambda d: change_name(d['Embarked']), axis=1)

df['Embarked'] = df['Embarked'].replace(['C', 'Q', 'S'],['Cherbourg', 'Queenstown', 'Southampton'])





df
# Out:
#              Survived  Pclass       Name     Sex  Age  SibSp  Parch  \
# PassengerId
# 1                   0       3     Braund    male   22      1      0
# 2                   1       1    Cumings  female   38      1      0
# 3                   1       3  Heikkinen  female   26      0      0
# 4                   1       1   Futrelle  female   35      1      0
# 5                   0       3      Allen    male   35      0      0
# ...               ...     ...        ...     ...  ...    ...    ...
# 886                 0       3       Rice  female   39      0      5
# 887                 0       2   Montvila    male   27      0      0
# 888                 1       1     Graham  female   19      0      0
# 890                 1       1       Behr    male   26      0      0
# 891                 0       3     Dooley    male   32      0      0
#
#                        Ticket     Fare Cabin     Embarked
# PassengerId
# 1                   A/5 21171   7.2500   NaN  Southampton
# ...

# %% [markdown]
# ### 7A create new column: 'relations' that adds sibling/spouse value with parent/child values

# %%
df[df['Name'] == 'Carter']
# Out:
#              Survived  Pclass    Name     Sex   Age  SibSp  Parch  Ticket  \
# PassengerId
# 250                 0       2  Carter    male  54.0      1      0  244252
# 391                 1       1  Carter    male  36.0      1      2  113760
# 436                 1       1  Carter  female  14.0      1      2  113760
# 764                 1       1  Carter  female  36.0      1      2  113760
# 803                 1       1  Carter    male  11.0      1      2  113760
# 855                 0       2  Carter  female  44.0      1      0  244252
#
#               Fare    Cabin     Embarked
# PassengerId
# 250           26.0      NaN  Southampton
# 391          120.0  B96 B98  Southampton
# 436          120.0  B96 B98  Southampton
# 764          120.0  B96 B98  Southampton
# 803          120.0  B96 B98  Southampton
# 855           26.0      NaN  Southampton

# %%
# Don't understand the question, did this instead..
df.groupby('Ticket')['Survived'].sum().reset_index().sort_values(by=["Survived"], ascending=False)
# Out:
#        Ticket  Survived
# 26     113760         4
# 160      2666         4
# 118     24160         3
# 482  PC 17757         3
# 66       1601         3
# ..        ...       ...
# 295    349209         0
# 294    349207         0
# 293    349206         0
# 292    349205         0
# 271    347078         0
#
# [542 rows x 2 columns]

# %%
def find_relation(name):
    rel = df[df['Name'] == name]
    return len(rel)

#test = df.iloc[19, 2]
#print(test)
#find_relation(test)

df['Relations'] = find_relation(df['Name'])
# Out:
# /tmp/ipykernel_6894/770628673.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Relations'] = find_relation(df['Name'])

# %%
df
# Out:
#              Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 1                   0       3     Braund    male  22.0      1      0
# 2                   1       1    Cumings  female  38.0      1      0
# 3                   1       3  Heikkinen  female  26.0      0      0
# 4                   1       1   Futrelle  female  35.0      1      0
# 5                   0       3      Allen    male  35.0      0      0
# ...               ...     ...        ...     ...   ...    ...    ...
# 886                 0       3       Rice  female  39.0      0      5
# 887                 0       2   Montvila    male  27.0      0      0
# 888                 1       1     Graham  female  19.0      0      0
# 890                 1       1       Behr    male  26.0      0      0
# 891                 0       3     Dooley    male  32.0      0      0
#
#                        Ticket     Fare Cabin     Embarked  Relations
# PassengerId
# ...

# %% [markdown]
# ### 7B Is there a relationship between how many relations and chances of survival?
