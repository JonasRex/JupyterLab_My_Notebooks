# %% [markdown]
# ## Exercise 1
# 1. Create a python file with 3 functions:
#   1. `def print_file_content(file)` that can print content of a csv file to the console
#   2. `def write_list_to_file(output_file, lst)` that can take a list or tuple of strings and write each element to a new line in file
#     1. rewrite the function so that it gets an arbitrary number of strings instead of a list
#   3. `def read_csv(input_file)` that take a csv file and read each row into a list. Print the list.
# 2. Add a functionality so that the file can be called from cli with 2 arguments:
#   1. path to csv file
#   2. an argument `--file file_name` that if given will write the content to file_name or otherwise will print it to the console.
# 3. Add a --help cli argument to describe how the module is used

# %% [markdown]
# ## 1A)

# %%
from my_modules.ex2 import file_handler as fh

fh.print_file_content('data/country_codes.csv')
# Out:
# Afghanistan 	AF 	AFG 	004
#
# Albania 	AL 	ALB 	008
#
# Algeria 	DZ 	DZA 	012
#
# American Samoa 	AS 	ASM 	016
#
# Andorra 	AD 	AND 	020
#
# Angola 	AO 	AGO 	024
#
# Anguilla 	AI 	AIA 	660
#
# Antarctica 	AQ 	ATA 	010
#
# Antigua and Barbuda 	AG 	ATG 	028
#
# Argentina 	AR 	ARG 	032
#
# Armenia 	AM 	ARM 	051
#
# Aruba 	AW 	ABW 	533
#
# Australia 	AU 	AUS 	036
#
# Austria 	AT 	AUT 	040
#
# Azerbaijan 	AZ 	AZE 	031
#
# Bahamas (the) 	BS 	BHS 	044
#
# Bahrain 	BH 	BHR 	048
#
# Bangladesh 	BD 	BGD 	050
#
# Barbados 	BB 	BRB 	052
#
# Belarus 	BY 	BLR 	112
#
# Belgium 	BE 	BEL 	056
#
# Belize 	BZ 	BLZ 	084
#
# Benin 	BJ 	BEN 	204
#
# Bermuda 	BM 	BMU 	060
#
# Bhutan 	BT 	BTN 	064
#
# Bolivia (Plurinational State of) 	BO 	BOL 	068
#
# Bonaire, Sint Eustatius and Saba 	BQ 	BES 	535
#
# Bosnia and Herzegovina 	BA 	BIH 	070
#
# Botswana 	BW 	BWA 	072
#
# Bouvet Island 	BV 	BVT 	074
#
# Brazil 	BR 	BRA 	076
#
# British Indian Ocean Territory (the) 	IO 	IOT 	086
#
# ...

# %% [markdown]
# ## 1B)

# %%
from my_modules.ex2 import file_handler as fh

filename = 'data/ex2data1b.txt'
word_list = ["Able", "Bending", "Crafting", "Dodging", "Evolving"]

fh.write_list_to_file(filename, word_list)
# Out:
# data/ex2data1b.txt been added to data folder

# %% [markdown]
# ## 1C)

# %%
from my_modules.ex2 import file_handler as fh

lst = fh.read_csv('data/country_codes.csv')
for i in lst[59:64]:
# for i in lst[:5]:
    print(i)
# Out:
# Denmark 	DK 	DNK 	208
#
# Djibouti 	DJ 	DJI 	262
#
# Dominica 	DM 	DMA 	212
#
# Dominican Republic (the) 	DO 	DOM 	214
#
# Ecuador 	EC 	ECU 	218

# %% [markdown]
# ## 2)

# %%
# !python my_modules/ex2/file_handler.py data --file country_codes.csv
# Out:
# Namespace(path='data', file='country_codes.csv')
# Afghanistan 	AF 	AFG 	004
#
# Albania 	AL 	ALB 	008
#
# Algeria 	DZ 	DZA 	012
#
# American Samoa 	AS 	ASM 	016
#
# Andorra 	AD 	AND 	020
#
# Angola 	AO 	AGO 	024
#
# Anguilla 	AI 	AIA 	660
#
# Antarctica 	AQ 	ATA 	010
#
# Antigua and Barbuda 	AG 	ATG 	028
#
# Argentina 	AR 	ARG 	032
#
# Armenia 	AM 	ARM 	051
#
# Aruba 	AW 	ABW 	533
#
# Australia 	AU 	AUS 	036
#
# Austria 	AT 	AUT 	040
#
# Azerbaijan 	AZ 	AZE 	031
#
# Bahamas (the) 	BS 	BHS 	044
#
# Bahrain 	BH 	BHR 	048
#
# Bangladesh 	BD 	BGD 	050
#
# Barbados 	BB 	BRB 	052
#
# Belarus 	BY 	BLR 	112
#
# Belgium 	BE 	BEL 	056
#
# Belize 	BZ 	BLZ 	084
#
# Benin 	BJ 	BEN 	204
#
# Bermuda 	BM 	BMU 	060
#
# Bhutan 	BT 	BTN 	064
#
# Bolivia (Plurinational State of) 	BO 	BOL 	068
#
# Bonaire, Sint Eustatius and Saba 	BQ 	BES 	535
#
# Bosnia and Herzegovina 	BA 	BIH 	070
#
# Botswana 	BW 	BWA 	072
#
# Bouvet Island 	BV 	BVT 	074
#
# Brazil 	BR 	BRA 	076
#
# ...

# %% [markdown]
# ## 3)

# %%
# !python my_modules/ex2/file_handler.py --help
# Out:
# usage: file_handler.py [-h] [--file FILE] path
#
# A program that handles csv files
#
# positional arguments:
#   path         File path for the csv file
#
# options:
#   -h, --help   show this help message and exit
#   --file FILE  The name of the file

# %% [markdown]
# ## Exercise 2
# Create a module called utils.py with the following 5 functions:
#
# ```python
# def get_file_names(folderpath,out=output.txt):
#     """ takes a path to a folder and writes all filenames in the folder to a specified output file"""
#
# def get_all_file_names(folderpath,out=output.txt):
#     """takes a path to a folder and write all filenames recursively (files of all sub folders to)"""
#
# def print_line_one(file_names):
#     """takes a list of filenames and print the first line of each"""
#
# def print_emails(file_names):
#     """takes a list of filenames and print each line that contains an email (just look for @)"""
#
# def write_headlines(md_files, out=output.txt):
#     """takes a list of md files and writes all headlines (lines starting with #) to a file"""
#
# ```
# Make sure your module can be called both from cli and imported to another module
# Create a new module that imports utils.py and test each function.

# %% [markdown]
# ### A little pre testing before writing the module

# %%
from os import listdir
from os.path import isfile, join

dir = "my_modules"

# onlyfiles = [f for f in listdir(dir) if isfile(join(mypath, f))]

files_and_directories = listdir(dir)
lst = [file for file in files_and_directories if not isfile(join(dir, file))]
print(lst)
# Out:
# ['ex2', '__pycache__']

# %% [markdown]
# ### The first function

# %%
from my_modules.ex2 import utils

dir = "my_modules"

utils.get_file_names(dir, 'delete_me.txt')
# Out:
# Files in my_modules:  ['names_list.py', 'test2.py', '__init__.py']
# new_test.txt has been created with the file names in the data folder.

# %% [markdown]
# ### Second function

# %%
from my_modules.ex2 import utils

dir = "my_modules"

utils.get_all_file_names(dir, 'delete_me.txt')
# Out:
# Files in my_modules:  ['names_list.py', 'test2.py', '__init__.py']
# delete_me.txt has been created with the file names in the data folder.
# Files in my_modules/ex2:  ['file_handler.py', 'utils.py', '__init__.py']
# Files in my_modules/__pycache__:  ['names_list.cpython-310.pyc', 'test1.cpython-310.pyc', 'test2.cpython-310.pyc', 'webget.cpython-310.pyc', '__init__.cpython-310.pyc']

# %% [markdown]
# ### Third function

# %% [markdown]
# #### Testing how to:

# %%
files_list = ['output.txt', 'befkbhalderstatkode.csv']


with open(files_list[1]) as data:
    for line in data:
        print(line)
        # Breakinf after 1 line
        break
# Out:
# <!DOCTYPE html>

# %%
from my_modules.ex2 import utils

files_list = ['output.txt', 'befkbhalderstatkode.csv']

utils.print_line_one(files_list)
# Out:
# 0 names_list.py test2.py __init__.py
# 1 <!DOCTYPE html>

# %% [markdown]
# ### Fourth function

# %%
from my_modules.ex2 import utils

files_list = ['output.txt', 'befkbhalderstatkode.csv', 'data/emailsEx2.txt']

utils.print_emails(files_list)
# Out:
# Lines with email adresses in output.txt:
# -----------------------------------------------------------------------
# 2: fdgfdsg@.com
#
# 3: @@@@
#
# 5: @@@dffddsf
#
# 6: @dfsdf
#
# Lines with email adresses in befkbhalderstatkode.csv:
# -----------------------------------------------------------------------
# 1219: <p>Har du spørgsmål om data, er du velkommen til at henvende dig til de kontaktpersoner der står på det enkelte datasæt. Alternativt kan du skrive til <a href="mailto:bydata@tmf.kk.dk">bydata@tmf.kk.dk</a></p>
#
# 1251:                         <p>Open Data DK | <a href="mailto:info@opendata.dk" class="site-footer_link">info@opendata.dk</a> | Hack Kampmanns Plads 2 | 8000 Aarhus C</p>
#
# 1452: <script src="//cdn.jsdelivr.net/gh/cferdinandi/tabby@12/dist/js/tabby.polyfills.min.js"></script>
#
# Lines with email adresses in data/emailsEx2.txt:
# -----------------------------------------------------------------------
# 1: test@test.dk
#
# 3: lol@gmail.com

# %% [markdown]
# ### Fifth function

# %%
from my_modules.ex2 import utils
from os import listdir
from os.path import isfile, join




markdown_list = ['data/markdowns/test1.MD', 'data/markdowns/test2.MD', 'data/markdowns/test3.MD']
utils.write_headlines(markdown_list)
# Out:
# ### Hej
#
# ## Jeg er en lille overskrift
#
# # Dette er en overskrift
#
# ### Slut
#
# # Sådan bliver du rig (not, det er bare en random tekst)

# %% [markdown]
# # Use CLI:

# %%
# !python my_modules/ex2/utils.py --help
# Out:
# usage: utils.py [-h] [--out OUT] path
#
# A program that creates a txt files with all the files in the path folder,
# including the subfolders
#
# positional arguments:
#   path        File path for the csv file
#
# options:
#   -h, --help  show this help message and exit
#   --out OUT   The name of the output file. Default output.txt

# %%
# !python my_modules/ex2/utils.py data --out test_with_cli
# Out:
# Files in data:  ['bones_in_london.txt', 'country_codes.csv', 'delete_me.txt', 'emailsEx2.txt', 'ex2data1b.txt']
# test_with_cli.txt has been created with the file names in the data folder.
# Files in data/.ipynb_checkpoints:  []
# Files in data/markdowns:  ['test1.MD', 'test2.MD', 'test3.MD']
