# %% [markdown]
# # Music / Lyric Analyzer
#
# ## Webscrapping the songs from Wikipedia (1959 - 2021)
# #### Notice: There will be a part 2, where i fetch all the lyrics from a site called https://www.mldb.org
#
# OBS:! I saw that most songs have a link. With some aditional data. Genre, Length, Label, Released.
# Also all most of singers actually!

# %%
import bs4
import requests

def get_top100_song_year(year=2021):
    result_dict = dict()
    
    url = "https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + str(year)
    
    r = requests.get(url)
    r.raise_for_status()
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    #table = soup.select('.mw-parser-output > table > tbody > tr')
    table = soup.select('.wikitable > tbody > tr')
    
    for el in table:
        td = el.select('td')
        if(len(td) > 0):
            number = td[0].text.rstrip('\n')
            title = td[1].text.rstrip('\n')
            artist = td[2].text.rstrip('\n')
            result_dict[number] = [title, artist]
    
    return result_dict

# %%
def get_all_top100_song_period(start=1959, end=2021):
    result_dict = dict()
    for i in range(start, end + 1):
        result_dict[i] = get_top100_song_year(i)
    return result_dict

        
data = get_all_top100_song_period(1959, 2021)
data
# Out:
# {1959: {'1': ['"The Battle of New Orleans"', 'Johnny Horton'],
#   '2': ['"Mack the Knife"', 'Bobby Darin'],
#   '3': ['"Personality"', 'Lloyd Price'],
#   '4': ['"Venus"', 'Frankie Avalon'],
#   '5': ['"Lonely Boy"', 'Paul Anka'],
#   '6': ['"Dream Lover"', 'Bobby Darin'],
#   '7': ['"The Three Bells"', 'The Browns'],
#   '8': ['"Come Softly to Me"', 'The Fleetwoods'],
#   '9': ['"Kansas City"', 'Wilbert Harrison'],
#   '10': ['"Mr. Blue"', 'The Fleetwoods'],
#   '11': ['"Sleep Walk"', 'Santo & Johnny'],
#   '12': ['"Put Your Head on My Shoulder"', 'Paul Anka'],
#   '13': ['"Stagger Lee"', 'Lloyd Price'],
#   '14': ['"Donna"', 'Ritchie Valens'],
#   '15': ['"Pink Shoe Laces"', 'Dodie Stevens'],
#   '16': ['"Smoke Gets in Your Eyes"', 'The Platters'],
#   '17': ['"Charlie Brown"', 'The Coasters'],
#   '18': ['"Quiet Village"', 'Martin Denny'],
#   '19': ['"My Heart Is an Open Book"', 'Carl Dobkins Jr.'],
#   '20': ['"(Till) I Kissed You"', 'The Everly Brothers'],
# ...

# %% [markdown]
# ## Testing the data:

# %%
total_songs = 0

for year, value in data.items():
    total_songs += len(value)
print("Number of songs: ",total_songs)
print("Years: ", len(data))
# Out:
# Number of songs:  6301
# Years:  63

# %%
# Making sure that every year has 100 songs. OBS: 1969 that had a tie for 100th spot. That's why there is 101

for year, value in data.items():
    print(year, len(value))
# Out:
# 1959 100
# 1960 100
# 1961 100
# 1962 100
# 1963 100
# 1964 100
# 1965 100
# 1966 100
# 1967 100
# 1968 100
# 1969 101
# 1970 100
# 1971 100
# 1972 100
# 1973 100
# 1974 100
# 1975 100
# 1976 100
# 1977 100
# 1978 100
# 1979 100
# 1980 100
# 1981 100
# 1982 100
# 1983 100
# 1984 100
# 1985 100
# 1986 100
# 1987 100
# 1988 100
# 1989 100
# 1990 100
# 1991 100
# 1992 100
# 1993 100
# 1994 100
# 1995 100
# 1996 100
# 1997 100
# 1998 100
# 1999 100
# 2000 100
# 2001 100
# 2002 100
# 2003 100
# 2004 100
# 2005 100
# 2006 100
# 2007 100
# 2008 100
# 2009 100
# 2010 100
# 2011 100
# 2012 100
# 2013 100
# 2014 100
# 2015 100
# 2016 100
# 2017 100
# 2018 100
# 2019 100
# 2020 100
# 2021 100

# %%
# Find the songs that was categoried as tie

for year, value in data.items():
    for key, song in value.items():
        if(key == "Tie"):
            print(year)
            print(100, value.get("100"))
            print(key, song)
# Out:
# 1969
# 100 ['"Sweet Cream Ladies"', 'The Box Tops']
# Tie ['"Let Me"', 'Paul Revere & the Raiders']

# %%
# Find all the no.1 songs

for year, value in data.items():
    for key, song in value.items():
        if(key == "1"):
            print(year, song)
# Out:
# 1959 ['"The Battle of New Orleans"', 'Johnny Horton']
# 1960 ['"Theme from A Summer Place"', 'Percy Faith']
# 1961 ['"Tossin\' and Turnin\'"', 'Bobby Lewis']
# 1962 ['"Stranger on the Shore"', 'Acker Bilk']
# 1963 ['"Sugar Shack"', 'Jimmy Gilmer and the Fireballs']
# 1964 ['"I Want to Hold Your Hand"', 'The Beatles']
# 1965 ['"Wooly Bully"', 'Sam the Sham and the Pharaohs']
# 1966 ['"California Dreamin\'"', 'The Mamas & the Papas']
# 1967 ['"To Sir With Love"', 'Lulu']
# 1968 ['"Hey Jude"', 'The Beatles']
# 1969 ['"Sugar, Sugar"', 'The Archies']
# 1970 ['"Bridge Over Troubled Water"', 'Simon & Garfunkel']
# 1971 ['"Joy to the World"', 'Three Dog Night']
# 1972 ['"The First Time Ever I Saw Your Face"', 'Roberta Flack']
# 1973 ['"Tie a Yellow Ribbon Round the Ole Oak Tree"', 'Tony Orlando and Dawn']
# 1974 ['"The Way We Were"', 'Barbra Streisand']
# 1975 ['"Love Will Keep Us Together"', 'Captain & Tennille']
# 1976 ['"Silly Love Songs"', 'Wings']
# ...

# %% [markdown]
# ### Notes after testing

# %%
# Notice 1986: Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder)
# Need a a clever way to break that down.
# Also 2004, 2012 (and others) have "feature" or "and". Need to be able to break down aswell

# %% [markdown]
# ## Turn it into a dataframe

# %%
import pandas as pd

def make_data_into_dataframe(billboard_data):
    data_list = []
    for year, value in billboard_data.items():
        for place, song in value.items():
            list_song = [year, place, song[0], song[1]]
            data_list.append(list_song)
    return pd.DataFrame(data_list, columns=['Year', 'Place', 'Title', 'Artist'])
   
make_data_into_dataframe(data)
# Out:
#       Year Place                                Title  \
# 0     1959     1          "The Battle of New Orleans"
# 1     1959     2                     "Mack the Knife"
# 2     1959     3                        "Personality"
# 3     1959     4                              "Venus"
# 4     1959     5                         "Lonely Boy"
# ...    ...   ...                                  ...
# 6296  2021    96           "Things a Man Oughta Know"
# 6297  2021    97              "Throat Baby (Go Baby)"
# 6298  2021    98                          "Tombstone"
# 6299  2021    99  "Drinkin' Beer. Talkin' God. Amen."
# 6300  2021   100                         "Todo de Ti"
#
#                                          Artist
# 0                                 Johnny Horton
# 1                                   Bobby Darin
# 2                                   Lloyd Price
# 3                                Frankie Avalon
# 4                                     Paul Anka
# ...

# %% [markdown]
# ### Notes after converting:

# %%
# link for each songs lyrics
# number of words in lyrics
# (maybe) lenth of song?
# (maybe) Link for youtube video of the song

# Turn it into a csv file

# %% [markdown]
# ## Web scrape all the lyrics

# %% [markdown]
# ## Textblob (For the lyrics)
# - https://www.youtube.com/watch?v=ea4IadDRwuc&list=PL_92WMXSLe_-RkWW5zAQZ-gMdVqZ7T-_F&index=3
# - https://textblob.readthedocs.io/en/dev/quickstart.html

# %%
# Research more
