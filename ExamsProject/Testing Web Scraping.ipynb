# %% [markdown]
# # Music / Lyric Analyzer
#
# ## Webscrapping the songs from Wikipedia (1959 - 2021)
# #### Notice: There will be a part 2, where i fetch all the lyrics from a site called https://www.mldb.org
#
# OBS:! I saw that most songs have a link. With some aditional data. Genre, Length, Label, Released.
# Also all most of singers actually!

# %%
import bs4
import requests

def get_top100_song_year(year=2021):
    """This function will return a dictionary with any of the official Billboard American top 100 end of the year lists.
    The top 100 list was introduced in 1959. Before that it was a top 50 only. Returns by default 2021.
    link: https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2021"""
    result_dict = dict()
    
    url = "https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + str(year)
    
    r = requests.get(url)
    r.raise_for_status()
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    table = soup.select('.wikitable > tbody > tr')
    
    for el in table:
        td = el.select('td')
        if(len(td) > 0):
            number = td[0].text.rstrip('\n')
            title = td[1].text.rstrip('\n')
            artist = extract_artists(td[2])
            title_url = extract_title_url(td[1])
            result_dict[number] = [title[1:-1], artist[0], artist[1], title_url]
    
    return result_dict

def extract_artists(element):
    """This function will return a list of the artists that have made the song. Only 2 artists will be applied,
    if more than two artists have collaborated. 
    """
    list_of_artists = [x.text.rstrip('\n') for x in element]
            
    result_list = split_featuring(list_of_artists)  
    
    # Need to add a blank spot if there is no featuring artist.
    if(len(result_list) < 2):
        result_list.append("")
        
    # Some featurings starts with ' & ' and some ends with 'and'. Quick fix:
    if(' and ' in result_list[1][-5:]):
        result_list[1] = result_list[1][:-5]
    if(' & ' in result_list[1][:3]):
        result_list[1] = result_list[1][3:]
        
    return [artist for artist in result_list][:2]


def split_featuring(list):
        """Many of the songs have featuring artists, sometimes even an additional ' and ' artist.
        This function splits them and returns a new list.
        
        Examples:
        1. Blackstreet featuring Mýa, Mase and Blinky Blink   # featuring + and + ,
        2. Silk Sonic (Bruno Mars and Anderson .Paak)         # Tuples
        3. SpotemGottem featuring Pooh Shiesty or DaBaby      # featuring + or
        4. Gerry and the Pacemakers                           # ' and the ' was a common band name in the old days
        5. Puff Daddy & the Family featuring The Notorious B.I.G.  # & the Family.. Gave some troubles.. 
        """
        
        new_list = []
        
        for artist in list:
            if(' featuring ' in artist):
                [new_list.append(x) for x in artist.split(' featuring ')]
            elif(' and ' in artist and ' and the ' not in artist ):
                [new_list.append(x) for x in artist.split(' and ')]
            elif(' or ' in artist):
                [new_list.append(x) for x in artist.split(' or ')] 
            else:
                new_list.append(artist)
                
        return [x for x in new_list if
                x != ' and ' and x != '' and x != ' (' and x != ')' and 
                x != ', ' and x != ' & 'and x != ' with ' and x != ' & the Family']
            

def extract_title_url(element):
    """This function will return the url for the song. This will be used later on to extract more data about each song."""
    
    if(element.find('a')):
        return element.select('a')[0].get('href')
    else:
        return ""

#get_top100_song_year(1998)

# %%
def get_all_top100_song_period(start=1959, end=2021):
    """This function will return..."""
    result_dict = dict()
    for i in range(start, end + 1):
        result_dict[i] = get_top100_song_year(i)
    return result_dict

        
billboard_data = get_all_top100_song_period(1959, 2021)
print("Size of Data:",len(billboard_data))
print("Example (2021):")
billboard_data.get(2021)
# Out:
# Size of Data: 63
# Example (2021):
# {'1': ['Levitating', 'Dua Lipa', '', '/wiki/Levitating_(song)'],
#  '2': ['Save Your Tears',
#   'The Weeknd',
#   'Ariana Grande',
#   '/wiki/Save_Your_Tears'],
#  '3': ['Blinding Lights', 'The Weeknd', '', '/wiki/Blinding_Lights'],
#  '4': ['Mood', '24kGoldn', 'Iann Dior', '/wiki/Mood_(song)'],
#  '5': ['Good 4 U', 'Olivia Rodrigo', '', '/wiki/Good_4_U'],
#  '6': ['Kiss Me More', 'Doja Cat', 'SZA', '/wiki/Kiss_Me_More'],
#  '7': ['Leave the Door Open',
#   'Silk Sonic',
#   'Bruno Mars',
#   '/wiki/Leave_the_Door_Open'],
#  '8': ['Drivers License',
#   'Olivia Rodrigo',
#   '',
#   '/wiki/Drivers_License_(song)'],
#  '9': ['Montero (Call Me by Your Name)',
#   'Lil Nas X',
#   '',
#   '/wiki/Montero_(Call_Me_by_Your_Name)'],
#  '10': ['Peaches',
#   'Justin Bieber',
#   'Daniel Caesar',
#   '/wiki/Peaches_(Justin_Bieber_song)'],
#  '11': ['Butter', 'BTS', '', '/wiki/Butter_(song)'],
#  '12': ['Stay',
#   'The Kid Laroi',
#   'Justin Bieber',
#   '/wiki/Stay_(The_Kid_Laroi_and_Justin_Bieber_song)'],
#  '13': ['Deja Vu',
#   'Olivia Rodrigo',
#   '',
#   '/wiki/Deja_Vu_(Olivia_Rodrigo_song)'],
#  '14': ['Positions', 'Ariana Grande', '', '/wiki/Positions_(song)'],
#  '15': ['Bad Habits', 'Ed Sheeran', '', '/wiki/Bad_Habits_(Ed_Sheeran_song)'],
#  '16': ['Heat Waves', 'Glass Animals', '', '/wiki/Heat_Waves'],
#  '17': ['Without You',
#   'The Kid Laroi',
#   '',
#   '/wiki/Without_You_(The_Kid_Laroi_song)'],
#  '18': ['Forever After All', 'Luke Combs', '', '/wiki/Forever_After_All'],
#  '19': ['Go Crazy',
#   'Chris Brown',
#   'Young Thug',
#   '/wiki/Go_Crazy_(Chris_Brown_and_Young_Thug_song)'],
#  '20': ['Astronaut in the Ocean',
#   'Masked Wolf',
#   '',
#   '/wiki/Astronaut_in_the_Ocean'],
#  '21': ['34+35', 'Ariana Grande', 'Doja Cat', '/wiki/34%2B35'],
#  '22': ['What You Know Bout Love',
#   'Pop Smoke',
#   '',
#   '/wiki/What_You_Know_Bout_Love'],
#  '23': ["My Ex's Best Friend",
#   'Machine Gun Kelly',
#   'Blackbear',
#   '/wiki/My_Ex%27s_Best_Friend'],
#  '24': ['Industry Baby', 'Lil Nas X', 'Jack Harlow', '/wiki/Industry_Baby'],
#  '25': ['Therefore I Am',
#   'Billie Eilish',
#   '',
#   '/wiki/Therefore_I_Am_(Billie_Eilish_song)'],
#  '26': ['Up', 'Cardi B', '', '/wiki/Up_(Cardi_B_song)'],
#  '27': ['Fancy Like', 'Walker Hayes', '', '/wiki/Fancy_Like'],
#  '28': ['Dakiti', 'Bad Bunny', 'Jhay Cortez', '/wiki/Dakiti'],
#  '29': ['Best Friend',
#   'Saweetie',
#   'Doja Cat',
#   '/wiki/Best_Friend_(Saweetie_song)'],
#  '30': ['Rapstar', 'Polo G', '', '/wiki/Rapstar'],
#  '31': ['Heartbreak Anniversary',
#   'Giveon',
#   '',
#   '/wiki/Heartbreak_Anniversary'],
#  '32': ['For the Night', 'Pop Smoke', 'Lil Baby', '/wiki/For_the_Night'],
#  '33': ['Calling My Phone', 'Lil Tjay', '6lack', '/wiki/Calling_My_Phone'],
#  '34': ['Beautiful Mistakes',
#   'Maroon 5',
#   'Megan Thee Stallion',
#   '/wiki/Beautiful_Mistakes'],
#  '35': ['Holy',
#   'Justin Bieber',
#   'Chance the Rapper',
#   '/wiki/Holy_(Justin_Bieber_song)'],
#  '36': ['On Me', 'Lil Baby', '', '/wiki/On_Me_(Lil_Baby_song)'],
#  '37': ['You Broke Me First', 'Tate McRae', '', '/wiki/You_Broke_Me_First'],
#  '38': ['Traitor', 'Olivia Rodrigo', '', '/wiki/Traitor_(song)'],
#  '39': ['Back in Blood',
#   'Pooh Shiesty',
#   'Lil Durk',
#   '/wiki/Back_in_Blood_(song)'],
#  '40': ['I Hope',
#   'Gabby Barrett',
#   'Charlie Puth',
#   '/wiki/I_Hope_(Gabby_Barrett_song)'],
#  '41': ['Dynamite', 'BTS', '', '/wiki/Dynamite_(BTS_song)'],
#  '42': ['Wockesha', 'Moneybagg Yo', '', '/wiki/Wockesha'],
#  '43': ['You Right', 'Doja Cat and the Weeknd', '', '/wiki/You_Right'],
#  '44': ['Beat Box',
#   'SpotemGottem',
#   'Pooh Shiesty or DaBaby',
#   '/wiki/Beat_Box_(SpotemGottem_song)'],
#  '45': ['Laugh Now Cry Later',
#   'Drake',
#   'Lil Durk',
#   '/wiki/Laugh_Now_Cry_Later'],
#  '46': ['Need to Know', 'Doja Cat', '', '/wiki/Need_to_Know_(Doja_Cat_song)'],
#  '47': ['Wants and Needs', 'Drake', 'Lil Baby', '/wiki/Wants_and_Needs'],
#  '48': ['Way 2 Sexy', 'Drake', 'Future', '/wiki/Way_2_Sexy'],
#  '49': ['Telepatía', 'Kali Uchis', '', '/wiki/Telepat%C3%ADa'],
#  '50': ['Whoopty', 'CJ', '', '/wiki/Whoopty'],
#  '51': ['Lemonade',
#   'Internet Money',
#   'Gunna',
#   '/wiki/Lemonade_(Internet_Money_and_Gunna_song)'],
#  '52': ['Good Days', 'SZA', '', '/wiki/Good_Days'],
#  '53': ['Starting Over',
#   'Chris Stapleton',
#   '',
#   '/wiki/Starting_Over_(Chris_Stapleton_song)'],
#  '54': ['Body',
#   'Megan Thee Stallion',
#   '',
#   '/wiki/Body_(Megan_Thee_Stallion_song)'],
#  '55': ['Willow', 'Taylor Swift', '', '/wiki/Willow_(song)'],
#  '56': ['Bang!', 'AJR', '', '/wiki/Bang!_(AJR_song)'],
#  '57': ['Better Together',
#   'Luke Combs',
#   '',
#   '/wiki/Better_Together_(Luke_Combs_song)'],
#  '58': ["You're Mines Still",
#   'Yung Bleu',
#   'Drake',
#   '/wiki/You%27re_Mines_Still'],
#  '59': ['Every Chance I Get',
#   'DJ Khaled',
#   'Lil Baby and Lil Durk',
#   '/wiki/Every_Chance_I_Get_(song)'],
#  '60': ['Essence', 'Wizkid', 'Justin Bieber', '/wiki/Essence_(song)'],
#  '61': ['Chasing After You',
#   'Ryan Hurd',
#   'Maren Morris',
#   '/wiki/Chasing_After_You'],
#  '62': ['The Good Ones',
#   'Gabby Barrett',
#   '',
#   '/wiki/The_Good_Ones_(Gabby_Barrett_song)'],
#  '63': ['Leave Before You Love Me',
#   'Marshmello',
#   'Jonas Brothers',
#   '/wiki/Leave_Before_You_Love_Me'],
#  '64': ['Glad You Exist', 'Dan + Shay', '', '/wiki/Glad_You_Exist'],
#  '65': ['Lonely',
#   'Justin Bieber',
#   'Benny Blanco',
#   '/wiki/Lonely_(Justin_Bieber_and_Benny_Blanco_song)'],
#  '66': ["Beggin'", 'Måneskin', '', '/wiki/Beggin%27#Måneskin_version'],
#  '67': ['Streets', 'Doja Cat', '', '/wiki/Streets_(song)'],
#  '68': ["What's Next", 'Drake', '', '/wiki/What%27s_Next_(Drake_song)'],
#  '69': ['Famous Friends', 'Chris Young', 'Kane Brown', '/wiki/Famous_Friends'],
#  '70': ['Lil Bit', 'Nelly', 'Florida Georgia Line', '/wiki/Lil_Bit'],
#  '71': ['Thot Shit', 'Megan Thee Stallion', '', '/wiki/Thot_Shit'],
#  '72': ['Late at Night',
#   'Roddy Ricch',
#   '',
#   '/wiki/Late_at_Night_(Roddy_Ricch_song)'],
#  '73': ['Kings & Queens',
#   'Ava Max',
#   '',
#   '/wiki/Kings_%26_Queens_(Ava_Max_song)'],
#  '74': ['Anyone', 'Justin Bieber', '', '/wiki/Anyone_(Justin_Bieber_song)'],
#  '75': ['Track Star', 'Mooski', '', '/wiki/Track_Star_(song)'],
#  '76': ['Time Today', 'Moneybagg Yo', '', '/wiki/Time_Today'],
#  '77': ['Cry Baby',
#   'Megan Thee Stallion',
#   'DaBaby',
#   '/wiki/Cry_Baby_(Megan_Thee_Stallion_song)'],
#  '78': ['All I Want for Christmas Is You',
#   'Mariah Carey',
#   '',
#   '/wiki/All_I_Want_for_Christmas_Is_You'],
#  '79': ['No More Parties', 'Coi Leray', 'Lil Durk', '/wiki/No_More_Parties'],
#  '80': ["What's Your Country Song",
#   'Thomas Rhett',
#   '',
#   '/wiki/What%27s_Your_Country_Song'],
#  '81': ['One Too Many', 'Keith Urban', 'Pink', '/wiki/One_Too_Many_(song)'],
#  '82': ['Arcade', 'Duncan Laurence', '', '/wiki/Arcade_(song)'],
#  '83': ['Yonaguni', 'Bad Bunny', '', '/wiki/Yonaguni_(song)'],
#  '84': ['Good Time', 'Niko Moon', '', '/wiki/Good_Time_(Niko_Moon_song)'],
#  '85': ["If I Didn't Love You",
#   'Jason Aldean',
#   'Carrie Underwood',
#   '/wiki/If_I_Didn%27t_Love_You_(Jason_Aldean_and_Carrie_Underwood_song)'],
#  '86': ['Knife Talk', 'Drake', '21 Savage', '/wiki/Knife_Talk'],
#  '87': ['POV', 'Ariana Grande', '', '/wiki/POV_(song)'],
#  '88': ['Just the Way', 'Parmalee', 'Blanco Brown', '/wiki/Just_the_Way'],
#  '89': ['Take My Breath', 'The Weeknd', '', '/wiki/Take_My_Breath'],
#  '90': ["We're Good", 'Dua Lipa', '', '/wiki/We%27re_Good'],
#  '91': ['Hell of a View', 'Eric Church', '', '/wiki/Hell_of_a_View'],
#  '92': ["Rockin' Around the Christmas Tree",
#   'Brenda Lee',
#   '',
#   '/wiki/Rockin%27_Around_the_Christmas_Tree'],
#  '93': ['Put Your Records On',
#   'Ritt Momney',
#   '',
#   '/wiki/Put_Your_Records_On#Ritt_Momney_version'],
#  '94': ['Happier Than Ever',
#   'Billie Eilish',
#   '',
#   '/wiki/Happier_Than_Ever_(song)'],
#  '95': ['Single Saturday Night',
#   'Cole Swindell',
#   '',
#   '/wiki/Single_Saturday_Night'],
#  '96': ['Things a Man Oughta Know',
#   'Lainey Wilson',
#   '',
#   '/wiki/Things_a_Man_Oughta_Know'],
#  '97': ['Throat Baby (Go Baby)',
#   'BRS Kash',
#   '',
#   '/wiki/Throat_Baby_(Go_Baby)'],
#  '98': ['Tombstone', 'Rod Wave', '', '/wiki/Tombstone_(song)'],
#  '99': ["Drinkin' Beer. Talkin' God. Amen.",
#   'Chase Rice',
#   'Florida Georgia Line',
#   '/wiki/Drinkin%27_Beer._Talkin%27_God._Amen.'],
#  '100': ['Todo de Ti', 'Rauw Alejandro', '', '/wiki/Todo_de_Ti']}

# %% [markdown]
# ## Turn it into a dataframe (IMPORTANT)

# %%
import pandas as pd

def make_data_into_dataframe(billboard_data):
    data_list = []
    for year, value in billboard_data.items():
        for place, song in value.items():
            list_song = [year, place, song[0], song[1], song[2], song[3]]
            data_list.append(list_song)
    return pd.DataFrame(data_list, columns=['Year', 'Place', 'Title', 'Artist', 'Featuring','Title_url'])
   
make_data_into_dataframe(billboard_data)
# Out:
#       Year Place                              Title          Artist  \
# 0     1959     1          The Battle of New Orleans   Johnny Horton
# 1     1959     2                     Mack the Knife     Bobby Darin
# 2     1959     3                        Personality     Lloyd Price
# 3     1959     4                              Venus  Frankie Avalon
# 4     1959     5                         Lonely Boy       Paul Anka
# ...    ...   ...                                ...             ...
# 6296  2021    96           Things a Man Oughta Know   Lainey Wilson
# 6297  2021    97              Throat Baby (Go Baby)        BRS Kash
# 6298  2021    98                          Tombstone        Rod Wave
# 6299  2021    99  Drinkin' Beer. Talkin' God. Amen.      Chase Rice
# 6300  2021   100                         Todo de Ti  Rauw Alejandro
#
#                  Featuring                                    Title_url
# 0                                       /wiki/The_Battle_of_New_Orleans
# 1                                                  /wiki/Mack_the_Knife
# 2                                  /wiki/Personality_(Lloyd_Price_song)
# 3                                     /wiki/Venus_(Frankie_Avalon_song)
# 4                                     /wiki/Lonely_Boy_(Paul_Anka_song)
# ...                    ...                                          ...
# 6296                                     /wiki/Things_a_Man_Oughta_Know
# 6297                                        /wiki/Throat_Baby_(Go_Baby)
# 6298                                             /wiki/Tombstone_(song)
# 6299  Florida Georgia Line  /wiki/Drinkin%27_Beer._Talkin%27_God._Amen.
# 6300                                                   /wiki/Todo_de_Ti
#
# [6301 rows x 6 columns]

# %% [markdown]
# ## Save as CSV. So i dont have to scrape it everyday..

# %%
#df_to_csv = pd.DataFrame.from_dict(billboard_data) 
make_data_into_dataframe(billboard_data).to_csv ('data/raw_top100_1959_2021.csv', index = False, header=True)

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
df = pd.read_csv('data/raw_top100_1959_2021.csv' )
df
# Out:
#       Year Place                              Title          Artist  \
# 0     1959     1          The Battle of New Orleans   Johnny Horton
# 1     1959     2                     Mack the Knife     Bobby Darin
# 2     1959     3                        Personality     Lloyd Price
# 3     1959     4                              Venus  Frankie Avalon
# 4     1959     5                         Lonely Boy       Paul Anka
# ...    ...   ...                                ...             ...
# 6296  2021    96           Things a Man Oughta Know   Lainey Wilson
# 6297  2021    97              Throat Baby (Go Baby)        BRS Kash
# 6298  2021    98                          Tombstone        Rod Wave
# 6299  2021    99  Drinkin' Beer. Talkin' God. Amen.      Chase Rice
# 6300  2021   100                         Todo de Ti  Rauw Alejandro
#
#                  Featuring                                    Title_url
# 0                      NaN              /wiki/The_Battle_of_New_Orleans
# 1                      NaN                         /wiki/Mack_the_Knife
# 2                      NaN         /wiki/Personality_(Lloyd_Price_song)
# 3                      NaN            /wiki/Venus_(Frankie_Avalon_song)
# 4                      NaN            /wiki/Lonely_Boy_(Paul_Anka_song)
# ...                    ...                                          ...
# 6296                   NaN               /wiki/Things_a_Man_Oughta_Know
# 6297                   NaN                  /wiki/Throat_Baby_(Go_Baby)
# 6298                   NaN                       /wiki/Tombstone_(song)
# 6299  Florida Georgia Line  /wiki/Drinkin%27_Beer._Talkin%27_God._Amen.
# 6300                   NaN                             /wiki/Todo_de_Ti
#
# [6301 rows x 6 columns]

# %% [markdown]
# ## Testing the data:

# %%
df[df['Featuring'] == 'the Pacemakers']
# Out:
#      Year Place                               Title Artist       Featuring  \
# 548  1964    49  Don't Let the Sun Catch You Crying  Gerry  the Pacemakers
# 588  1964    89                   How Do You Do It?  Gerry  the Pacemakers
# 642  1965    43              Ferry Cross the Mersey  Gerry  the Pacemakers
#
#                                       Title_url
# 548  /wiki/Don%27t_Let_the_Sun_Catch_You_Crying
# 588                   /wiki/How_Do_You_Do_It%3F
# 642                /wiki/Ferry_Cross_the_Mersey

# %%
df[df['Artist'] == 'Gerry and the Pacemakers'] # Fixed
# Out:
#      Year Place                               Title                    Artist  \
# 548  1964    49  Don't Let the Sun Catch You Crying  Gerry and the Pacemakers
# 588  1964    89                   How Do You Do It?  Gerry and the Pacemakers
# 642  1965    43              Ferry Cross the Mersey  Gerry and the Pacemakers
#
#     Featuring                                   Title_url
# 548       NaN  /wiki/Don%27t_Let_the_Sun_Catch_You_Crying
# 588       NaN                   /wiki/How_Do_You_Do_It%3F
# 642       NaN                /wiki/Ferry_Cross_the_Mersey

# %%
df[df['Featuring'] == ' & ']
# Out:
#       Year Place                                              Title  \
# 36    1959    37                 Kookie, Kookie (Lend Me Your Comb)
# 2021          /wiki/You_Don%27t_Bring_Me_Flowers_(song)
# 2023                               /wiki/Stumblin%27_In
# 2057                            /wiki/Boogie_Wonderland
# 2124                             /wiki/Yes,_I%27m_Ready
# 2131          /wiki/Don%27t_Fall_in_Love_with_a_Dreamer
# 2138             /wiki/No_More_Tears_(Enough_Is_Enough)
# 2202                          /wiki/Endless_Love_(song)
# 2218  /wiki/Just_the_Two_of_Us_(Grover_Washington,_J...
# 2229  /wiki/Guilty_(Barbra_Streisand_and_Barry_Gibb_...
# 2255                  /wiki/What_Are_We_Doin%27_in_Love
# 2259              /wiki/Stop_Draggin%27_My_Heart_Around
# 2278  /wiki/Sweet_Baby_(George_Duke_%26_Stanley_Clar...
# 2285                            /wiki/What_Kind_of_Fool
# 2291  /wiki/Suddenly_(Olivia_Newton-John_and_Cliff_R...
# 2651                              /wiki/Raspberry_Beret

# %%
df[df['Featuring'] == ' & '] # Fixed
# Out:
# Empty DataFrame
# Columns: [Year, Place, Title, Artist, Featuring, Title_url]
# Index: []

# %%
df[df['Artist'] == 'The Mamas & the Papas']
# Out:
#      Year Place                        Title                 Artist Featuring  \
# 700  1966     1          California Dreamin'  The Mamas & the Papas       NaN
# 723  1966    24               Monday, Monday  The Mamas & the Papas       NaN
# 861  1967    62  Dedicated to the One I Love  The Mamas & the Papas       NaN
#
#                              Title_url
# 700        /wiki/California_Dreamin%27
# 723               /wiki/Monday,_Monday
# 861  /wiki/Dedicated_to_the_One_I_Love

# %%
df[df['Title'] == 'Stay']
# Out:
#       Year Place Title                            Artist      Featuring  \
# 197   1960    98  Stay  Maurice Williams and the Zodiacs            NaN
# 3345  1992    45  Stay                Shakespears Sister            NaN
# 3580  1994    80  Stay                           Eternal            NaN
# 5413  2013    13  Stay                           Rihanna     Mikky Ekko
# 5817  2017    17  Stay                              Zedd   Alessia Cara
# 6212  2021    12  Stay                     The Kid Laroi  Justin Bieber
#
#                                               Title_url
# 197                  /wiki/Stay_(Maurice_Williams_song)
# 3345               /wiki/Stay_(Shakespears_Sister_song)
# 3580                          /wiki/Stay_(Eternal_song)
# 5413                          /wiki/Stay_(Rihanna_song)
# 5817            /wiki/Stay_(Zedd_and_Alessia_Cara_song)
# 6212  /wiki/Stay_(The_Kid_Laroi_and_Justin_Bieber_song)

# %%
df[df['Title'] == 'Venus']
# Out:
#       Year Place  Title          Artist Featuring  \
# 3     1959     4  Venus  Frankie Avalon       NaN
# 1133  1970    33  Venus   Shocking Blue       NaN
# 2738  1986    38  Venus      Bananarama       NaN
#
#                               Title_url
# 3     /wiki/Venus_(Frankie_Avalon_song)
# 1133   /wiki/Venus_(Shocking_Blue_song)
# 2738   /wiki/Venus_(Shocking_Blue_song)

# %%
df[df['Artist'] == 'The Beatles']
# Out:
#       Year Place                         Title       Artist      Featuring  \
# 500   1964     1      I Want to Hold Your Hand  The Beatles            NaN
# 501   1964     2                 She Loves You  The Beatles            NaN
# 512   1964    13            A Hard Day's Night  The Beatles            NaN
# 513   1964    14                    Love Me Do  The Beatles            NaN
# 515   1964    16              Please Please Me  The Beatles            NaN
# 539   1964    40               Twist and Shout  The Beatles            NaN
# 551   1964    52             Can't Buy Me Love  The Beatles            NaN
# 554   1964    55  Do You Want to Know a Secret  The Beatles            NaN
# 594   1964    95      I Saw Her Standing There  The Beatles            NaN
# 606   1965     7                         Help!  The Beatles            NaN
# 630   1965    31                Ticket to Ride  The Beatles            NaN
# 654   1965    55             Eight Days a Week  The Beatles            NaN
# 748   1966    49            We Can Work It Out  The Beatles            NaN
# 756   1966    57              Paperback Writer  The Beatles            NaN
# 783   1966    84                   Nowhere Man  The Beatles            NaN
# 789   1966    90              Yellow Submarine  The Beatles            NaN
# 829   1967    30          All You Need Is Love  The Beatles            NaN
# 854   1967    55                    Penny Lane  The Beatles            NaN
# 900   1968     1                      Hey Jude  The Beatles            NaN
# 959   1968    60                  Lady Madonna  The Beatles            NaN
# 977   1968    78                    Revolution  The Beatles            NaN
# 1024  1969    25                      Get Back  The Beatles  Billy Preston
# 1082  1969    83                     Something  The Beatles            NaN
# 1084  1969    85                 Come Together  The Beatles            NaN
# 1109  1970     9                     Let It Be  The Beatles            NaN
# 1141  1970    41     The Long and Winding Road  The Beatles            NaN
# 1778  1976    78   Got to Get You into My Life  The Beatles            NaN
#
#                                Title_url
# 500       /wiki/I_Want_to_Hold_Your_Hand
# 501                  /wiki/She_Loves_You
# 512    /wiki/A_Hard_Day%27s_Night_(song)
# 513                     /wiki/Love_Me_Do
# 515        /wiki/Please_Please_Me_(song)
# 539                /wiki/Twist_and_Shout
# 551            /wiki/Can%27t_Buy_Me_Love
# 554   /wiki/Do_You_Want_to_Know_a_Secret
# 594       /wiki/I_Saw_Her_Standing_There
# 606                   /wiki/Help!_(song)
# 630          /wiki/Ticket_to_Ride_(song)
# 654              /wiki/Eight_Days_a_Week
# 748             /wiki/We_Can_Work_It_Out
# 756               /wiki/Paperback_Writer
# 783             /wiki/Nowhere_Man_(song)
# 789        /wiki/Yellow_Submarine_(song)
# 829           /wiki/All_You_Need_Is_Love
# 854                     /wiki/Penny_Lane
# 900                       /wiki/Hey_Jude
# 959                   /wiki/Lady_Madonna
# 977      /wiki/Revolution_(Beatles_song)
# 1024                      /wiki/Get_Back
# 1082      /wiki/Something_(Beatles_song)
# 1084                 /wiki/Come_Together
# 1109      /wiki/Let_It_Be_(Beatles_song)
# 1141     /wiki/The_Long_and_Winding_Road
# 1778   /wiki/Got_to_Get_You_into_My_Life

# %% [markdown]
# #### Testing featuring after refactoring the web scrapper:

# %%
# How many songs have a featurin artist for the song:
print("Featuring artists: ",df['Artist'].str.contains('featuring').sum())
print("AND in the name: ",df['Artist'].str.contains('and').sum()) # OBS.: This could also be Andrew, Andy etc.. not valid!
# Out:
# Featuring artists:  0
# AND in the name:  227

# %%
print("Featuring artists: ",df['Featuring'].str.contains('&').sum())
# Out:
# Featuring artists:  4

# %%
test_featuring_for_and[test_featuring_for_and['Featuring'].str.contains(' and ')]
# Out:
#       Year Place               Title         Artist              Featuring  \
# 6149  2020    49       For the Night      Pop Smoke    Lil Baby and DaBaby
# 6221  2021    21               34+35  Ariana Grande          Doja Cat and
# 6259  2021    59  Every Chance I Get      DJ Khaled  Lil Baby and Lil Durk
# 6260  2021    60             Essence         Wizkid     Justin Bieber and
#
#                             Title_url
# 6149              /wiki/For_the_Night
# 6221                    /wiki/34%2B35
# 6259  /wiki/Every_Chance_I_Get_(song)
# 6260             /wiki/Essence_(song)

# %%
# It's usually used if there is a third featuring person/band. DRAKE featuring 21 SAVAGE and PROJECT PAT
# Might have to change the way i crawl the data!

test_featuring_for_and = df.dropna(subset='Featuring')

test_featuring_for_and[test_featuring_for_and['Featuring'].str.contains(' and')]
#df[df['Featuring'].str.contains(' and')]
# Out:
#       Year Place               Title     Artist              Featuring  \
# 6149  2020    49       For the Night  Pop Smoke    Lil Baby and DaBaby
# 6259  2021    59  Every Chance I Get  DJ Khaled  Lil Baby and Lil Durk
#
#                             Title_url
# 6149              /wiki/For_the_Night
# 6259  /wiki/Every_Chance_I_Get_(song)

# %%
#testdf['Year'].values.tolist()

for x in test_featuring_for_and.values:
    print(x[0], x[1], x[4])
# Out:
# 1959 37 Connie Stevens
# 1959 60 Bob
# 1959 81 Carol Kay
# 1959 95 Dean
# 1960 27 Brook Benton
# 1960 49 The Midnighters
# 1960 62 The Phantom's Band
# 1960 75 Brook Benton
# 1960 79 Flip
# 1961 27 Dee Dee
# 1961 65 Tina Turner
# 1962 17 Dee Dee Sharp
# 1962 50 Juan
# 1962 84 Dee Dee
# 1962 98 Mary
# 1963 7 Paula
# 1963 16 Mary
# 1963 17 Mary
# 1963 18 Grace
# 1963 25 Charlie Foxx
# 1963 28 Dean
# 1963 53 the Enchanters
# 1964 18 The Dakotas
# 1964 28 Dean
# 1964 30 Gordon
# 1964 34 Jerry Butler
# 1964 48 Dean
# 1964 51 Astrud Gilberto
# 1964 97 The Dakotas
# 1965 34 The Mindbenders
# 1965 75 Gordon
# 1965 82 Gordon
# 1966 79 Gordon
# 1967 7 Nancy Sinatra
# 1967 32 Tammi Terrell
# 1967 87 Tammi Terrell
# 1967 91 Mary
# 1968 57 Tammi Terrell
# 1968 82 Tammi Terrell
# 1969 25 Billy Preston
# 1969 78 The First Edition
# 1969 87 The Temptations
# 1970 20 War
# 1970 38 The First Edition
# 1971 10 Dawn
# 1971 22 Linda McCartney
# 1971 67 Friends
# 1971 71 Katie Kissoon
# 1972 38 Tim
# 1972 58 Donny Hathaway
# 1972 69 His Lost Planet Airmen
# 1972 84 Brenda Lee Eager
# 1973 1 Dawn
# 1973 34 Dawn
# 1973 40 Crofts
# 1973 53 Messina
# 1973 61 Steve Mandell
# 1974 21 The Heywoods
# 1974 22 Wings
# 1974 46 The Spinners
# 1974 52 James Taylor
# 1974 56 Chaka Khan
# 1974 77 Wings
# 1974 81 Marie Osmond
# 1974 84 Wolfman Jack
# 1974 91 Wings
# 1974 92 Marvin Gaye
# 1975 19 Dawn
# 1975 66 Odia Coates
df[df['Title'] == 'Peaches'] # This title's artist(s) ot featuring + and in the name. FIXED
# Out:
#       Year Place    Title         Artist      Featuring  \
# 6210  2021    10  Peaches  Justin Bieber  Daniel Caesar
#
#                                Title_url
# 6210  /wiki/Peaches_(Justin_Bieber_song)

# %%
print("Number of songs: ",len(df))
print("Years: ", len(df["Year"].drop_duplicates()))
# Out:
# Number of songs:  6301
# Years:  63

# %%
# Find all the no.1 songs

df[df['Place'] == "1"]
# Out:
#       Year Place                      Title                          Artist  \
# 0     1959     1  The Battle of New Orleans                   Johnny Horton
# 100   1960     1  Theme from A Summer Place                     Percy Faith
# 200   1961     1        Tossin' and Turnin'                     Bobby Lewis
# 300   1962     1      Stranger on the Shore                      Acker Bilk
# 400   1963     1                Sugar Shack  Jimmy Gilmer and the Fireballs
# ...    ...   ...                        ...                             ...
# 5801  2017     1               Shape of You                      Ed Sheeran
# 5901  2018     1                 God's Plan                           Drake
# 6001  2019     1              Old Town Road                       Lil Nas X
# 6101  2020     1            Blinding Lights                      The Weeknd
# 6201  2021     1                 Levitating                        Dua Lipa
#
#             Featuring                        Title_url
# 0                 NaN  /wiki/The_Battle_of_New_Orleans
# 100               NaN  /wiki/Theme_from_A_Summer_Place
# 200               NaN    /wiki/Tossin%27_and_Turnin%27
# 300               NaN      /wiki/Stranger_on_the_Shore
# 400               NaN                /wiki/Sugar_Shack
# ...               ...                              ...
# 5801              NaN               /wiki/Shape_of_You
# 5901              NaN        /wiki/God%27s_Plan_(song)
# 6001  Billy Ray Cyrus              /wiki/Old_Town_Road
# 6101              NaN            /wiki/Blinding_Lights
# 6201              NaN          /wiki/Levitating_(song)
#
# [63 rows x 6 columns]

# %%
songs_without_url = df[df['Title_url'].isnull()]

# %%
# Find songs that don't have a link.
            
print(len(songs_without_url), " out of ", len(df), " Songs.",  (len(songs_without_url) / len(df))*100, "%")
songs_without_url
# Out:
# 74  out of  6301  Songs. 1.1744167592445642 %
#       Year Place                           Title             Artist Featuring  \
# 112   1960    13                     Greenfields  The Brothers Four       NaN
# 139   1960    40  Way Down Yonder in New Orleans      Freddy Cannon       NaN
# 165   1960    66                It's Time to Cry          Paul Anka       NaN
# 181   1960    82                       Lady Luck        Lloyd Price       NaN
# 182   1960    83                    Step by Step         The Crests       NaN
# ...    ...   ...                             ...                ...       ...
# 4061  1999    61                          If You               Silk       NaN
# 4081  1999    81                  Faded Pictures               Case       Joe
# 4289  2001    89                      I'm a Thug        Trick Daddy       NaN
# 4388  2002    88                        Anything             Jaheim      Next
# 4482  2003    82            Put That Woman First             Jaheim       NaN
#
#      Title_url
# 112        NaN
# 139        NaN
# 165        NaN
# 181        NaN
# 182        NaN
# ...        ...
# 4061       NaN
# 4081       NaN
# 4289       NaN
# 4388       NaN
# 4482       NaN
#
# [74 rows x 6 columns]

# %% [markdown]
# ### Notes after testing

# %%
# Notice 1986: Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder)
# Need a a clever way to break that down.
# Also 2004, 2012 (and others) have "feature" or "and". Need to be able to break down aswell 
# 74 songs wont get extra data. Which is acceptable
# Paul McCartney need some attention. "Paul", "Paul M and the Wings", "Beatles"

# %% [markdown]
# ## Get additional data from wikipedia link

# %%
import bs4
import requests
import re


def get_additional_song_data(link):
    result_dict = dict()
    
    url = "https://en.wikipedia.org/"+link
    
    r = requests.get(url)
    r.raise_for_status()
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    # Some songs have more than one infobox. We only want the first.
    infobox = soup.select('.infobox')
    table = infobox[0].select('tbody > tr')
    
    # All the data we want to extract (Will convert it into an Object!)
    released = ""
    genres = [""]
    length = ""
    label = ""
    total_labels = ""
    writer = [""]
    youtube = ""
    
    
    for el in table:

        
        if(el.find('th')):
            th = el.select('th')
            td = el.select('td')
            if(len(td) > 0):
                #print(th[0].text, td[0].text)
                match th[0].text:
                    case "Released":
                        released =  extract_released_year(td[0])
                        #print("Released", extract_released_year(td[0]))
                    case "Genre":
                        genres = extract_genre(td[0])
                        #print("Genre:", extract_genre(td[0]))
                    case "Length":
                        length = extract_length(td[0])
                        #print("Length", extract_length(td[0]))
                    case "Label":
                        label_data = extract_label(td[0])
                        label = label_data[0]
                        total_labels = label_data[1]
                        #print("Label", extract_label(td[0]))
                    case "Songwriter(s)":
                        writer = extract_songwriter(td[0])
                        #print("Songwriter(s)", extract_songwriter(td[0]))
                        
        # Search for YT link
        if(el.find('a', {'title': 'YouTube'})):
            youtube = el.find('a', {'class': 'external'}).get('href')
            #print(el.find('a', {'class': 'external'}).get('href'))
                    
                
    return [released, genres, length, label, total_labels, writer, youtube]
    
    

def extract_released_year(element):
    """This function will return the year the song was released. But tests shows that is different scenarios. 
    1. Multiple release days, release etc., 
    2. Sometimes only the Year and Month(or Just the year), 
    
    I am using regex and split to make a list of 4 digit numbers and only returns index 0(Incase there was a rerelease later)
    """    
    years_reg = re.compile(r"\b(19|20)\d{2}\b")
        
    return [year for year in element.text.split() if re.search(years_reg, year)][0]
    
                        
def extract_genre(element):
    """This function will return a list of up to 3 genres. But tests shows that is different scenarios. 
    1. Only one Genre, 
    2. Multiple genres in an unordered list(ul), 
    3. Multiple genres with a bookmark like this. Pop[1], Rock[2].
    
    Which is handle but simple if statements.
    """
    letters_reg = re.compile(r"[a-zA-Z]")    
    
    if(element.find('ul')):
        result_list = [x.text for x in element.select('a')]
    else:
        result_list = element.text.split()
        
    return [genre for genre in result_list if re.search(letters_reg, genre)][:3]
    
    
def extract_length(element):
    """This function will return the length of the song. In some cases there is a single and an album version etc.,
    but i decided to return just the longest version. 
    1. The function splits the text elements into a list if it contains ':'.
    2. It cleans up the result for any letters or symbols(not ':' obviously).
    3. Return the max value."""

    # c = character   l = length
    lengths = ["".join([c for c in l if int(c.isnumeric()) or c == ":"]) for l in element.text.split() if ":" in l] 
    
    return max(lengths)
    
def extract_label(element):
    """This function will return only the first mentioned Label. Some singers/song change labels for whatever reason.
    Sometimes up tp two or three times. For simplicity I only return the first mentioned and the amount of different
    labels that the song have had. Maybe we can use that information for something interresting."""
    
    if(element.find('a')):
        result_list = [x.text for x in element.select('a')]
    elif(element.find('li')):
        result_list = [x.text for x in element.select('li')]
    else:
        result_list = element.text.split()
    
    # Returning originale label and the amount of different labels.
    return [[label for label in result_list][0], len(result_list)]

def extract_songwriter(element):
    """This function will return only the first mentioned songwriter. Some singers/song change labels for whatever reason.
    Sometimes up tp two or three times. For simplicity I only return the first mentioned and the amount of different
    labels that the song have had. Maybe we can use that information for something interresting."""
    
    if(element.find('a')):
        result_list = [x.text for x in element.select('a')]
        
    else:
        result_list = re.split('; |,',element.text) 
    
    # Returning originale label and the amount of different labels.
    return [writer for writer in result_list][:2]
    
    
    
get_additional_song_data("/wiki/Thrift_Shop")

# Some songs have up to 7 genres! Limit it to 3!?
# Length can be different aswell, album and single (Think i should go with the longest one)
# Multiple recording days. (Take the earliest)
# More than one label! (Like Wham - Careless whispers...)
# Song writers is often more than one. Some weird ones like Andy Gibb - shadow song:  "Barry, Robin & Maurice Gibb; Andy Gibb"
# Out:
# ['2012',
#  ['Pop-rap', 'comedy hip hop'],
#  '3:55',
#  'Macklemore LLC',
#  1,
#  ['Ben Haggerty', 'Ryan Lewis'],
#  'https://www.youtube.com/watch?v=QK8mJJJvaes']

# %%
test1 = "/wiki/The_First_Time_Ever_I_Saw_Your_Face" # 2 different lenghts + label also have a number after
test2 = "/wiki/When_Doves_Cry" # 7 different genres! And 3  dates..
test3 = "/wiki/Shadow_Dancing_(song)" # Songwriters: "Barry, Robin & Maurice Gibb; Andy Gibb"
test4 = "/wiki/Careless_Whisper" # Genre has this [1] etc + multiple labels
test5 = "/wiki/The_Way_We_Were_(song)" # No genre
test6 = "/wiki/The_Sign_(song)" # the genres prints like this: Techno-reggaepopEuropop (Make sure it's splits correctly)

get_additional_song_data(test1)
get_additional_song_data(test2)
get_additional_song_data(test3)
get_additional_song_data(test4)
get_additional_song_data(test5)
get_additional_song_data(test6)
# Out:
# Released 1972
# Genre: ['Soul', 'vocal jazz']
# Length 5:22
# Label ['Atlantic', 2]
# Songwriter(s) ['Ewan MacColl']
# Released 1984
# Genre: ['Experimental pop', 'neo-psychedelia', 'soul']
# Length 5:52
# Label ['Warner', 2]
# Songwriter(s) ['Prince']
# https://www.youtube.com/watch?v=UG3VcCAlUgE
# Released 1978
# Genre: ['Disco']
# Length 4:34
# Label ['RSO', 2]
# Songwriter(s) ['Barry, Robin & Maurice Gibb', 'Andy Gibb']
# Released 1984
# Genre: ['Pop', 'soul', 'R&B']
# Length 6:30
# Label ['Epic', 3]
# Songwriter(s) ['George Michael', 'Andrew Ridgeley']
# https://www.youtube.com/watch?v=izGwDsrQ1eQ
# Released 1973
# Length 3:29
# Label ['Columbia', 1]
# Songwriter(s) ['Alan Bergman', 'Marilyn Bergman']
# Released 1993
# Genre: ['Techno-reggae', 'pop', 'Europop']
# Length 3:08
# Label ['Arista', 2]
# Songwriter(s) ['Jonas Berggren']
# https://www.youtube.com/watch?v=iqu132vTl5Y

# %%
list123 = [['"The Battle of New Orleans"', 'Johnny Horton', '/wiki/The_Battle_of_New_Orleans']
,['"Theme from A Summer Place"', 'Percy Faith', '/wiki/Theme_from_A_Summer_Place']
,['"Tossin\' and Turnin\'"', 'Bobby Lewis', '/wiki/Tossin%27_and_Turnin%27']
,['"Stranger on the Shore"', 'Acker Bilk', '/wiki/Stranger_on_the_Shore']
,['"Sugar Shack"', 'Jimmy Gilmer and the Fireballs', '/wiki/Sugar_Shack']
,['"I Want to Hold Your Hand"', 'The Beatles', '/wiki/I_Want_to_Hold_Your_Hand']
,['"Wooly Bully"', 'Sam the Sham and the Pharaohs', '/wiki/Wooly_Bully']
,['"California Dreamin\'"', 'The Mamas & the Papas', '/wiki/California_Dreamin%27']
,['"To Sir With Love"', 'Lulu', '/wiki/To_Sir_with_Love_(song)']
,['"Hey Jude"', 'The Beatles', '/wiki/Hey_Jude']
,['"Sugar, Sugar"', 'The Archies', '/wiki/Sugar,_Sugar']
,['"Bridge Over Troubled Water"', 'Simon & Garfunkel', '/wiki/Bridge_Over_Troubled_Water_(song)']
,['"Joy to the World"', 'Three Dog Night', '/wiki/Joy_to_the_World_(Hoyt_Axton_song)']
,['"The First Time Ever I Saw Your Face"', 'Roberta Flack', '/wiki/The_First_Time_Ever_I_Saw_Your_Face']
,['"Tie a Yellow Ribbon Round the Ole Oak Tree"', 'Tony Orlando and Dawn', '/wiki/Tie_a_Yellow_Ribbon_Round_the_Ole_Oak_Tree']
,['"The Way We Were"', 'Barbra Streisand', '/wiki/The_Way_We_Were_(song)']
,['"Love Will Keep Us Together"', 'Captain & Tennille', '/wiki/Love_Will_Keep_Us_Together#Captain_&_Tennille_version']
,['"Silly Love Songs"', 'Wings', '/wiki/Silly_Love_Songs']
,['"Tonight\'s the Night (Gonna Be Alright)"', 'Rod Stewart', '/wiki/Tonight%27s_the_Night_(Gonna_Be_Alright)']
,['"Shadow Dancing"', 'Andy Gibb', '/wiki/Shadow_Dancing_(song)']
,['"My Sharona"', 'The Knack', '/wiki/My_Sharona']
,['"Call Me"', 'Blondie', '/wiki/Call_Me_(Blondie_song)']
,['"Bette Davis Eyes"', 'Kim Carnes', '/wiki/Bette_Davis_Eyes']
,['"Physical"', 'Olivia Newton-John', '/wiki/Physical_(Olivia_Newton-John_song)']
,['"Every Breath You Take"', 'The Police', '/wiki/Every_Breath_You_Take']
,['"When Doves Cry"', 'Prince', '/wiki/When_Doves_Cry']
,['"Careless Whisper"', 'Wham!', '/wiki/Careless_Whisper']
,['"That\'s What Friends Are For"', 'Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder)', '/wiki/That%27s_What_Friends_Are_For']
,['"Walk Like An Egyptian"', 'The Bangles', '/wiki/Walk_Like_An_Egyptian']
,['"Faith"', 'George Michael', '/wiki/Faith_(George_Michael_song)']
,['"Look Away"', 'Chicago', '/wiki/Look_Away']
,['"Hold On"', 'Wilson Phillips', '/wiki/Hold_On_(Wilson_Phillips_song)']
,['"(Everything I Do) I Do It for You"', 'Bryan Adams', '/wiki/(Everything_I_Do)_I_Do_It_for_You']
,['"End of the Road"', 'Boyz II Men', '/wiki/End_of_the_Road_(Boyz_II_Men_song)']
,['"I Will Always Love You"', 'Whitney Houston', '/wiki/I_Will_Always_Love_You#Whitney_Houston_version']
,['"The Sign"', 'Ace of Base', '/wiki/The_Sign_(song)']
,['"Gangsta\'s Paradise"', 'Coolio featuring L.V.', '/wiki/Gangsta%27s_Paradise']
,['"Macarena (Bayside Boys Mix)"', 'Los del Río', '/wiki/Macarena_(song)']
,['"Candle in the Wind 1997" / "Something About the Way You Look Tonight"', 'Elton John', '/wiki/Candle_in_the_Wind_1997']
,['"Too Close"', 'Next', '/wiki/Too_Close_(Next_song)']
,['"Believe"', 'Cher', '/wiki/Believe_(Cher_song)']
,['"Breathe"', 'Faith Hill', '/wiki/Breathe_(Faith_Hill_song)']
,['"Hanging by a Moment"', 'Lifehouse', '/wiki/Hanging_by_a_Moment']
,['"How You Remind Me"', 'Nickelback', '/wiki/How_You_Remind_Me']
,['"In da Club"', '50 Cent', '/wiki/In_da_Club']
,['"Yeah!"', 'Usher featuring Lil Jon and Ludacris', '/wiki/Yeah!_(Usher_song)']
,['"We Belong Together"', 'Mariah Carey', '/wiki/We_Belong_Together_(Mariah_Carey_song)']
,['"Bad Day"', 'Daniel Powter', '/wiki/Bad_Day_(Daniel_Powter_song)']
,['"Irreplaceable"', 'Beyoncé', '/wiki/Irreplaceable']
,['"Low"', 'Flo Rida featuring T-Pain', '/wiki/Low_(Flo_Rida_song)']
,['"Boom Boom Pow"', 'The Black Eyed Peas', '/wiki/Boom_Boom_Pow']
,['"Tik Tok"', 'Kesha', '/wiki/Tik_Tok_(song)']
,['"Rolling in the Deep"', 'Adele', '/wiki/Rolling_in_the_Deep']
,['"Somebody That I Used to Know"', 'Gotye featuring Kimbra', '/wiki/Somebody_That_I_Used_to_Know']
,['"Thrift Shop"', 'Macklemore & Ryan Lewis featuring Wanz', '/wiki/Thrift_Shop']
,['"Happy"', 'Pharrell Williams', '/wiki/Happy_(Pharrell_Williams_song)']
,['"Uptown Funk"', 'Mark Ronson featuring Bruno Mars', '/wiki/Uptown_Funk']
,['"Love Yourself"', 'Justin Bieber', '/wiki/Love_Yourself']
,['"Shape of You"', 'Ed Sheeran', '/wiki/Shape_of_You']
,['"God\'s Plan"', 'Drake', '/wiki/God%27s_Plan_(song)']
,['"Old Town Road"', 'Lil Nas X featuring Billy Ray Cyrus', '/wiki/Old_Town_Road']
,['"Blinding Lights"', 'The Weeknd', '/wiki/Blinding_Lights']
,['"Levitating"', 'Dua Lipa', '/wiki/Levitating_(song)']]

# %%
for song in list123:
    print("================")
    print(song[1],song[0])
    print(get_additional_song_data(song[2]))
# Out:
# ================
# Johnny Horton "The Battle of New Orleans"
# ['1959', ['Country'], '2:33', 'Columbia', 1, ['Jimmy Driftwood'], '']
# ================
# Percy Faith "Theme from A Summer Place"
# ['1959[4]', ['Easy', 'listening'], '2:25', 'Columbia Records', 1, ['Max Steiner'], 'https://www.youtube.com/watch?v=fRV0yHiEua8']
# ================
# Bobby Lewis "Tossin' and Turnin'"
# ['1961', ['R&B'], '2:29', 'Beltone', 1, ['Ritchie Adams'], '']
# ================
# Acker Bilk "Stranger on the Shore"
# ['1961', ['Easy', 'listening', 'Jazz'], '2:52', 'Columbia', 2, ['Acker Bilk', 'Robert Mellin'], '']
# ================
# Jimmy Gilmer and the Fireballs "Sugar Shack"
# ['1963', ['Garage', 'rock,', 'rock'], '2:00', 'Dot', 1, ['Keith McCormack'], '']
# ================
# The Beatles "I Want to Hold Your Hand"
# ['1963', ['Rock and roll', 'pop'], '2:24', 'Parlophone', 2, ['Lennon–McCartney'], 'https://www.youtube.com/watch?v=XT4pwRi2JmY']
# ================
# Sam the Sham and the Pharaohs "Wooly Bully"
# ['1965', ['Rock and roll', 'garage rock'], '2:20', 'MGM', 1, ['Domingo Samudio'], '']
# ================
# The Mamas & the Papas "California Dreamin'"
# ['1965', ['Sunshine pop', 'folk rock'], '2:42', 'Dunhill', 2, ['John Phillips', 'Michelle Phillips'], '']
# ================
# Lulu "To Sir With Love"
# ['1967', ['Pop'], '2:47', 'Epic', 1, [''], '']
# ================
# The Beatles "Hey Jude"
# ['1968', ['Pop', 'rock'], '7:11', 'Apple', 1, ['Lennon–McCartney'], 'https://www.youtube.com/watch?v=A_MjCqQoLLA']
# ================
# The Archies "Sugar, Sugar"
# ['1969', ['Bubblegum', 'pop[1]'], '2:48', 'Calendar', 3, ['Andy Kim', 'Jeff Barry'], 'https://www.youtube.com/watch?v=h9nE2spOw_o']
# ================
# Simon & Garfunkel "Bridge Over Troubled Water"
# ['1970', ['Pop rock', 'gospel'], '4:55', 'Columbia', 1, ['Paul Simon'], 'https://www.youtube.com/watch?v=4G-YQA_bsOU']
# ================
# Three Dog Night "Joy to the World"
# ['1971', ['Soft', 'rock[2]'], '3:40', 'Dunhill', 1, ['Hoyt Axton'], '']
# ================
# Roberta Flack "The First Time Ever I Saw Your Face"
# ['1972', ['Soul', 'vocal jazz'], '5:22', 'Atlantic', 1, ['Ewan MacColl'], '']
# ================
# Tony Orlando and Dawn "Tie a Yellow Ribbon Round the Ole Oak Tree"
# ['1973', ['Pop'], '3:20', 'Bell', 1, ['Irwin Levine', 'L. Russell Brown'], '']
# ================
# Barbra Streisand "The Way We Were"
# ['1973', [''], '3:29', 'Columbia', 1, ['Alan Bergman', 'Marilyn Bergman'], '']
# ================
# Captain & Tennille "Love Will Keep Us Together"
# ['1973', ['Pop'], '', 'MGM', 1, [''], '']
# ================
# Wings "Silly Love Songs"
# ['1976', ['Disco', 'funk'], '5:54', 'Capitol', 1, ['Paul McCartney', 'Linda McCartney'], 'https://www.youtube.com/watch?v=ap87QgZKTNw']
# ================
# Rod Stewart "Tonight's the Night (Gonna Be Alright)"
# ['1976', ['Soft', 'rock[1]'], '3:56', 'Riva', 2, ['Rod Stewart'], 'https://www.youtube.com/watch?v=IZr6AE-u2UM']
# ================
# Andy Gibb "Shadow Dancing"
# ['1978', ['Disco'], '4:34', 'RSO Records', 1, ['Barry, Robin & Maurice Gibb', 'Andy Gibb'], '']
# ================
# The Knack "My Sharona"
# ['1979', ['Power pop', 'new wave'], '4:52', 'Capitol', 1, ['Doug Fieger', 'Berton Averre'], 'https://www.youtube.com/watch?v=bbr60I0u2Ng']
# ================
# Blondie "Call Me"
# ['1980', ['Dance-rock', 'hard rock', 'new wave'], '8:05', 'Polydor', 3, ['Debbie Harry', 'Giorgio Moroder'], 'https://www.youtube.com/watch?v=StKVS0eI85I']
# ================
# Kim Carnes "Bette Davis Eyes"
# ['1981', ['New wave', 'soft rock'], '3:48', 'EMI America', 1, ['Donna Weiss', 'Jackie DeShannon'], 'https://www.youtube.com/watch?v=EPOIS5taqA8']
# ================
# Olivia Newton-John "Physical"
# ['1981', ['Pop rock', 'dance-pop', 'post-disco'], '3:44', 'EMI', 2, ['Steve Kipner'], 'https://www.youtube.com/watch?v=KDGvSZb9syw']
# ================
# The Police "Every Breath You Take"
# ['1983', ['New wave', 'soft rock'], '4:13', 'A&M', 1, ['Sting'], 'https://www.youtube.com/watch?v=OMOGaugKpzs']
# ================
# Prince "When Doves Cry"
# ['1984', ['Experimental pop', 'neo-psychedelia', 'soul'], '5:52', 'Warner Bros.', 1, ['Prince'], 'https://www.youtube.com/watch?v=UG3VcCAlUgE']
# ================
# Wham! "Careless Whisper"
# ['1984', ['Pop', 'soul', 'R&B'], '6:30', 'Epic', 3, ['George Michael', 'Andrew Ridgeley'], 'https://www.youtube.com/watch?v=izGwDsrQ1eQ']
# ================
# Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder) "That's What Friends Are For"
# ['1982', ['Pop'], '3:54', 'Warner Bros.', 1, ['Burt Bacharach', 'Carole Bayer Sager'], '']
# ================
# The Bangles "Walk Like An Egyptian"
# ['1986', ['Pop rock', 'novelty'], '3:24', 'Columbia', 2, ['Liam Sternberg'], 'https://www.youtube.com/watch?v=Cv6tuzHUuuk']
# ================
# George Michael "Faith"
# ['1987', ['Pop', 'rock and roll'], '3:16', 'Columbia', 1, ['George Michael'], 'https://www.youtube.com/watch?v=6Cs3Pvmmv0E']
# ================
# Chicago "Look Away"
# ['1988[1]', ['Rock'], '4:02', 'Full Moon', 2, ['Diane Warren'], '']
# ================
# Wilson Phillips "Hold On"
# ['1990', ['Pop,', 'pop', 'rock,'], '4:27', 'SBK', 1, ['Carnie Wilson', 'Chynna Phillips'], 'https://www.youtube.com/watch?v=uIbXvaE39wM']
# ================
# Bryan Adams "(Everything I Do) I Do It for You"
# ['1991', ['Soft rock'], '6:34', 'A&M', 1, ['Bryan Adams', 'Michael Kamen'], 'https://www.youtube.com/watch?v=Y0pdQU87dc8']
# ================
# Boyz II Men "End of the Road"
# ['1992', ['R&B'], '5:48', 'LaFace', 3, ['Kenneth "Babyface" Edmonds', 'Antonio "L.A." Reid'], 'https://www.youtube.com/watch?v=zDKO6XYXioc']
# ================
# Whitney Houston "I Will Always Love You"
# ['1974', ['Country'], '2:54', 'RCA Victor', 1, ['Dolly Parton'], 'https://www.youtube.com/watch?v=lKsQR72HY0s']
# ================
# Ace of Base "The Sign"
# ['1993', ['Techno-reggae', 'pop', 'Europop'], '3:08', 'Arista', 2, ['Jonas Berggren'], 'https://www.youtube.com/watch?v=iqu132vTl5Y']
# ================
# Coolio featuring L.V. "Gangsta's Paradise"
# ['1995', ['Hip hop', 'gangsta rap', 'G-funk'], '4:04', 'Tommy Boy', 3, [''], 'https://www.youtube.com/watch?v=fPO76Jlnz6c']
# ================
# Los del Río "Macarena (Bayside Boys Mix)"
# ['1993', ['Flamenco', 'pop'], '4:12', 'RCA', 1, ['\nRafael Ruiz Perdigones\nAntonio Romero Monge\n'], 'https://www.youtube.com/watch?v=zWaymcVmJ-A']
# ================
# Elton John "Candle in the Wind 1997" / "Something About the Way You Look Tonight"
# ['1997', ['Pop', 'rock'], '4:11', 'Rocket', 2, ['Bernie Taupin'], '']
# ================
# Next "Too Close"
# ['1998', [''], '4:20', 'Arista', 1, ['Kay Gee', ' Terry Brown'], 'https://www.youtube.com/watch?v=kwEZRPkAAu8']
# ================
# Cher "Believe"
# ['1998', ['Electropop', 'dance-pop'], '3:59', 'Warner Bros.', 1, ['Brian Higgins', 'Paul Barry'], 'https://www.youtube.com/watch?v=nZXRV4MezEw']
# ================
# Faith Hill "Breathe"
# ['1999', ['Country', 'pop'], '4:09', 'Warner Bros. Nashville', 1, ['Stephanie Bentley', 'Holly Lamar'], 'https://www.youtube.com/watch?v=yCmsZUN4r_s']
# ================
# Lifehouse "Hanging by a Moment"
# ['2000', ['Post-grunge', 'alternative rock'], '3:36', 'DreamWorks', 1, ['Jason Wade'], '']
# ================
# Nickelback "How You Remind Me"
# ['2001', ['Post-grunge', 'alternative rock', 'hard rock'], '3:43', 'Roadrunner', 1, [''], 'https://www.youtube.com/watch?v=1cQh1ccqu8M']
# ================
# 50 Cent "In da Club"
# ['2003', ['East Coast hip hop', 'gangsta rap'], '3:13', 'Aftermath', 3, ['Curtis Jackson', 'Andre Young'], 'https://www.youtube.com/watch?v=5qm8PH4xAss']
# ================
# Usher featuring Lil Jon and Ludacris "Yeah!"
# ['2004', ['Hip hop', 'crunk&B'], '4:10', 'Arista', 1, ['Christopher Bridges', 'James Phillips'], '']
# ================
# Mariah Carey "We Belong Together"
# ['2005', ['R&B'], '3:21', 'Island Def Jam', 1, ['Jermaine Dupri', 'Manuel Seal'], 'https://www.youtube.com/watch?v=0habxsuXW4g']
# ================
# Daniel Powter "Bad Day"
# ['2005', ['Pop'], '3:55', 'Warner Bros.', 1, ['Daniel Powter'], '']
# ================
# Beyoncé "Irreplaceable"
# ['2006', ['Pop', 'R&B'], '3:47', 'Columbia', 1, ['Shaffer "Ne-Yo" Smith', 'Mikkel S. Eriksen'], 'https://www.youtube.com/watch?v=2EwViQxSJJQ']
# ================
# Flo Rida featuring T-Pain "Low"
# ['2007', ['Southern hip hop', 'crunk'], '3:50', 'Atlantic', 2, ['Tramar Dillard', 'Faheem Najm'], '']
# ================
# The Black Eyed Peas "Boom Boom Pow"
# ['2009', [''], '5:08', 'Interscope', 1, ['William Adams', 'Allan Pineda'], 'https://www.youtube.com/watch?v=4m48GqaOz90']
# ================
# Kesha "Tik Tok"
# ['2009', ['Dance-pop', 'electropop'], '3:20', 'RCA', 1, ['Kesha Sebert', 'Dr. Luke'], 'https://www.youtube.com/watch?v=iP6XpLQM2Cs']
# ================
# Adele "Rolling in the Deep"
# ['2010', ['Rhythm and blues', 'soul'], '3:48', 'XL', 2, ['Adele Adkins', 'Paul Epworth'], 'https://www.youtube.com/watch?v=rYEDA3JcQqw']
# ================
# Gotye featuring Kimbra "Somebody That I Used to Know"
# ['2011', ['Art pop', 'alternative rock'], '4:04', 'Eleven', 1, ['Wally de Backer'], '']
# ================
# Macklemore & Ryan Lewis featuring Wanz "Thrift Shop"
# ['2012', ['Pop-rap', 'comedy hip hop'], '3:55', 'Macklemore LLC', 1, ['Ben Haggerty', 'Ryan Lewis'], 'https://www.youtube.com/watch?v=QK8mJJJvaes']
# ================
# Pharrell Williams "Happy"
# ['2013', ['Soul', 'neo soul'], '3:55', 'i Am Other', 2, ['Pharrell Williams'], 'https://www.youtube.com/watch?v=y6Sxv-sUYtM']
# ================
# Mark Ronson featuring Bruno Mars "Uptown Funk"
# ['2014', ['Funk', 'pop', 'soul'], '4:30', 'Columbia', 3, ['Mark Ronson', 'Bruno Mars'], 'https://www.youtube.com/watch?v=OPf0YbXqDm0']
# ================
# Justin Bieber "Love Yourself"
# ['2015', ['Pop[1][2]'], '3:53', 'Def Jam', 1, ['Justin Bieber', 'Benjamin Levin'], 'https://www.youtube.com/watch?v=oyEuk8j8imI']
# ================
# Ed Sheeran "Shape of You"
# ['2017', ['Pop', 'dancehall', 'tropical house'], '3:541', 'Asylum', 2, ['Ed Sheeran', 'Johnny McDaid'], 'https://www.youtube.com/watch?v=JGwWNGJdvx8']
# ================
# Drake "God's Plan"
# ['2018', ['Pop', 'pop-rap', 'trap'], '3:19', 'Young Money', 3, ['Aubrey Graham', 'Ronald LaTour'], 'https://www.youtube.com/watch?v=xpVfcZ0ZcFM']
# ================
# Lil Nas X featuring Billy Ray Cyrus "Old Town Road"
# ['2018', ['Country rap', 'country trap', 'pop'], '2:37', 'Columbia', 1, ['Montero Hill', 'Trent Reznor'], 'https://www.youtube.com/watch?v=w2Ov5jzm3j8']
# ================
# The Weeknd "Blinding Lights"
# ['2019', ['Synthwave', 'synth-pop', 'electropop'], '3:21', 'XO', 2, ['Abel Tesfaye', 'Ahmad Balshe'], 'https://www.youtube.com/watch?v=4NRXx6U8ABQ']
# ================
# Dua Lipa "Levitating"
# ['2020', ['Electro', 'disco', 'nu-disco'], '3:23', 'Warner', 1, ['Clarence Coffee Jr.', 'Sarah Hudson'], 'https://www.youtube.com/watch?v=N000qglmmY0']

# %% [markdown]
# ## Web scrape all the lyrics

# %% [markdown]
# ## Textblob (For the lyrics)
# - https://www.youtube.com/watch?v=ea4IadDRwuc&list=PL_92WMXSLe_-RkWW5zAQZ-gMdVqZ7T-_F&index=3
# - https://textblob.readthedocs.io/en/dev/quickstart.html

# %%
# Research more
