# %% [markdown]
# # Music / Lyric Analyzer
#
# ## Webscrapping the songs from Wikipedia (1959 - 2021)
# #### Notice: There will be a part 2, where i fetch all the lyrics from a site called https://www.mldb.org
#
# OBS:! I saw that most songs have a link. With some aditional data. Genre, Length, Label, Released.
# Also all most of singers actually!

# %%
import bs4
import requests

def get_top100_song_year(year=2021):
    """This function will return..."""
    result_dict = dict()
    
    url = "https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + str(year)
    
    r = requests.get(url)
    r.raise_for_status()
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    table = soup.select('.wikitable > tbody > tr')
    
    for el in table:
        td = el.select('td')
        if(len(td) > 0):
            number = td[0].text.rstrip('\n')
            title = td[1].text.rstrip('\n')
            artist = extract_artists(td[2])
            title_url = extract_title_url(td[1])
            result_dict[number] = [title[1:-1], artist[0], artist[1], title_url]
    
    return result_dict

def extract_artists(element):
    """This function will return..."""
    
    if(element.find('a')):
        result_list = [x.text.rstrip('\n') for x in element.select('a')]
    elif(element.find('li')):
        result_list = [x.text.rstrip('\n') for x in element.select('li')]
    else:
        # A handfull of songs are listed wrongly. So I have to check for the word 'featuring'
        result = element.text.rstrip('\n')
        if('featuring' in result):
            result_list = result.split(' featuring ')
        else:
            result_list =  [result]
    
     
    
    # Need to add a blank spot if there is no featuring artist.
    if(len(result_list) < 2):
        result_list.append("")
    
    return [artist for artist in result_list][:2]

def extract_title_url(element):
    """This function will return..."""
    
    if(element.find('a')):
        return element.select('a')[0].get('href')
    else:
        return ""

# %%
def get_all_top100_song_period(start=1959, end=2021):
    """This function will return..."""
    result_dict = dict()
    for i in range(start, end + 1):
        result_dict[i] = get_top100_song_year(i)
    return result_dict

        
billboard_data = get_all_top100_song_period(1959, 2021)
billboard_data
# Out:
# {1959: {'1': ['The Battle of New Orleans',
#    'Johnny Horton',
#    '',
#    '/wiki/The_Battle_of_New_Orleans'],
#   '2': ['Mack the Knife', 'Bobby Darin', '', '/wiki/Mack_the_Knife'],
#   '3': ['Personality',
#    'Lloyd Price',
#    '',
#    '/wiki/Personality_(Lloyd_Price_song)'],
#   '4': ['Venus', 'Frankie Avalon', '', '/wiki/Venus_(Frankie_Avalon_song)'],
#   '5': ['Lonely Boy', 'Paul Anka', '', '/wiki/Lonely_Boy_(Paul_Anka_song)'],
#   '6': ['Dream Lover', 'Bobby Darin', '', '/wiki/Dream_Lover'],
#   '7': ['The Three Bells', 'The Browns', '', '/wiki/The_Three_Bells'],
#   '8': ['Come Softly to Me', 'The Fleetwoods', '', '/wiki/Come_Softly_to_Me'],
#   '9': ['Kansas City',
#    'Wilbert Harrison',
#    '',
#    '/wiki/Kansas_City_(Leiber_and_Stoller_song)'],
#   '10': ['Mr. Blue', 'The Fleetwoods', '', '/wiki/Mr._Blue'],
#   '11': ['Sleep Walk', 'Santo & Johnny', '', '/wiki/Sleep_Walk'],
#   '12': ['Put Your Head on My Shoulder',
#    'Paul Anka',
#    '',
#    '/wiki/Put_Your_Head_on_My_Shoulder'],
#   '13': ['Stagger Lee', 'Lloyd Price', '', '/wiki/Stagger_Lee'],
#   '14': ['Donna', 'Ritchie Valens', '', '/wiki/Donna_(Ritchie_Valens_song)'],
#   '15': ['Pink Shoe Laces', 'Dodie Stevens', '', '/wiki/Pink_Shoe_Laces'],
#   '16': ['Smoke Gets in Your Eyes',
#    'The Platters',
#    '',
#    '/wiki/Smoke_Gets_in_Your_Eyes'],
#   '17': ['Charlie Brown',
#    'The Coasters',
#    '',
#    '/wiki/Charlie_Brown_(The_Coasters_song)'],
#   '18': ['Quiet Village', 'Martin Denny', '', '/wiki/Quiet_Village'],
#   '19': ['My Heart Is an Open Book',
#    'Carl Dobkins Jr.',
#    '',
#    '/wiki/My_Heart_Is_an_Open_Book'],
#   '20': ['(Till) I Kissed You',
#    'The Everly Brothers',
#    '',
#    '/wiki/(Till)_I_Kissed_You'],
#   '21': ['Sea of Love',
#    'Phil Phillips',
#    '',
#    '/wiki/Sea_of_Love_(Phil_Phillips_song)'],
#   '22': ['The Happy Organ', 'Dave Cortez', '', '/wiki/The_Happy_Organ'],
#   '23': ["I'm Gonna Get Married",
#    'Lloyd Price',
#    '',
#    '/wiki/I%27m_Gonna_Get_Married'],
#   '24': ['Sorry (I Ran All the Way Home)',
#    'The Impalas',
#    '',
#    '/wiki/Sorry_(I_Ran_All_the_Way_Home)'],
#   '25': ['A Teenager in Love',
#    'Dion and the Belmonts',
#    '',
#    '/wiki/A_Teenager_in_Love'],
#   '26': ['16 Candles', 'The Crests', '', '/wiki/16_Candles_(song)'],
#   '27': ["It's Just a Matter of Time",
#    'Brook Benton',
#    '',
#    '/wiki/It%27s_Just_a_Matter_of_Time_(song)'],
#   '28': ['Lipstick on Your Collar',
#    'Connie Francis',
#    '',
#    '/wiki/Lipstick_on_Your_Collar_(song)'],
#   '29': ['There Goes My Baby',
#    'The Drifters',
#    '',
#    '/wiki/There_Goes_My_Baby_(The_Drifters_song)'],
#   '30': ["A Big Hunk o' Love",
#    'Elvis Presley',
#    '',
#    '/wiki/A_Big_Hunk_o%27_Love'],
#   '31': ['Red River Rock',
#    'Johnny and the Hurricanes',
#    '',
#    '/wiki/Red_River_Valley_(song)'],
#   '32': ['Waterloo',
#    'Stonewall Jackson',
#    '',
#    '/wiki/Waterloo_(Stonewall_Jackson_song)'],
#   '33': ["Lavender's Blue", 'Sammy Turner', '', '/wiki/Lavender%27s_Blue'],
#   '34': ["(Now and Then There's) A Fool Such as I",
#    'Elvis Presley',
#    '',
#    '/wiki/(Now_and_Then_There%27s)_A_Fool_Such_as_I'],
#   '35': ['Guitar Boogie Shuffle',
#    'The Virtues',
#    '',
#    '/wiki/Guitar_Boogie_(song)'],
#   '36': ['Teen Beat', 'Sandy Nelson', '', '/wiki/Teen_Beat_(song)'],
#   '37': ['Kookie, Kookie (Lend Me Your Comb)',
#    'Edd Byrnes',
#    'Connie Stevens',
#    '/wiki/Kookie,_Kookie_(Lend_Me_Your_Comb)'],
#   '38': ['Tragedy', 'Thomas Wayne', '', '/wiki/Tragedy_(Thomas_Wayne_song)'],
#   '39': ['My Happiness',
#    'Connie Francis',
#    '',
#    '/wiki/My_Happiness_(1948_song)'],
#   '40': ['Tallahassee Lassie',
#    'Freddy Cannon',
#    '',
#    '/wiki/Tallahassee_Lassie'],
#   '41': ['Tiger', 'Fabian', '', '/wiki/Tiger_(Fabian_song)'],
#   '42': ['Never Be Anyone Else But You',
#    'Ricky Nelson',
#    '',
#    '/wiki/Never_Be_Anyone_Else_But_You'],
#   '43': ["Don't You Know?", 'Della Reese', '', '/wiki/Don%27t_You_Know%3F'],
#   '44': ['I Need Your Love Tonight',
#    'Elvis Presley',
#    '',
#    '/wiki/I_Need_Your_Love_Tonight'],
#   '45': ["What a Diff'rence a Day Makes",
#    'Dinah Washington',
#    '',
#    '/wiki/What_a_Diff%27rence_a_Day_Made'],
#   '46': ['The All American Boy',
#    'Bill Parsons',
#    '',
#    '/wiki/The_All_American_Boy'],
#   '47': ['Primrose Lane', 'Jerry Wallace', '', '/wiki/Primrose_Lane'],
#   '48': ["Alvin's Harmonica",
#    'The Chipmunks',
#    '',
#    '/wiki/Alvin%27s_Harmonica'],
#   '49': ['Lonely Street', 'Andy Williams', '', '/wiki/Lonely_Street_(song)'],
#   '50': ["What'd I Say", 'Ray Charles', '', '/wiki/What%27d_I_Say'],
#   '51': ['Broken Hearted Melody',
#    'Sarah Vaughan',
#    '',
#    '/wiki/Broken_Hearted_Melody'],
#   '52': ['Only You (And You Alone)',
#    'Franck Pourcel',
#    '',
#    '/wiki/Only_You_(And_You_Alone)'],
#   '53': ['Gotta Travel On', 'Billy Grammer', '', '/wiki/Gotta_Travel_On'],
#   '54': ['Poison Ivy', 'The Coasters', '', '/wiki/Poison_Ivy_(song)'],
#   '55': ['Turn Me Loose', 'Fabian', '', '/wiki/Turn_Me_Loose_(Fabian_song)'],
#   '56': ['Lonely Teardrops', 'Jackie Wilson', '', '/wiki/Lonely_Teardrops'],
#   '57': ['Hawaiian Wedding Song',
#    'Andy Williams',
#    '',
#    '/wiki/Hawaiian_Wedding_Song'],
#   '58': ['Forty Miles of Bad Road',
#    'Duane Eddy',
#    '',
#    '/wiki/Forty_Miles_of_Bad_Road'],
#   '59': ['Just Ask Your Heart',
#    'Frankie Avalon',
#    '',
#    '/wiki/Just_Ask_Your_Heart'],
#   '60': ['Tell Him No', 'Travis and Bob', '', '/wiki/Tell_Him_No'],
#   '61': ['Frankie',
#    'Connie Francis',
#    '',
#    '/wiki/Frankie_(Connie_Francis_song)'],
#   '62': ["I've Had It",
#    'The Bell Notes',
#    '',
#    '/wiki/I%27ve_Had_It_(The_Bell_Notes_song)'],
#   '63': ['I Cried a Tear', 'LaVern Baker', '', '/wiki/I_Cried_a_Tear'],
#   '64': ['Enchanted',
#    'The Platters',
#    '',
#    '/wiki/Enchanted_(The_Platters_song)'],
#   '65': ["Since I Don't Have You",
#    'The Skyliners',
#    '',
#    '/wiki/Since_I_Don%27t_Have_You'],
#   '66': ['Peter Gunn Theme', 'Ray Anthony', '', '/wiki/Peter_Gunn_(song)'],
#   '67': ["The Chipmunk Song (Christmas Don't Be Late)",
#    'The Chipmunks',
#    '',
#    '/wiki/The_Chipmunk_Song_(Christmas_Don%27t_Be_Late)'],
#   '68': ['I Want to Walk You Home',
#    'Fats Domino',
#    '',
#    '/wiki/I_Want_to_Walk_You_Home'],
#   '69': ['So Fine', 'The Fiestas', '', '/wiki/So_Fine_(Johnny_Otis_song)'],
#   '70': ['Bobby Sox to Stockings',
#    'Frankie Avalon',
#    '',
#    '/wiki/Bobby_Sox_to_Stockings'],
#   '71': ['The Deck of Cards',
#    'Wink Martindale',
#    '',
#    '/wiki/The_Deck_of_Cards'],
#   '72': ["A Lover's Question",
#    'Clyde McPhatter',
#    '',
#    '/wiki/A_Lover%27s_Question'],
#   '73': ['I Only Have Eyes for You',
#    'The Flamingos',
#    '',
#    '/wiki/I_Only_Have_Eyes_for_You'],
#   '74': ["It's Late",
#    'Ricky Nelson',
#    '',
#    '/wiki/It%27s_Late_(Ricky_Nelson_song)'],
#   '75': ['Petite Fleur', "Chris Barber's Jazz Band", '', '/wiki/Petite_Fleur'],
#   '76': ['Tall Paul', 'Annette Funicello', '', '/wiki/Tall_Paul'],
#   '77': ['The Tijuana Jail',
#    'The Kingston Trio',
#    '',
#    '/wiki/The_Tijuana_Jail'],
#   '78': ['Just a Little Too Much',
#    'Ricky Nelson',
#    '',
#    '/wiki/Just_a_Little_Too_Much'],
#   '79': ['Goodbye Baby',
#    'Jack Scott',
#    '',
#    '/wiki/Goodbye_Baby_(Jack_Scott_song)'],
#   '80': ['Along Came Jones',
#    'The Coasters',
#    '',
#    '/wiki/Along_Came_Jones_(song)'],
#   '81': ['Three Stars', 'Tommy Dee', '', '/wiki/Three_Stars_(song)'],
#   '82': ['A Boy Without a Girl',
#    'Frankie Avalon',
#    '',
#    '/wiki/A_Boy_Without_a_Girl'],
#   '83': ['Sweeter Than You', 'Ricky Nelson', '', '/wiki/Sweeter_Than_You'],
#   '84': ['It Was I', 'Skip & Flip', '', '/wiki/It_Was_I'],
#   '85': ['Goodbye Jimmy, Goodbye',
#    'Kathy Linden',
#    '',
#    '/wiki/Goodbye_Jimmy,_Goodbye'],
#   '86': ['Manhattan Spiritual',
#    'Reg Owen Orchestra',
#    '',
#    '/wiki/Manhattan_Spiritual'],
#   '87': ['Endlessly',
#    'Brook Benton',
#    '',
#    '/wiki/Endlessly_(Sonny_James_song)'],
#   '88': ['Heartaches by the Number',
#    'Guy Mitchell',
#    '',
#    '/wiki/Heartaches_by_the_Number'],
#   '89': ['Sea Cruise', 'Frankie Ford', '', '/wiki/Sea_Cruise'],
#   '90': ["That's Why (I Love You So)",
#    'Jackie Wilson',
#    '',
#    '/wiki/That%27s_Why_(I_Love_You_So)'],
#   '91': ["You're So Fine",
#    'The Falcons',
#    '',
#    '/wiki/You%27re_So_Fine_(The_Falcons_song)'],
#   '92': ["Kissin' Time", 'Bobby Rydell', '', '/wiki/Kissin%27_Time_(song)'],
#   '93': ['My Wish Came True', 'Elvis Presley', '', '/wiki/My_Wish_Came_True'],
#   '94': ['Morgen', 'Ivo Robić', '', '/wiki/Morgen_(Ivo_Robi%C4%87_song)'],
#   '95': ['Baby Talk',
#    'Jan and Dean',
#    '',
#    '/wiki/Baby_Talk_(Jan_and_Dean_song)'],
#   '96': ['Take a Message to Mary',
#    'The Everly Brothers',
#    '',
#    '/wiki/Take_a_Message_to_Mary'],
#   '97': ['The Battle Hymn of the Republic',
#    'Mormon Tabernacle Choir',
#    '',
#    '/wiki/The_Battle_Hymn_of_the_Republic'],
#   '98': ['Bongo Rock', 'Preston Epps', '', '/wiki/Bongo_Rock'],
#   '99': ['In the Mood', 'Ernie Fields', '', '/wiki/In_the_Mood'],
#   '100': ['Seven Little Girls Sitting in the Back Seat',
#    'Paul Evans',
#    '',
#    '/wiki/Seven_Little_Girls_Sitting_in_the_Backseat']},
#  1960: {'1': ['Theme from A Summer Place',
#    'Percy Faith',
#    '',
#    '/wiki/Theme_from_A_Summer_Place'],
#   '2': ["He'll Have to Go", 'Jim Reeves', '', '/wiki/He%27ll_Have_to_Go'],
#   '3': ["Cathy's Clown",
#    'The Everly Brothers',
#    '',
#    '/wiki/Cathy%27s_Clown_(The_Everly_Brothers_song)'],
#   '4': ['Running Bear', 'Johnny Preston', '', '/wiki/Running_Bear'],
#   '5': ['Teen Angel', 'Mark Dinning', '', '/wiki/Teen_Angel_(song)'],
#   '6': ["I'm Sorry", 'Brenda Lee', '', '/wiki/I%27m_Sorry_(Brenda_Lee_song)'],
#   '7': ["It's Now or Never",
#    'Elvis Presley',
#    '',
#    '/wiki/It%27s_Now_or_Never_(song)'],
#   '8': ['Handy Man', 'Jimmy Jones', '', '/wiki/Handy_Man_(song)'],
#   '9': ['Stuck on You',
#    'Elvis Presley',
#    '',
#    '/wiki/Stuck_on_You_(Elvis_Presley_song)'],
#   '10': ['The Twist', 'Chubby Checker', '', '/wiki/The_Twist_(song)'],
#   '11': ["Everybody's Somebody's Fool",
#    'Connie Francis',
#    '',
#    '/wiki/Everybody%27s_Somebody%27s_Fool'],
#   '12': ['Wild One', 'Bobby Rydell', '', '/wiki/Wild_One_(Bobby_Rydell_song)'],
#   '13': ['Greenfields', 'The Brothers Four', '', ''],
#   '14': ["What in the World's Come Over You",
#    'Jack Scott',
#    '',
#    '/wiki/What_in_the_World%27s_Come_Over_You'],
#   '15': ['El Paso', 'Marty Robbins', '', '/wiki/El_Paso_(song)'],
#   '16': ['Alley Oop', 'The Hollywood Argyles', '', '/wiki/Alley_Oop_(song)'],
#   '17': ['My Heart Has a Mind of Its Own',
#    'Connie Francis',
#    '',
#    '/wiki/My_Heart_Has_a_Mind_of_Its_Own'],
#   '18': ["Sweet Nothin's", 'Brenda Lee', '', '/wiki/Sweet_Nothin%27s'],
#   '19': ['Itsy Bitsy Teenie Weenie Yellow Polka Dot Bikini',
#    'Brian Hyland',
#    '',
#    '/wiki/Itsy_Bitsy_Teenie_Weenie_Yellow_Polka_Dot_Bikini'],
#   '20': ['Only the Lonely', 'Roy Orbison', '', '/wiki/Only_the_Lonely'],
#   '21': ['Where or When', 'Dion and the Belmonts', '', '/wiki/Where_or_When'],
#   '22': ['Sixteen Reasons', 'Connie Stevens', '', '/wiki/Sixteen_Reasons'],
#   '23': ['Puppy Love', 'Paul Anka', '', '/wiki/Puppy_Love_(Paul_Anka_song)'],
#   '24': ['Why', 'Frankie Avalon', '', '/wiki/Why_(Frankie_Avalon_song)'],
#   '25': ["Walk, Don't Run",
#    'The Ventures',
#    '',
#    '/wiki/Walk,_Don%27t_Run_(instrumental)'],
#   '26': ['Save the Last Dance for Me',
#    'The Drifters',
#    '',
#    '/wiki/Save_the_Last_Dance_for_Me'],
#   '27': ["Baby (You've Got What It Takes)",
#    'Dinah Washington',
#    'Brook Benton',
#    '/wiki/Baby_(You%27ve_Got_What_It_Takes)'],
#   '28': ['Sink the Bismarck',
#    'Johnny Horton',
#    '',
#    '/wiki/Sink_the_Bismarck_(song)'],
#   '29': ['Chain Gang', 'Sam Cooke', '', '/wiki/Chain_Gang_(song)'],
#   '30': ['Let It Be Me',
#    'The Everly Brothers',
#    '',
#    '/wiki/Let_It_Be_Me_(The_Everly_Brothers_song)'],
#   '31': ["Good Timin'",
#    'Jimmy Jones',
#    '',
#    '/wiki/Good_Timin%27_(Jimmy_Jones_song)'],
#   '32': ['Beyond the Sea', 'Bobby Darin', '', '/wiki/Beyond_the_Sea_(song)'],
#   '33': ['Go, Jimmy, Go', 'Jimmy Clanton', '', '/wiki/Go,_Jimmy,_Go'],
#   '34': ['Night', 'Jackie Wilson', '', '/wiki/Night_(Jackie_Wilson_song)'],
#   '35': ['Burning Bridges',
#    'Jack Scott',
#    '',
#    '/wiki/Burning_Bridges_(Jack_Scott_song)'],
#   '36': ['The Big Hurt', 'Toni Fisher', '', '/wiki/The_Big_Hurt_(song)'],
#   '37': ["Because They're Young",
#    'Duane Eddy',
#    '',
#    '/wiki/Because_They%27re_Young_(song)'],
#   '38': ['Lonely Blue Boy',
#    'Conway Twitty',
#    '',
#    '/wiki/Lonely_Blue_Boy_(song)'],
#   '39': ['Pretty Blue Eyes', 'Steve Lawrence', '', '/wiki/Pretty_Blue_Eyes'],
#   '40': ['Way Down Yonder in New Orleans', 'Freddy Cannon', '', ''],
#   '41': ['Paper Roses', 'Anita Bryant', '', '/wiki/Paper_Roses'],
#   '42': ['Mr. Custer', 'Larry Verne', '', '/wiki/Mr._Custer'],
#   '43': ['I Want to Be Wanted', 'Brenda Lee', '', '/wiki/I_Want_to_Be_Wanted'],
#   '44': ['Mule Skinner Blues',
#    'The Fendermen',
#    '',
#    '/wiki/Mule_Skinner_Blues'],
#   '45': ['Cradle of Love',
#    'Johnny Preston',
#    '',
#    '/wiki/Cradle_of_Love_(Johnny_Preston_song)'],
#   '46': ['You Got What It Takes',
#    'Marv Johnson',
#    '',
#    '/wiki/You_Got_What_It_Takes'],
#   '47': ["Please Help Me, I'm Falling",
#    'Hank Locklin',
#    '',
#    '/wiki/Please_Help_Me,_I%27m_Falling'],
#   '48': ['Love You So',
#    'Ron Holden',
#    '',
#    '/wiki/Love_You_So_(Ron_Holden_song)'],
#   '49': ["Finger Poppin' Time",
#    'Hank Ballard',
#    'The Midnighters',
#    '/wiki/Finger_Poppin%27_Time'],
#   '50': ['Harbor Lights', 'The Platters', '', '/wiki/Harbour_Lights_(song)'],
#   '51': ['Let the Little Girl Dance',
#    'Billy Bland',
#    '',
#    '/wiki/Let_the_Little_Girl_Dance'],
#   '52': ["He'll Have to Stay",
#    'Jeanne Black',
#    '',
#    '/wiki/He%27ll_Have_to_Stay'],
#   '53': ['Theme from The Apartment',
#    'Ferrante & Teicher',
#    '',
#    '/wiki/Theme_from_The_Apartment'],
#   '54': ['Volare', 'Bobby Rydell', '', '/wiki/Volare_(song)'],
#   '55': ['A Million to One', 'Jimmy Charles', '', '/wiki/A_Million_to_One'],
#   '56': ['The Village of St. Bernadette',
#    'Andy Williams',
#    '',
#    '/wiki/The_Village_of_St._Bernadette_(song)'],
#   '57': ['White Silver Sands',
#    "Bill Black's Combo",
#    '',
#    '/wiki/White_Silver_Sands'],
#   '58': ['The Old Lamp-Lighter',
#    'The Browns',
#    '',
#    '/wiki/The_Old_Lamp-Lighter'],
#   '59': ['Devil or Angel', 'Bobby Vee', '', '/wiki/Devil_or_Angel'],
#   '60': ['Down by the Station',
#    'The Four Preps',
#    '',
#    '/wiki/Down_by_the_Station'],
#   '61': ['Forever',
#    'The Little Dippers',
#    '',
#    '/wiki/Forever_(The_Little_Dippers_song)'],
#   '62': ['Image of a Girl', 'The Safaris', '', '/wiki/Image_of_a_Girl'],
#   '63': ['Kiddio', 'Brook Benton', '', '/wiki/Kiddio'],
#   '64': ['Mission Bell',
#    'Donnie Brooks',
#    '',
#    '/wiki/Mission_Bell_(Donnie_Brooks_song)'],
#   '65': ['I Love the Way You Love',
#    'Marv Johnson',
#    '',
#    '/wiki/I_Love_the_Way_You_Love'],
#   '66': ["It's Time to Cry", 'Paul Anka', '', ''],
#   '67': ['Tell Laura I Love Her',
#    'Ray Peterson',
#    '',
#    '/wiki/Tell_Laura_I_Love_Her'],
#   '68': ['Mama', 'Connie Francis', '', '/wiki/Mama_(David_Whitfield_song)'],
#   '69': ['Footsteps',
#    'Steve Lawrence',
#    '',
#    '/wiki/Footsteps_(Steve_Lawrence_song)'],
#   '70': ['So Sad',
#    'The Everly Brothers',
#    '',
#    '/wiki/So_Sad_(To_Watch_Good_Love_Go_Bad)'],
#   '71': ["That's All You Gotta Do",
#    'Brenda Lee',
#    '',
#    '/wiki/That%27s_All_You_Gotta_Do'],
#   '72': ['Walking to New Orleans',
#    'Fats Domino',
#    '',
#    '/wiki/Walking_to_New_Orleans'],
#   '73': ['Among My Souvenirs',
#    'Connie Francis',
#    '',
#    '/wiki/Among_My_Souvenirs'],
#   '74': ["Swingin' School", 'Bobby Rydell', '', '/wiki/Swingin%27_School'],
#   '75': ["A Rockin' Good Way (To Mess Around and Fall in Love)",
#    'Dinah Washington',
#    'Brook Benton',
#    '/wiki/A_Rockin%27_Good_Way_(To_Mess_Around_and_Fall_in_Love)'],
#   '76': ['Stairway to Heaven',
#    'Neil Sedaka',
#    '',
#    '/wiki/Stairway_to_Heaven_(Neil_Sedaka_song)'],
#   '77': ['My Home Town', 'Paul Anka', '', '/wiki/My_Home_Town'],
#   '78': ['Georgia on My Mind', 'Ray Charles', '', '/wiki/Georgia_on_My_Mind'],
#   '79': ['Cherry Pie',
#    'Skip and Flip',
#    '',
#    '/wiki/Cherry_Pie_(Joe_Josea_song)'],
#   '80': ['Wonderful World',
#    'Sam Cooke',
#    '',
#    '/wiki/Wonderful_World_(Sam_Cooke_song)'],
#   '81': ["Tracy's Theme", 'Spencer Ross', '', '/wiki/Tracy%27s_Theme'],
#   '82': ['Lady Luck', 'Lloyd Price', '', ''],
#   '83': ['Step by Step', 'The Crests', '', ''],
#   '84': ['Happy-Go-Lucky Me', 'Paul Evans', '', ''],
#   '85': ['Young Emotions', 'Ricky Nelson', '', '/wiki/Young_Emotions'],
#   '86': ["Dreamin'",
#    'Johnny Burnette',
#    '',
#    '/wiki/Dreamin%27_(Johnny_Burnette_song)'],
#   '87': ['Poetry in Motion',
#    'Johnny Tillotson',
#    '',
#    '/wiki/Poetry_in_Motion_(song)'],
#   '88': ['O Dio Mio', 'Annette Funicello', '', ''],
#   '89': ['You Talk Too Much',
#    'Joe Jones',
#    '',
#    '/wiki/You_Talk_Too_Much_(Joe_Jones_song)'],
#   '90': ['Beatnik Fly',
#    'Johnny and the Hurricanes',
#    '',
#    '/wiki/Jimmy_Crack_Corn'],
#   '91': ['When Will I Be Loved',
#    'The Everly Brothers',
#    '',
#    '/wiki/When_Will_I_Be_Loved_(song)'],
#   '92': ["Let's Think About Living",
#    'Bob Luman',
#    '',
#    '/wiki/Let%27s_Think_About_Living'],
#   '93': ['Heartaches by the Number',
#    'Guy Mitchell',
#    '',
#    '/wiki/Heartaches_by_the_Number'],
#   '94': ['My Little Corner of the World',
#    'Anita Bryant',
#    '',
#    '/wiki/My_Little_Corner_of_the_World'],
#   '95': ["Doggin' Around", 'Jackie Wilson', '', '/wiki/Doggin%27_Around'],
#   '96': ['Little Bitty Girl', 'Bobby Rydell', '', '/wiki/Little_Bitty_Girl'],
#   '97': ["Money (That's What I Want)",
#    'Barrett Strong',
#    '',
#    '/wiki/Money_(That%27s_What_I_Want)'],
#   '98': ['Stay',
#    'Maurice Williams and the Zodiacs',
#    '',
#    '/wiki/Stay_(Maurice_Williams_song)'],
#   '99': ['Lonely Weekends', 'Charlie Rich', '', ''],
#   '100': ['Sandy', 'Larry Hall', '', '/wiki/Sandy_(Larry_Hall_song)']},
#  1961: {'1': ["Tossin' and Turnin'",
#    'Bobby Lewis',
#    '',
#    '/wiki/Tossin%27_and_Turnin%27'],
#   '2': ['I Fall to Pieces', 'Patsy Cline', '', '/wiki/I_Fall_to_Pieces'],
#   '3': ['Michael', 'The Highwaymen', '', '/wiki/Michael_Row_the_Boat_Ashore'],
#   '4': ['Crying', 'Roy Orbison', '', '/wiki/Crying_(Roy_Orbison_song)'],
#   '5': ['Runaway', 'Del Shannon', '', '/wiki/Runaway_(Del_Shannon_song)'],
#   '6': ['My True Story', 'The Jive Five', '', '/wiki/My_True_Story'],
#   '7': ['Pony Time', 'Chubby Checker', '', '/wiki/Pony_Time'],
#   '8': ['Wheels',
#    'The String-A-Longs',
#    '',
#    '/wiki/Wheels_(The_String-A-Longs_song)'],
#   '9': ['Raindrops', 'Dee Clark', '', '/wiki/Raindrops_(Dee_Clark_song)'],
#   '10': ['Wooden Heart', 'Joe Dowell', '', '/wiki/Wooden_Heart'],
#   '11': ['Calcutta', 'Lawrence Welk', '', '/wiki/Calcutta_(song)'],
#   '12': ['Take Good Care of My Baby',
#    'Bobby Vee',
#    '',
#    '/wiki/Take_Good_Care_of_My_Baby'],
#   '13': ['Running Scared',
#    'Roy Orbison',
#    '',
#    '/wiki/Running_Scared_(Roy_Orbison_song)'],
#   '14': ['Dedicated to the One I Love',
#    'The Shirelles',
#    '',
#    '/wiki/Dedicated_to_the_One_I_Love'],
#   '15': ['Last Night',
#    'The Mar-Keys',
#    '',
#    '/wiki/Last_Night_(Mar-Keys_composition)'],
#   '16': ['Will You Love Me Tomorrow',
#    'The Shirelles',
#    '',
#    '/wiki/Will_You_Love_Me_Tomorrow'],
#   '17': ['Exodus', 'Ferrante & Teicher', '', ''],
#   '18': ['Where the Boys Are',
#    'Connie Francis',
#    '',
#    '/wiki/Where_the_Boys_Are_(Connie_Francis_song)'],
#   '19': ['Hit the Road Jack', 'Ray Charles', '', '/wiki/Hit_the_Road_Jack'],
#   '20': ['Sad Movies (Make Me Cry)',
#    'Sue Thompson',
#    '',
#    '/wiki/Sad_Movies_(Make_Me_Cry)'],
#   '21': ['Mother-in-Law', 'Ernie K-Doe', '', '/wiki/Mother-in-Law_(song)'],
#   '22': ['Bristol Stomp', 'The Dovells', '', '/wiki/Bristol_Stomp'],
#   '23': ["Travelin' Man", 'Ricky Nelson', '', '/wiki/Travelin%27_Man'],
#   '24': ['Shop Around', 'The Miracles', '', '/wiki/Shop_Around'],
#   '25': ['The Boll Weevil Song',
#    'Brook Benton',
#    '',
#    '/wiki/Boll_Weevil_(song)'],
#   '26': ['A Hundred Pounds of Clay',
#    'Gene McDaniels',
#    '',
#    '/wiki/A_Hundred_Pounds_of_Clay'],
#   '27': ["The Mountain's High",
#    'Dick and Dee Dee',
#    '',
#    '/wiki/The_Mountain%27s_High'],
#   '28': ["Don't Worry",
#    'Marty Robbins',
#    '',
#    '/wiki/Don%27t_Worry_(Marty_Robbins_song)'],
#   '29': ['On the Rebound', 'Floyd Cramer', '', '/wiki/On_the_Rebound'],
#   '30': ['Portrait of My Love',
#    'Steve Lawrence',
#    '',
#    '/wiki/Portrait_of_My_Love'],
#   '31': ['Quarter to Three', 'Gary U.S. Bonds', '', '/wiki/Quarter_to_Three'],
#   '32': ['Who Put the Bomp (in the Bomp, Bomp, Bomp)',
#    'Barry Mann',
#    '',
#    '/wiki/Who_Put_the_Bomp_(in_the_Bomp,_Bomp,_Bomp)'],
#   '33': ['Calendar Girl', 'Neil Sedaka', '', '/wiki/Calendar_Girl_(song)'],
#   '34': ['I Like It Like That',
#    'Chris Kenner',
#    '',
#    '/wiki/I_Like_It_Like_That_(Chris_Kenner_song)'],
#   '35': ['Apache', 'Jørgen Ingmann', '', '/wiki/Apache_(instrumental)'],
#   '36': ["Don't Bet Money Honey",
#    'Linda Scott',
#    '',
#    '/wiki/Don%27t_Bet_Money_Honey'],
#   '37': ['Without You',
#    'Johnny Tillotson',
#    '',
#    '/wiki/Without_You_(Johnny_Tillotson_song)'],
#   '38': ['Wings of a Dove',
#    'Ferlin Husky',
#    '',
#    '/wiki/Wings_of_a_Dove_(Bob_Ferguson_song)'],
#   '39': ['Little Sister',
#    'Elvis Presley',
#    '',
#    '/wiki/Little_Sister_(Elvis_Presley_song)'],
#   '40': ['Blue Moon', 'The Marcels', '', '/wiki/Blue_Moon_(1934_song)'],
#   '41': ["Daddy's Home",
#    'Shep and the Limelites',
#    '',
#    '/wiki/Daddy%27s_Home_(song)'],
#   '42': ['This Time',
#    'Troy Shondell',
#    '',
#    '/wiki/This_Time_(Thomas_Wayne_song)'],
#   '43': ["(I Don't Know Why) But I Do",
#    'Clarence "Frogman" Henry',
#    '',
#    '/wiki/(I_Don%27t_Know_Why)_But_I_Do'],
#   '44': ['Asia Minor', 'Kokomo', '', '/wiki/Asia_Minor_(instrumental)'],
#   '45': ['Hello Walls', 'Faron Young', '', '/wiki/Hello_Walls'],
#   '46': ['Runaround Sue', 'Dion', '', '/wiki/Runaround_Sue'],
#   '47': ['Yellow Bird', 'Arthur Lyman', '', '/wiki/Choucoune_(song)'],
#   '48': ['Hurt', 'Timi Yuro', '', '/wiki/Hurt_(Roy_Hamilton_song)'],
#   '49': ['Hello Mary Lou', 'Ricky Nelson', '', '/wiki/Hello_Mary_Lou'],
#   '50': ["There's a Moon Out Tonight",
#    'The Capris',
#    '',
#    '/wiki/There%27s_a_Moon_Out_Tonight'],
#   '51': ['Surrender',
#    'Elvis Presley',
#    '',
#    '/wiki/Surrender_(Elvis_Presley_song)'],
#   '52': ['I Love How You Love Me',
#    'The Paris Sisters',
#    '',
#    '/wiki/I_Love_How_You_Love_Me'],
#   '53': ['Ya Ya', 'Lee Dorsey', '', '/wiki/Ya_Ya'],
#   '54': ['School Is Out', 'Gary U.S. Bonds', '', '/wiki/School_Is_Out'],
#   '55': ['Mexico', 'Bob Moore', '', '/wiki/Mexico_(instrumental)'],
#   '56': ["You Don't Know What You've Got (Until You Lose It)",
#    'Ral Donner',
#    '',
#    '/wiki/You_Don%27t_Know_What_You%27ve_Got'],
#   '57': ['Walk Right Back',
#    'The Everly Brothers',
#    '',
#    '/wiki/Walk_Right_Back'],
#   '58': ['The Way You Look Tonight',
#    'The Lettermen',
#    '',
#    '/wiki/The_Way_You_Look_Tonight'],
#   '59': ['Moody River', 'Pat Boone', '', '/wiki/Moody_River'],
#   '60': ['One Mint Julep', 'Ray Charles', '', '/wiki/One_Mint_Julep'],
#   '61': ['Take Good Care of Her',
#    'Adam Wade',
#    '',
#    '/wiki/Take_Good_Care_of_Her'],
#   '62': ['Gee Whiz (Look at His Eyes)',
#    'Carla Thomas',
#    '',
#    '/wiki/Gee_Whiz_(Look_at_His_Eyes)'],
#   '63': ['Stand by Me',
#    'Ben E. King',
#    '',
#    '/wiki/Stand_by_Me_(Ben_E._King_song)'],
#   '64': ['Spanish Harlem', 'Ben E. King', '', '/wiki/Spanish_Harlem_(song)'],
#   '65': ["It's Gonna Work Out Fine",
#    'Ike and Tina Turner',
#    '',
#    '/wiki/It%27s_Gonna_Work_Out_Fine'],
#   '66': ['Baby Blue', 'The Echoes', '', '/wiki/Baby_Blue_(The_Echoes_song)'],
#   '67': ["Baby Sittin' Boogie",
#    'Buzz Clifford',
#    '',
#    '/wiki/Baby_Sittin%27_Boogie'],
#   '68': ['Hats Off to Larry', 'Del Shannon', '', '/wiki/Hats_Off_to_Larry'],
#   '69': ['Those Oldies but Goodies',
#    'Little Caesar & the Romans',
#    '',
#    '/wiki/Those_Oldies_but_Goodies_(Remind_Me_of_You)'],
#   '70': ['The Fly',
#    'Chubby Checker',
#    '',
#    '/wiki/The_Fly_(Chubby_Checker_song)'],
#   '71': ["(Marie's the Name) His Latest Flame",
#    'Elvis Presley',
#    '',
#    '/wiki/(Marie%27s_the_Name)_His_Latest_Flame'],
#   '72': ['Wonderland by Night',
#    'Bert Kaempfert',
#    '',
#    '/wiki/Wonderland_by_Night'],
#   '73': ['Bless You',
#    'Tony Orlando',
#    '',
#    '/wiki/Bless_You_(Tony_Orlando_song)'],
#   '74': ["I've Told Every Little Star",
#    'Linda Scott',
#    '',
#    '/wiki/I%27ve_Told_Ev%27ry_Little_Star'],
#   '75': ['One Track Mind', 'Bobby Lewis', '', ''],
#   '76': ['Angel Baby',
#    'Rosie and the Originals',
#    '',
#    '/wiki/Angel_Baby_(Rosie_and_the_Originals_song)'],
#   '77': ['Pretty Little Angel Eyes',
#    'Curtis Lee',
#    '',
#    '/wiki/Pretty_Little_Angel_Eyes'],
#   '78': ['Think Twice',
#    'Brook Benton',
#    '',
#    '/wiki/Think_Twice_(Brook_Benton_song)'],
#   '79': ['Does Your Chewing Gum Lose Its Flavour (On the Bedpost Overnight?)',
#    'Lonnie Donegan',
#    '',
#    '/wiki/Does_Your_Chewing_Gum_Lose_Its_Flavour_(On_the_Bedpost_Overnight%3F)'],
#   '80': ["Breakin' in a Brand New Broken Heart",
#    'Connie Francis',
#    '',
#    '/wiki/Breakin%27_in_a_Brand_New_Broken_Heart'],
#   '81': ['Mama Said',
#    'The Shirelles',
#    '',
#    '/wiki/Mama_Said_(The_Shirelles_song)'],
#   '82': ['Let the Four Winds Blow', 'Fats Domino', '', ''],
#   '83': ['The Writing on the Wall',
#    'Adam Wade',
#    '',
#    '/wiki/The_Writing_on_the_Wall_(Adam_Wade_song)'],
#   '84': ['My Kind of Girl', 'Matt Monro', '', '/wiki/My_Kind_of_Girl'],
#   '85': ['Tonight My Love, Tonight', 'Paul Anka', '', ''],
#   '86': ['San Antonio Rose', 'Floyd Cramer', '', '/wiki/New_San_Antonio_Rose'],
#   '87': ['Big Bad John', 'Jimmy Dean', '', '/wiki/Big_Bad_John'],
#   '88': ['Good Time Baby', 'Bobby Rydell', '', '/wiki/Good_Time_Baby'],
#   '89': ['Rubber Ball', 'Bobby Vee', '', '/wiki/Rubber_Ball'],
#   '90': ['Missing You',
#    'Ray Peterson',
#    '',
#    '/wiki/Missing_You_(Red_Sovine_song)'],
#   '91': ['Dum Dum', 'Brenda Lee', '', '/wiki/Dum_Dum_(Brenda_Lee_song)'],
#   '92': ["I'm Gonna Knock on Your Door",
#    'Eddie Hodges',
#    '',
#    '/wiki/I%27m_Gonna_Knock_on_Your_Door'],
#   '93': ['You Can Depend on Me',
#    'Brenda Lee',
#    '',
#    '/wiki/You_Can_Depend_on_Me_(Brenda_Lee_song)'],
#   '94': ["Let's Twist Again",
#    'Chubby Checker',
#    '',
#    '/wiki/Let%27s_Twist_Again'],
#   '95': ['Take Five', 'The Dave Brubeck Quartet', '', '/wiki/Take_Five'],
#   '96': ['Are You Lonesome Tonight?',
#    'Elvis Presley',
#    '',
#    '/wiki/Are_You_Lonesome_Tonight%3F_(song)'],
#   '97': ['Sea of Heartbreak', 'Don Gibson', '', '/wiki/Sea_of_Heartbreak'],
#   '98': ['More Money for You and Me', 'The Four Preps', '', ''],
#   '99': ['You Must Have Been a Beautiful Baby',
#    'Bobby Darin',
#    '',
#    '/wiki/You_Must_Have_Been_a_Beautiful_Baby'],
#   '100': ['Please Stay',
#    'The Drifters',
#    '',
#    '/wiki/Please_Stay_(Burt_Bacharach_song)']},
#  1962: {'1': ['Stranger on the Shore',
#    'Acker Bilk',
#    '',
#    '/wiki/Stranger_on_the_Shore'],
#   '2': ["I Can't Stop Loving You",
#    'Ray Charles',
#    '',
#    '/wiki/I_Can%27t_Stop_Loving_You'],
#   '3': ['Mashed Potato Time', 'Dee Dee Sharp', '', '/wiki/Mashed_Potato_Time'],
#   '4': ['Roses Are Red (My Love)',
#    'Bobby Vinton',
#    '',
#    '/wiki/Roses_Are_Red_(My_Love)'],
#   '5': ['The Stripper', 'David Rose', '', '/wiki/The_Stripper'],
#   '6': ['Johnny Angel', 'Shelley Fabares', '', '/wiki/Johnny_Angel_(song)'],
#   '7': ['The Loco-Motion', 'Little Eva', '', '/wiki/The_Loco-Motion'],
#   '8': ['Let Me In',
#    'The Sensations',
#    '',
#    '/wiki/Let_Me_In_(The_Sensations_song)'],
#   '9': ['The Twist', 'Chubby Checker', '', '/wiki/The_Twist_(song)'],
#   '10': ['Soldier Boy',
#    'The Shirelles',
#    '',
#    '/wiki/Soldier_Boy_(The_Shirelles_song)'],
#   '11': ['Hey! Baby', 'Bruce Channel', '', '/wiki/Hey!_Baby'],
#   '12': ['The Wanderer', 'Dion', '', '/wiki/The_Wanderer_(Dion_song)'],
#   '13': ['Duke of Earl', 'Gene Chandler', '', '/wiki/Duke_of_Earl'],
#   '14': ['Palisades Park',
#    'Freddy Cannon',
#    '',
#    '/wiki/Palisades_Park_(Freddy_Cannon_song)'],
#   '15': ['Breaking Up Is Hard to Do',
#    'Neil Sedaka',
#    '',
#    '/wiki/Breaking_Up_Is_Hard_to_Do'],
#   '16': ['Wolverton Mountain', 'Claude King', '', '/wiki/Wolverton_Mountain'],
#   '17': ["Slow Twistin'",
#    'Chubby Checker',
#    'Dee Dee Sharp',
#    '/wiki/Slow_Twistin%27'],
#   '18': ["It Keeps Right On a-Hurtin'",
#    'Johnny Tillotson',
#    '',
#    '/wiki/It_Keeps_Right_On_A-Hurtin%27'],
#   '19': ['The One Who Really Loves You',
#    'Mary Wells',
#    '',
#    '/wiki/The_One_Who_Really_Loves_You_(song)'],
#   '20': ['Good Luck Charm', 'Elvis Presley', '', '/wiki/Good_Luck_Charm'],
#   '21': ['Midnight in Moscow', 'Kenny Ball', '', '/wiki/Moscow_Nights'],
#   '22': ['Sheila', 'Tommy Roe', '', '/wiki/Sheila_(Tommy_Roe_song)'],
#   '23': ["Twistin' the Night Away",
#    'Sam Cooke',
#    '',
#    '/wiki/Twistin%27_the_Night_Away'],
#   '24': ['The Wah-Watusi', 'The Orlons', '', '/wiki/The_Wah-Watusi'],
#   '25': ['Peppermint Twist',
#    'Joey Dee and the Starliters',
#    '',
#    '/wiki/Peppermint_Twist'],
#   '26': ['Break It to Me Gently',
#    'Brenda Lee',
#    '',
#    '/wiki/Break_It_to_Me_Gently'],
#   '27': ['Playboy',
#    'The Marvelettes',
#    '',
#    '/wiki/Playboy_(The_Marvelettes_song)'],
#   '28': ["Ramblin' Rose", 'Nat King Cole', '', '/wiki/Ramblin%27_Rose'],
#   '29': ['Sealed with a Kiss', 'Brian Hyland', '', '/wiki/Sealed_with_a_Kiss'],
#   '30': ['She Cried', 'Jay and the Americans', '', '/wiki/She_Cried'],
#   '31': ["Don't Break the Heart That Loves You",
#    'Connie Francis',
#    '',
#    '/wiki/Don%27t_Break_the_Heart_That_Loves_You'],
#   '32': ['Dear Lady Twist', 'Gary U.S. Bonds', '', '/wiki/Dear_Lady_Twist'],
#   '33': ['Norman', 'Sue Thompson', '', '/wiki/Norman_(song)'],
#   '34': ['Love Letters', 'Ketty Lester', '', '/wiki/Love_Letters_(song)'],
#   '35': ['Party Lights',
#    'Claudine Clark',
#    '',
#    '/wiki/Party_Lights_(Claudine_Clark_song)'],
#   '36': ['Cotton Fields', 'The Highwaymen', '', '/wiki/Cotton_Fields'],
#   '37': ['Alley Cat', 'Bent Fabric', '', '/wiki/Alley_Cat_(song)'],
#   '38': ['Twist and Shout', 'The Isley Brothers', '', '/wiki/Twist_and_Shout'],
#   '39': ['Theme from Dr. Kildare (Three Stars Will Shine Tonight)',
#    'Richard Chamberlain',
#    '',
#    '/wiki/Theme_from_Dr._Kildare_(Three_Stars_Will_Shine_Tonight)'],
#   '40': ['Tuff', 'Ace Cannon', '', '/wiki/Tuff_(instrumental)'],
#   '41': ['Lover Please', 'Clyde McPhatter', '', '/wiki/Lover_Please'],
#   '42': ["I Know (You Don't Love Me No More)",
#    'Barbara George',
#    '',
#    '/wiki/I_Know_(You_Don%27t_Love_Me_No_More)'],
#   '43': ['Young World', 'Ricky Nelson', '', '/wiki/Young_World_(song)'],
#   '44': ["Baby It's You", 'The Shirelles', '', '/wiki/Baby_It%27s_You'],
#   '45': ['Speedy Gonzales', 'Pat Boone', '', '/wiki/Speedy_Gonzales_(song)'],
#   '46': ['A Little Bitty Tear', 'Burl Ives', '', '/wiki/A_Little_Bitty_Tear'],
#   '47': ['Crying in the Rain',
#    'The Everly Brothers',
#    '',
#    '/wiki/Crying_in_the_Rain'],
#   '48': ['Al di là', 'Emilio Pericoli', '', '/wiki/Al_di_l%C3%A0'],
#   '49': ['Shout! Shout! (Knock Yourself Out)',
#    'Ernie Maresca',
#    '',
#    '/wiki/Shout!_Shout!_(Knock_Yourself_Out)'],
#   '50': ["What's Your Name",
#    'Don and Juan',
#    '',
#    '/wiki/What%27s_Your_Name_(Don_and_Juan_song)'],
#   '51': ['Smoky Places', 'The Corsairs', '', '/wiki/Smoky_Places'],
#   '52': ['Having a Party',
#    'Sam Cooke',
#    '',
#    '/wiki/Having_a_Party_(Sam_Cooke_song)'],
#   '53': ['Green Onions', "Booker T. & the M.G.'s", '', '/wiki/Green_Onions'],
#   '54': ["You Don't Know Me",
#    'Ray Charles',
#    '',
#    '/wiki/You_Don%27t_Know_Me_(Eddy_Arnold_song)'],
#   '55': ['Sherry', 'The Four Seasons', '', '/wiki/Sherry_(song)'],
#   '56': ['Johnny Get Angry', 'Joanie Sommers', '', '/wiki/Johnny_Get_Angry'],
#   '57': ["Can't Help Falling in Love",
#    'Elvis Presley',
#    '',
#    '/wiki/Can%27t_Help_Falling_in_Love'],
#   '58': ['Shout',
#    'Joey Dee and the Starliters',
#    '',
#    '/wiki/Shout_(The_Isley_Brothers_song)'],
#   '59': ['Rinky Dink',
#    'Dave "Baby" Cortez',
#    '',
#    '/wiki/Rinky_Dink_(instrumental)'],
#   '60': ['Moon River', 'Henry Mancini', '', '/wiki/Moon_River'],
#   '61': ['Ahab the Arab', 'Ray Stevens', '', '/wiki/Ahab_the_Arab'],
#   '62': ['Things', 'Bobby Darin', '', '/wiki/Things_(1962_song)'],
#   '63': ['(The Man Who Shot) Liberty Valance',
#    'Gene Pitney',
#    '',
#    '/wiki/(The_Man_Who_Shot)_Liberty_Valance'],
#   '64': ['You Belong to Me',
#    'The Duprees',
#    '',
#    '/wiki/You_Belong_to_Me_(1952_song)'],
#   '65': ['Dream Baby (How Long Must I Dream)',
#    'Roy Orbison',
#    '',
#    '/wiki/Dream_Baby_(How_Long_Must_I_Dream)'],
#   '66': ['Snap Your Fingers', 'Joe Henderson', '', '/wiki/Snap_Your_Fingers'],
#   '67': ['Lovers Who Wander', 'Dion', '', '/wiki/Lovers_Who_Wander'],
#   '68': ["Let's Dance",
#    'Chris Montez',
#    '',
#    '/wiki/Let%27s_Dance_(Chris_Montez_song)'],
#   '69': ["Cindy's Birthday", 'Johnny Crawford', '', ''],
#   '70': ['You Beat Me to the Punch',
#    'Mary Wells',
#    '',
#    '/wiki/You_Beat_Me_to_the_Punch'],
#   '71': ["You'll Lose a Good Thing",
#    'Barbara Lynn',
#    '',
#    '/wiki/You%27ll_Lose_a_Good_Thing'],
#   '72': ['Uptown', 'The Crystals', '', '/wiki/Uptown_(The_Crystals_song)'],
#   '73': ['Everybody Loves Me But You',
#    'Brenda Lee',
#    '',
#    '/wiki/Everybody_Loves_Me_But_You'],
#   '74': ['Patches', 'Dickey Lee', '', '/wiki/Patches_(Dickey_Lee_song)'],
#   '75': ['Venus in Blue Jeans',
#    'Jimmy Clanton',
#    '',
#    '/wiki/Venus_in_Blue_Jeans'],
#   '76': ['Love Me Warm and Tender', 'Paul Anka', '', ''],
#   '77': ['Teen Age Idol', 'Rick Nelson', '', '/wiki/Teen_Age_Idol'],
#   '78': ["She's Got You", 'Patsy Cline', '', '/wiki/She%27s_Got_You'],
#   '79': ['Dear One',
#    'Larry Finnegan',
#    '',
#    '/wiki/Dear_One_(Larry_Finnegan_song)'],
#   '80': ['Her Royal Majesty',
#    'James Darren',
#    '',
#    '/wiki/Her_Royal_Majesty_(song)'],
#   '81': ['Old Rivers', 'Walter Brennan', '', '/wiki/Old_Rivers'],
#   '82': ["Funny Way of Laughin'",
#    'Burl Ives',
#    '',
#    '/wiki/Funny_Way_of_Laughin%27'],
#   '83': ["A Swingin' Safari", 'Billy Vaughn', '', '/wiki/A_Swingin%27_Safari'],
#   '84': ['Tell Me', 'Dick and Dee Dee', '', ''],
#   '85': ['PT-109', 'Jimmy Dean', '', '/wiki/PT-109_(song)'],
#   '86': ['Little Diane', 'Dion', '', '/wiki/Little_Diane'],
#   '87': ['Percolator (Twist)', 'Billy Joe and the Checkmates', '', ''],
#   '88': ['Twist, Twist Senora',
#    'Gary U.S. Bonds',
#    '',
#    '/wiki/Twist,_Twist_Senora'],
#   '89': ["Twistin' Matilda", 'Jimmy Soul', '', ''],
#   '90': ['Gravy (For My Mashed Potatoes)', 'Dee Dee Sharp', '', ''],
#   '91': ['Walk on the Wild Side', 'Jimmy Smith', '', ''],
#   '92': ['Soul Twist', 'King Curtis', '', '/wiki/Soul_Twist'],
#   '93': ["I'll Never Dance Again",
#    'Bobby Rydell',
#    '',
#    '/wiki/I%27ll_Never_Dance_Again'],
#   '94': ["I'm Blue (The Gong-Gong Song)",
#    'The Ikettes',
#    '',
#    '/wiki/I%27m_Blue_(The_Gong-Gong_Song)'],
#   '95': ['Where Have All the Flowers Gone?',
#    'The Kingston Trio',
#    '',
#    '/wiki/Where_Have_All_the_Flowers_Gone%3F'],
#   '96': ['(Girls, Girls, Girls) Made to Love', 'Eddie Hodges', '', ''],
#   '97': ['Town Without Pity',
#    'Gene Pitney',
#    '',
#    '/wiki/Town_Without_Pity_(song)'],
#   '98': ['If I Had a Hammer',
#    'Peter, Paul and Mary',
#    '',
#    '/wiki/If_I_Had_a_Hammer'],
#   '99': ['I Wish That We Were Married', 'Ronnie & the Hi-Lites', '', ''],
#   '100': ["Surfin' Safari",
#    'The Beach Boys',
#    '',
#    '/wiki/Surfin%27_Safari_(song)']},
#  1963: {'1': ['Sugar Shack',
#    'Jimmy Gilmer and the Fireballs',
#    '',
#    '/wiki/Sugar_Shack'],
#   '2': ["Surfin' U.S.A.",
#    'The Beach Boys',
#    '',
#    '/wiki/Surfin%27_U.S.A._(song)'],
#   '3': ['The End of the World',
#    'Skeeter Davis',
#    '',
#    '/wiki/The_End_of_the_World_(Skeeter_Davis_song)'],
#   '4': ['Rhythm of the Rain', 'The Cascades', '', '/wiki/Rhythm_of_the_Rain'],
#   '5': ["He's So Fine", 'The Chiffons', '', '/wiki/He%27s_So_Fine'],
#   '6': ['Blue Velvet', 'Bobby Vinton', '', '/wiki/Blue_Velvet_(song)'],
#   '7': ['Hey Paula', 'Paul and Paula', '', '/wiki/Hey_Paula_(song)'],
#   '8': ['Fingertips', 'Stevie Wonder', '', '/wiki/Fingertips'],
#   '9': ['Washington Square',
#    'The Village Stompers',
#    '',
#    '/wiki/Washington_Square_(composition)'],
#   '10': ["It's All Right",
#    'The Impressions',
#    '',
#    '/wiki/It%27s_All_Right_(The_Impressions_song)'],
#   '11': ["Can't Get Used to Losing You",
#    'Andy Williams',
#    '',
#    '/wiki/Can%27t_Get_Used_to_Losing_You'],
#   '12': ["My Boyfriend's Back",
#    'The Angels',
#    '',
#    '/wiki/My_Boyfriend%27s_Back_(song)'],
#   '13': ['Sukiyaki', 'Kyu Sakamoto', '', '/wiki/Sukiyaki_(song)'],
#   '14': ["She's a Fool", 'Lesley Gore', '', '/wiki/She%27s_a_Fool'],
#   '15': ['So Much in Love', 'The Tymes', '', '/wiki/So_Much_in_Love'],
#   '16': ['Puff, the Magic Dragon',
#    'Peter, Paul and Mary',
#    '',
#    '/wiki/Puff,_the_Magic_Dragon'],
#   '17': ["Blowin' in the Wind",
#    'Peter, Paul and Mary',
#    '',
#    '/wiki/Blowin%27_in_the_Wind'],
#   '18': ["I'm Leaving It Up to You",
#    'Dale and Grace',
#    '',
#    '/wiki/I%27m_Leaving_It_Up_to_You'],
#   '19': ['Deep Purple',
#    'Nino Tempo & April Stevens',
#    '',
#    '/wiki/Deep_Purple_(song)'],
#   '20': ['Wipe Out', 'The Surfaris', '', '/wiki/Wipe_Out_(instrumental)'],
#   '21': ['I Love You Because',
#    'Al Martino',
#    '',
#    '/wiki/I_Love_You_Because_(song)'],
#   '22': ['Wild Weekend', 'The Rebels', '', '/wiki/Wild_Weekend'],
#   '23': ["You're the Reason I'm Living",
#    'Bobby Darin',
#    '',
#    '/wiki/You%27re_the_Reason_I%27m_Living'],
#   '24': ['Walk Like a Man',
#    'The Four Seasons',
#    '',
#    '/wiki/Walk_Like_a_Man_(The_Four_Seasons_song)'],
#   '25': ['Mockingbird',
#    'Inez and Charlie Foxx',
#    '',
#    '/wiki/Mockingbird_(Inez_%26_Charlie_Foxx_song)'],
#   '26': ['I Will Follow Him',
#    'Little Peggy March',
#    '',
#    '/wiki/I_Will_Follow_Him'],
#   '27': ['Pipeline', 'The Chantays', '', '/wiki/Pipeline_(instrumental)'],
#   '28': ['Surf City', 'Jan and Dean', '', '/wiki/Surf_City_(song)'],
#   '29': ["It's My Party",
#    'Lesley Gore',
#    '',
#    '/wiki/It%27s_My_Party_(Lesley_Gore_song)'],
#   '30': ['Blame It on the Bossa Nova',
#    'Eydie Gormé',
#    '',
#    '/wiki/Blame_It_on_the_Bossa_Nova'],
#   '31': ["You Can't Sit Down",
#    'The Dovells',
#    '',
#    '/wiki/You_Can%27t_Sit_Down'],
#   '32': ['Heat Wave',
#    'Martha and the Vandellas',
#    '',
#    '/wiki/Heat_Wave_(Martha_and_the_Vandellas_song)'],
#   '33': ['Denise', 'Randy & the Rainbows', '', '/wiki/Denise_(song)'],
#   '34': ['Walk Right In', 'The Rooftop Singers', '', '/wiki/Walk_Right_In'],
#   '35': ['If You Wanna Be Happy',
#    'Jimmy Soul',
#    '',
#    '/wiki/If_You_Wanna_Be_Happy'],
#   '36': ['Surfer Girl', 'The Beach Boys', '', '/wiki/Surfer_Girl_(song)'],
#   '37': ['If I Had a Hammer', 'Trini Lopez', '', '/wiki/If_I_Had_a_Hammer'],
#   '38': ['Everybody', 'Tommy Roe', '', '/wiki/Everybody_(Tommy_Roe_song)'],
#   '39': ['Easier Said Than Done',
#    'The Essex',
#    '',
#    '/wiki/Easier_Said_Than_Done'],
#   '40': ['Ruby Baby', 'Dion', '', '/wiki/Ruby_Baby'],
#   '41': ['Maria Elena',
#    'Los Indios Tabajaras',
#    '',
#    '/wiki/Mar%C3%ADa_Elena_(song)'],
#   '42': ['Our Day Will Come',
#    'Ruby & the Romantics',
#    '',
#    '/wiki/Our_Day_Will_Come'],
#   '43': ["I Can't Stay Mad at You",
#    'Skeeter Davis',
#    '',
#    '/wiki/I_Can%27t_Stay_Mad_at_You'],
#   '44': ['Hello Stranger', 'Barbara Lewis', '', '/wiki/Hello_Stranger'],
#   '45': ['Be My Baby', 'The Ronettes', '', '/wiki/Be_My_Baby'],
#   '46': ['Mean Woman Blues', 'Roy Orbison', '', '/wiki/Mean_Woman_Blues'],
#   '47': ['South Street', 'The Orlons', '', '/wiki/South_Street_(song)'],
#   '48': ['Days of Wine and Roses',
#    'Henry Mancini',
#    '',
#    '/wiki/Days_of_Wine_and_Roses_(song)'],
#   '49': ['The Monkey Time', 'Major Lance', '', '/wiki/The_Monkey_Time'],
#   '50': ['Candy Girl',
#    'The Four Seasons',
#    '',
#    '/wiki/Candy_Girl_(The_Four_Seasons_song)'],
#   '51': ['Still', 'Bill Anderson', '', '/wiki/Still_(Bill_Anderson_song)'],
#   '52': ['Blue on Blue', 'Bobby Vinton', '', '/wiki/Blue_on_Blue_(song)'],
#   '53': ['Cry Baby', 'Garnet Mimms', '', '/wiki/Cry_Baby_(Garnet_Mimms_song)'],
#   '54': ['Two Faces Have I', 'Lou Christie', '', '/wiki/Two_Faces_Have_I'],
#   '55': ['Busted', 'Ray Charles', '', '/wiki/Busted_(Johnny_Cash_song)'],
#   '56': ['Da Doo Ron Ron', 'The Crystals', '', '/wiki/Da_Doo_Ron_Ron'],
#   '57': ['Foolish Little Girl',
#    'The Shirelles',
#    '',
#    '/wiki/Foolish_Little_Girl_(song)'],
#   '58': ['Memphis', 'Lonnie Mack', '', '/wiki/Memphis,_Tennessee_(song)'],
#   '59': ['In Dreams', 'Roy Orbison', '', '/wiki/In_Dreams_(Roy_Orbison_song)'],
#   '60': ['More', 'Kai Winding', '', '/wiki/More_(Mondo_Cane_theme)'],
#   '61': ['Fools Rush In',
#    'Rick Nelson',
#    '',
#    '/wiki/Fools_Rush_In_(Where_Angels_Fear_to_Tread)'],
#   '62': ['Losing You', 'Brenda Lee', '', '/wiki/Losing_You_(Brenda_Lee_song)'],
#   '63': ['Our Winter Love', 'Bill Pursell', '', '/wiki/Our_Winter_Love'],
#   '64': ['I Wanna Be Around', 'Tony Bennett', '', '/wiki/I_Wanna_Be_Around'],
#   '65': ["You've Really Got a Hold on Me",
#    'The Miracles',
#    '',
#    '/wiki/You%27ve_Really_Got_a_Hold_on_Me'],
#   '66': ["Sally Go 'Round the Roses",
#    'The Jaynetts',
#    '',
#    '/wiki/Sally_Go_%27Round_the_Roses'],
#   '67': ['Little Red Rooster', 'Sam Cooke', '', '/wiki/Little_Red_Rooster'],
#   '68': ['Then He Kissed Me', 'The Crystals', '', '/wiki/Then_He_Kissed_Me'],
#   '69': ["(You're the) Devil in Disguise",
#    'Elvis Presley',
#    '',
#    '/wiki/(You%27re_the)_Devil_in_Disguise'],
#   '70': ['Those Lazy-Hazy-Crazy Days of Summer',
#    'Nat King Cole',
#    '',
#    '/wiki/Those_Lazy-Hazy-Crazy_Days_of_Summer_(song)'],
#   '71': ['Baby Workout', 'Jackie Wilson', '', '/wiki/Baby_Workout'],
#   '72': ['Pride and Joy',
#    'Marvin Gaye',
#    '',
#    '/wiki/Pride_and_Joy_(Marvin_Gaye_song)'],
#   '73': ['Walking the Dog', 'Rufus Thomas', '', '/wiki/Walking_the_Dog'],
#   '74': ['From a Jack to a King',
#    'Ned Miller',
#    '',
#    '/wiki/From_a_Jack_to_a_King'],
#   '75': ['Up on the Roof', 'The Drifters', '', '/wiki/Up_on_the_Roof_(song)'],
#   '76': ['What Will Mary Say',
#    'Johnny Mathis',
#    '',
#    '/wiki/What_Will_Mary_Say'],
#   '77': ["Mama Didn't Lie", 'Jan Bradley', '', ''],
#   '78': ['The Night Has a Thousand Eyes',
#    'Bobby Vee',
#    '',
#    '/wiki/The_Night_Has_a_Thousand_Eyes_(song)'],
#   '79': ["Don't Say Nothin' Bad (About My Baby)",
#    'The Cookies',
#    '',
#    '/wiki/Don%27t_Say_Nothin%27_Bad_(About_My_Baby)'],
#   '80': ['Ring of Fire', 'Johnny Cash', '', '/wiki/Ring_of_Fire_(song)'],
#   '81': ['Just One Look', 'Doris Troy', '', '/wiki/Just_One_Look_(song)'],
#   '82': ['Hello Muddah, Hello Fadduh (A Letter from Camp)',
#    'Allan Sherman',
#    '',
#    '/wiki/Hello_Muddah,_Hello_Fadduh_(A_Letter_from_Camp)'],
#   '83': ["Judy's Turn to Cry",
#    'Lesley Gore',
#    '',
#    '/wiki/Judy%27s_Turn_to_Cry'],
#   '84': ['Tie Me Kangaroo Down, Sport',
#    'Rolf Harris',
#    '',
#    '/wiki/Tie_Me_Kangaroo_Down,_Sport'],
#   '85': ["Mickey's Monkey",
#    'The Miracles',
#    '',
#    '/wiki/Mickey%27s_Monkey_(song)'],
#   '86': ['Donna the Prima Donna', 'Dion', '', '/wiki/Donna_the_Prima_Donna'],
#   '87': ['That Sunday, That Summer',
#    'Nat King Cole',
#    '',
#    '/wiki/That_Sunday,_That_Summer'],
#   '88': ['Another Saturday Night',
#    'Sam Cooke',
#    '',
#    '/wiki/Another_Saturday_Night'],
#   '89': ['Painted, Tainted Rose', 'Al Martino', '', ''],
#   '90': ["(Down At) Papa Joe's", 'Dixie Belles', '', ''],
#   '91': ['Go Away Little Girl',
#    'Steve Lawrence',
#    '',
#    '/wiki/Go_Away_Little_Girl'],
#   '92': ['Take These Chains from My Heart',
#    'Ray Charles',
#    '',
#    '/wiki/Take_These_Chains_from_My_Heart'],
#   '93': ['Talk to Me',
#    'Sunny & the Sunglows',
#    '',
#    '/wiki/Talk_to_Me_(Joe_Seneca_song)'],
#   '94': ['Come and Get These Memories',
#    'Martha and the Vandellas',
#    '',
#    '/wiki/Come_and_Get_These_Memories'],
#   '95': ['Bossa Nova Baby', 'Elvis Presley', '', '/wiki/Bossa_Nova_Baby'],
#   '96': ['Do the Bird', 'Dee Dee Sharp', '', ''],
#   '97': ['Shut Down',
#    'The Beach Boys',
#    '',
#    '/wiki/Shut_Down_(The_Beach_Boys_song)'],
#   '98': ['One Fine Day', 'The Chiffons', '', '/wiki/One_Fine_Day_(song)'],
#   '99': ['500 Miles', 'Bobby Bare', '', '/wiki/500_Miles'],
#   '100': ['Little Town Flirt', 'Del Shannon', '', '/wiki/Little_Town_Flirt']},
#  1964: {'1': ['I Want to Hold Your Hand',
#    'The Beatles',
#    '',
#    '/wiki/I_Want_to_Hold_Your_Hand'],
#   '2': ['She Loves You', 'The Beatles', '', '/wiki/She_Loves_You'],
#   '3': ['Hello, Dolly!', 'Louis Armstrong', '', '/wiki/Hello,_Dolly!_(song)'],
#   '4': ['Oh, Pretty Woman', 'Roy Orbison', '', '/wiki/Oh,_Pretty_Woman'],
#   '5': ['I Get Around', 'The Beach Boys', '', '/wiki/I_Get_Around'],
#   '6': ['Everybody Loves Somebody',
#    'Dean Martin',
#    '',
#    '/wiki/Everybody_Loves_Somebody'],
#   '7': ['My Guy', 'Mary Wells', '', '/wiki/My_Guy'],
#   '8': ["We'll Sing in the Sunshine",
#    'Gale Garnett',
#    '',
#    '/wiki/We%27ll_Sing_in_the_Sunshine'],
#   '9': ['Last Kiss', 'J. Frank Wilson & the Cavaliers', '', '/wiki/Last_Kiss'],
#   '10': ['Where Did Our Love Go',
#    'The Supremes',
#    '',
#    '/wiki/Where_Did_Our_Love_Go'],
#   '11': ['People', 'Barbra Streisand', '', '/wiki/People_(1964_song)'],
#   '12': ['Java', 'Al Hirt', '', '/wiki/Java_(instrumental)'],
#   '13': ["A Hard Day's Night",
#    'The Beatles',
#    '',
#    '/wiki/A_Hard_Day%27s_Night_(song)'],
#   '14': ['Love Me Do', 'The Beatles', '', '/wiki/Love_Me_Do'],
#   '15': ['Do Wah Diddy Diddy', 'Manfred Mann', '', '/wiki/Do_Wah_Diddy_Diddy'],
#   '16': ['Please Please Me',
#    'The Beatles',
#    '',
#    '/wiki/Please_Please_Me_(song)'],
#   '17': ['Dancing in the Street',
#    'Martha and the Vandellas',
#    '',
#    '/wiki/Dancing_in_the_Street'],
#   '18': ['Little Children',
#    'Billy J. Kramer',
#    'The Dakotas',
#    '/wiki/Little_Children_(song)'],
#   '19': ['Love Me with All Your Heart (Cuando Calienta El Sol)',
#    'The Ray Charles Singers',
#    '',
#    '/wiki/Love_Me_with_All_Your_Heart'],
#   '20': ['Under the Boardwalk',
#    'The Drifters',
#    '',
#    '/wiki/Under_the_Boardwalk'],
#   '21': ['Chapel of Love', 'The Dixie Cups', '', '/wiki/Chapel_of_Love'],
#   '22': ['Suspicion',
#    'Terry Stafford',
#    '',
#    '/wiki/Suspicion_(Terry_Stafford_song)'],
#   '23': ['Glad All Over', 'The Dave Clark Five', '', '/wiki/Glad_All_Over'],
#   '24': ['Rag Doll',
#    'The Four Seasons',
#    '',
#    '/wiki/Rag_Doll_(The_Four_Seasons_song)'],
#   '25': ['Dawn (Go Away)', 'The Four Seasons', '', '/wiki/Dawn_(Go_Away)'],
#   '26': ['Bread and Butter',
#    'The Newbeats',
#    '',
#    '/wiki/Bread_and_Butter_(The_Newbeats_song)'],
#   '27': ['It Hurts to Be in Love',
#    'Gene Pitney',
#    '',
#    '/wiki/It_Hurts_to_Be_in_Love'],
#   '28': ["Dead Man's Curve",
#    'Jan and Dean',
#    '',
#    '/wiki/Dead_Man%27s_Curve_(song)'],
#   '29': ['Come a Little Bit Closer',
#    'Jay and the Americans',
#    '',
#    '/wiki/Come_a_Little_Bit_Closer'],
#   '30': ['A World Without Love',
#    'Peter and Gordon',
#    '',
#    '/wiki/A_World_Without_Love'],
#   '31': ['Have I the Right?',
#    'The Honeycombs',
#    '',
#    '/wiki/Have_I_the_Right%3F'],
#   '32': ["Don't Let the Rain Come Down (Crooked Little Man)",
#    'The Serendipity Singers',
#    '',
#    '/wiki/Don%27t_Let_the_Rain_Come_Down_(Crooked_Little_Man)'],
#   '33': ['Baby Love', 'The Supremes', '', '/wiki/Baby_Love'],
#   '34': ['Let It Be Me',
#    'Betty Everett',
#    'Jerry Butler',
#    '/wiki/Let_It_Be_Me_(The_Everly_Brothers_song)'],
#   '35': ["Wishin' and Hopin'",
#    'Dusty Springfield',
#    '',
#    '/wiki/Wishin%27_and_Hopin%27'],
#   '36': ["You Don't Own Me", 'Lesley Gore', '', '/wiki/You_Don%27t_Own_Me'],
#   '37': ['Walk On By', 'Dionne Warwick', '', '/wiki/Walk_On_By_(song)'],
#   '38': ['The House of the Rising Sun',
#    'The Animals',
#    '',
#    '/wiki/The_House_of_the_Rising_Sun'],
#   '39': ['G.T.O.',
#    'Ronny & the Daytonas',
#    '',
#    '/wiki/GTO_(Ronny_%26_the_Daytonas_song)'],
#   '40': ['Twist and Shout', 'The Beatles', '', '/wiki/Twist_and_Shout'],
#   '41': ['Memphis', 'Johnny Rivers', '', '/wiki/Memphis,_Tennessee_(song)'],
#   '42': ['White on White',
#    'Danny Williams',
#    '',
#    '/wiki/White_on_White_(song)'],
#   '43': ['Hey Little Cobra', 'The Rip Chords', '', '/wiki/Hey_Little_Cobra'],
#   '44': ["The Shoop Shoop Song (It's in His Kiss)",
#    'Betty Everett',
#    '',
#    '/wiki/The_Shoop_Shoop_Song_(It%27s_in_His_Kiss)'],
#   '45': ['Bits and Pieces',
#    'The Dave Clark Five',
#    '',
#    '/wiki/Bits_and_Pieces_(song)'],
# ...
#   '6': ['Adore You',
#    'Harry Styles',
#    '',
#    '/wiki/Adore_You_(Harry_Styles_song)'],
#   '7': ['Life Is Good', 'Future', 'Drake', '/wiki/Life_Is_Good_(song)'],
#   '8': ['Memories', 'Maroon 5', '', '/wiki/Memories_(Maroon_5_song)'],
#   '9': ['The Bones', 'Maren Morris', '', '/wiki/The_Bones_(song)'],
#   '10': ['Someone You Loved', 'Lewis Capaldi', '', '/wiki/Someone_You_Loved'],
#   '11': ['Say So', 'Doja Cat', '', '/wiki/Say_So'],
#   '12': ['I Hope',
#    'Gabby Barrett',
#    'Charlie Puth',
#    '/wiki/I_Hope_(Gabby_Barrett_song)'],
#   '13': ['Whats Poppin', 'Jack Harlow', 'Tory Lanez', '/wiki/Whats_Poppin'],
#   '14': ['Dance Monkey', 'Tones and I', '', '/wiki/Dance_Monkey'],
#   '15': ['Savage',
#    'Megan Thee Stallion',
#    'Beyoncé',
#    '/wiki/Savage_(Megan_Thee_Stallion_song)'],
#   '16': ['Roxanne',
#    'Arizona Zervas',
#    '',
#    '/wiki/Roxanne_(Arizona_Zervas_song)'],
#   '17': ['Intentions',
#    'Justin Bieber',
#    'Quavo',
#    '/wiki/Intentions_(Justin_Bieber_song)'],
#   '18': ['Everything I Wanted',
#    'Billie Eilish',
#    '',
#    '/wiki/Everything_I_Wanted'],
#   '19': ['Roses (Imanbek Remix)',
#    'Saint Jhn',
#    '',
#    '/wiki/Roses_(Saint_Jhn_song)'],
#   '20': ['Watermelon Sugar', 'Harry Styles', '', '/wiki/Watermelon_Sugar'],
#   '21': ['Before You Go',
#    'Lewis Capaldi',
#    '',
#    '/wiki/Before_You_Go_(Lewis_Capaldi_song)'],
#   '22': ['Falling', 'Trevor Daniel', '', '/wiki/Falling_(Trevor_Daniel_song)'],
#   '23': ['10,000 Hours', 'Dan + Shay', '', '/wiki/10,000_Hours'],
#   '24': ['WAP', 'Cardi B', '', '/wiki/WAP_(song)'],
#   '25': ["Ballin'", 'Mustard', '', '/wiki/Ballin%27_(Mustard_song)'],
#   '26': ['Hot Girl Bummer', 'Blackbear', '', '/wiki/Hot_Girl_Bummer'],
#   '27': ['Blueberry Faygo', 'Lil Mosey', '', '/wiki/Blueberry_Faygo'],
#   '28': ['Heartless', 'The Weeknd', '', '/wiki/Heartless_(The_Weeknd_song)'],
#   '29': ['Bop', 'DaBaby', '', '/wiki/Bop_(DaBaby_song)'],
#   '30': ['Lose You to Love Me',
#    'Selena Gomez',
#    '',
#    '/wiki/Lose_You_to_Love_Me'],
#   '31': ['Good as Hell', 'Lizzo', '', '/wiki/Good_as_Hell'],
#   '32': ['Toosie Slide', 'Drake', '', '/wiki/Toosie_Slide'],
#   '33': ['Break My Heart',
#    'Dua Lipa',
#    '',
#    '/wiki/Break_My_Heart_(Dua_Lipa_song)'],
#   '34': ["Chasin' You", 'Morgan Wallen', '', '/wiki/Chasin%27_You'],
#   '35': ['Savage Love (Laxed – Siren Beat)',
#    'Jawsh 685',
#    'Jason Derulo',
#    '/wiki/Savage_Love_(Laxed_%E2%80%93_Siren_Beat)'],
#   '36': ['No Guidance', 'Chris Brown', '', '/wiki/No_Guidance'],
#   '37': ['My Oh My',
#    'Camila Cabello',
#    '',
#    '/wiki/My_Oh_My_(Camila_Cabello_song)'],
#   '38': ['Dynamite', 'BTS', '', '/wiki/Dynamite_(BTS_song)'],
#   '39': ['Go Crazy',
#    'Young Thug',
#    '',
#    '/wiki/Go_Crazy_(Chris_Brown_and_Young_Thug_song)'],
#   '40': ['High Fashion',
#    'Roddy Ricch featuring Mustard',
#    '',
#    '/wiki/High_Fashion_(song)'],
#   '41': ['Laugh Now Cry Later', 'Lil Durk', '', '/wiki/Laugh_Now_Cry_Later'],
#   '42': ['Woah', 'Lil Baby', '', '/wiki/Woah_(Lil_Baby_song)'],
#   '43': ['Death Bed',
#    'Powfu',
#    'Beabadoobee',
#    '/wiki/Death_Bed_(Coffee_for_Your_Head)'],
#   '44': ['Señorita',
#    'Shawn Mendes',
#    'Camila Cabello',
#    '/wiki/Se%C3%B1orita_(Shawn_Mendes_and_Camila_Cabello_song)'],
#   '45': ['Highest in the Room',
#    'Travis Scott',
#    '',
#    '/wiki/Highest_in_the_Room'],
#   '46': ['Bad Guy', 'Billie Eilish', '', '/wiki/Bad_Guy_(Billie_Eilish_song)'],
#   '47': ['Mood', '24kGoldn', 'Iann Dior', '/wiki/Mood_(song)'],
#   '48': ['Rain on Me',
#    'Lady Gaga',
#    'Ariana Grande',
#    '/wiki/Rain_on_Me_(Lady_Gaga_and_Ariana_Grande_song)'],
#   '49': ['For the Night', 'Pop Smoke', '', '/wiki/For_the_Night'],
#   '50': ['Ritmo (Bad Boys for Life)',
#    'Black Eyed Peas',
#    'J Balvin',
#    '/wiki/Ritmo_(Bad_Boys_for_Life)'],
#   '51': ['Heart on Ice', 'Rod Wave', '', '/wiki/Heart_on_Ice'],
#   '52': ['Nobody but You',
#    'Blake Shelton',
#    'Gwen Stefani',
#    '/wiki/Nobody_but_You_(Blake_Shelton_and_Gwen_Stefani_song)'],
#   '53': ['Trampoline', 'Shaed', '', '/wiki/Trampoline_(Shaed_song)'],
#   '54': ['Come & Go',
#    'Juice Wrld',
#    'Marshmello',
#    '/wiki/Come_%26_Go_(Juice_Wrld_and_Marshmello_song)'],
#   '55': ['Truth Hurts', 'Lizzo', '', '/wiki/Truth_Hurts_(song)'],
#   '56': ['If the World Was Ending',
#    'JP Saxe',
#    'Julia Michaels',
#    '/wiki/If_the_World_Was_Ending'],
#   '57': ['We Paid', '42 Dugg', '', '/wiki/We_Paid'],
#   '58': ['Yummy', 'Justin Bieber', '', '/wiki/Yummy_(Justin_Bieber_song)'],
#   '59': ['One Man Band',
#    'Old Dominion',
#    '',
#    '/wiki/One_Man_Band_(Old_Dominion_song)'],
#   '60': ['Got What I Got', 'Jason Aldean', '', '/wiki/Got_What_I_Got'],
#   '61': ['Sunday Best', 'Surfaces', '', '/wiki/Sunday_Best_(Surfaces_song)'],
#   '62': ['Godzilla', 'Eminem', '', '/wiki/Godzilla_(Eminem_song)'],
#   '63': ['Bandit', 'YoungBoy Never Broke Again', '', '/wiki/Bandit_(song)'],
#   '64': ['Party Girl',
#    'StaySolidRocky',
#    '',
#    '/wiki/Party_Girl_(StaySolidRocky_song)'],
#   '65': ['Die from a Broken Heart',
#    'Maddie & Tae',
#    '',
#    '/wiki/Die_from_a_Broken_Heart'],
#   '66': ['Popstar', 'DJ Khaled', '', '/wiki/Popstar_(DJ_Khaled_song)'],
#   '67': ['All I Want for Christmas Is You',
#    'Mariah Carey',
#    '',
#    '/wiki/All_I_Want_for_Christmas_Is_You'],
#   '68': ['One of Them Girls', 'Lee Brice', '', '/wiki/One_of_Them_Girls'],
#   '69': ['Hard to Forget', 'Sam Hunt', '', '/wiki/Hard_to_Forget'],
#   '70': ['One Margarita', 'Luke Bryan', '', '/wiki/One_Margarita'],
#   '71': ['Panini', 'Lil Nas X', '', '/wiki/Panini_(song)'],
#   '72': ['Hot', 'Young Thug', 'Gunna', '/wiki/Hot_(Young_Thug_song)'],
#   '73': ["I Hope You're Happy Now",
#    'Carly Pearce',
#    'Lee Brice',
#    '/wiki/I_Hope_You%27re_Happy_Now_(Carly_Pearce_and_Lee_Brice_song)'],
#   '74': ['Emotionally Scarred', 'Lil Baby', '', '/wiki/Emotionally_Scarred'],
#   '75': ['Suicidal', 'YNW Melly', '', '/wiki/Suicidal_(song)'],
#   '76': ['The Bigger Picture',
#    'Lil Baby',
#    '',
#    '/wiki/The_Bigger_Picture_(song)'],
#   '77': ['Only Human',
#    'Jonas Brothers',
#    '',
#    '/wiki/Only_Human_(Jonas_Brothers_song)'],
#   '78': ['The Woo', '50 Cent', '', '/wiki/The_Woo'],
#   '79': ['Sum 2 Prove', 'Lil Baby', '', '/wiki/Sum_2_Prove'],
#   '80': ['Stuck with U',
#    'Ariana Grande and Justin Bieber',
#    '',
#    '/wiki/Stuck_with_U'],
#   '81': ['Mood Swings', 'Lil Tjay', '', '/wiki/Mood_Swings_(Pop_Smoke_song)'],
#   '82': ['You Should Be Sad', 'Halsey', '', '/wiki/You_Should_Be_Sad'],
#   '83': ['Dior', 'Pop Smoke', '', '/wiki/Dior_(song)'],
#   '84': ['Supalonely', 'Benee', 'Gus Dapperton', '/wiki/Supalonely'],
#   '85': ["Even Though I'm Leaving",
#    'Luke Combs',
#    '',
#    '/wiki/Even_Though_I%27m_Leaving'],
#   '86': ['The Scotts', 'Kid Cudi', '', '/wiki/The_Scotts'],
#   '87': ['Juicy', 'Tyga', '', '/wiki/Juicy_(Doja_Cat_song)'],
#   '88': ['Be Like That',
#    'Kane Brown',
#    'Swae Lee',
#    '/wiki/Be_Like_That_(Kane_Brown,_Swae_Lee_and_Khalid_song)'],
#   '89': ['Homesick', 'Kane Brown', '', '/wiki/Homesick_(Kane_Brown_song)'],
#   '90': ['Rags2Riches',
#    'Rod Wave featuring ATR Son Son',
#    '',
#    '/wiki/Rags2Riches_(song)'],
#   '91': ['Bluebird',
#    'Miranda Lambert',
#    '',
#    '/wiki/Bluebird_(Miranda_Lambert_song)'],
#   '92': ['Wishing Well',
#    'Juice Wrld',
#    '',
#    '/wiki/Wishing_Well_(Juice_Wrld_song)'],
#   '93': ['Does to Me', 'Eric Church', '', '/wiki/Does_to_Me'],
#   '94': ['Pussy Fairy (OTW)', 'Jhené Aiko', '', '/wiki/Pussy_Fairy_(OTW)'],
#   '95': ['ILY (I Love You Baby)',
#    'Surf Mesa',
#    '',
#    '/wiki/ILY_(I_Love_You_Baby)'],
#   '96': ['More Than My Hometown',
#    'Morgan Wallen',
#    '',
#    '/wiki/More_Than_My_Hometown'],
#   '97': ["Lovin' on You", 'Luke Combs', '', '/wiki/Lovin%27_on_You'],
#   '98': ['Said Sum', 'Moneybagg Yo', '', '/wiki/Said_Sum'],
#   '99': ['Slide', 'H.E.R.', 'YG', '/wiki/Slide_(H.E.R._song)'],
#   '100': ['Walk Em Down', 'NLE Choppa', '', '/wiki/Walk_Em_Down']},
#  2021: {'1': ['Levitating', 'Dua Lipa', '', '/wiki/Levitating_(song)'],
#   '2': ['Save Your Tears',
#    'The Weeknd',
#    'Ariana Grande',
#    '/wiki/Save_Your_Tears'],
#   '3': ['Blinding Lights', 'The Weeknd', '', '/wiki/Blinding_Lights'],
#   '4': ['Mood', '24kGoldn', 'Iann Dior', '/wiki/Mood_(song)'],
#   '5': ['Good 4 U', 'Olivia Rodrigo', '', '/wiki/Good_4_U'],
#   '6': ['Kiss Me More', 'Doja Cat', 'SZA', '/wiki/Kiss_Me_More'],
#   '7': ['Leave the Door Open',
#    'Silk Sonic',
#    'Bruno Mars',
#    '/wiki/Leave_the_Door_Open'],
#   '8': ['Drivers License',
#    'Olivia Rodrigo',
#    '',
#    '/wiki/Drivers_License_(song)'],
#   '9': ['Montero (Call Me by Your Name)',
#    'Lil Nas X',
#    '',
#    '/wiki/Montero_(Call_Me_by_Your_Name)'],
#   '10': ['Peaches',
#    'Justin Bieber',
#    'Daniel Caesar',
#    '/wiki/Peaches_(Justin_Bieber_song)'],
#   '11': ['Butter', 'BTS', '', '/wiki/Butter_(song)'],
#   '12': ['Stay',
#    'The Kid Laroi',
#    '',
#    '/wiki/Stay_(The_Kid_Laroi_and_Justin_Bieber_song)'],
#   '13': ['Deja Vu',
#    'Olivia Rodrigo',
#    '',
#    '/wiki/Deja_Vu_(Olivia_Rodrigo_song)'],
#   '14': ['Positions', 'Ariana Grande', '', '/wiki/Positions_(song)'],
#   '15': ['Bad Habits', 'Ed Sheeran', '', '/wiki/Bad_Habits_(Ed_Sheeran_song)'],
#   '16': ['Heat Waves', 'Glass Animals', '', '/wiki/Heat_Waves'],
#   '17': ['Without You',
#    'The Kid Laroi',
#    '',
#    '/wiki/Without_You_(The_Kid_Laroi_song)'],
#   '18': ['Forever After All', 'Luke Combs', '', '/wiki/Forever_After_All'],
#   '19': ['Go Crazy',
#    'Chris Brown',
#    'Young Thug',
#    '/wiki/Go_Crazy_(Chris_Brown_and_Young_Thug_song)'],
#   '20': ['Astronaut in the Ocean',
#    'Masked Wolf',
#    '',
#    '/wiki/Astronaut_in_the_Ocean'],
#   '21': ['34+35', 'Megan Thee Stallion', '', '/wiki/34%2B35'],
#   '22': ['What You Know Bout Love',
#    'Pop Smoke',
#    '',
#    '/wiki/What_You_Know_Bout_Love'],
#   '23': ["My Ex's Best Friend",
#    'Machine Gun Kelly',
#    'Blackbear',
#    '/wiki/My_Ex%27s_Best_Friend'],
#   '24': ['Industry Baby', 'Jack Harlow', '', '/wiki/Industry_Baby'],
#   '25': ['Therefore I Am',
#    'Billie Eilish',
#    '',
#    '/wiki/Therefore_I_Am_(Billie_Eilish_song)'],
#   '26': ['Up', 'Cardi B', '', '/wiki/Up_(Cardi_B_song)'],
#   '27': ['Fancy Like', 'Walker Hayes', '', '/wiki/Fancy_Like'],
#   '28': ['Dakiti', 'Bad Bunny', 'Jhay Cortez', '/wiki/Dakiti'],
#   '29': ['Best Friend', 'Saweetie', '', '/wiki/Best_Friend_(Saweetie_song)'],
#   '30': ['Rapstar', 'Polo G', '', '/wiki/Rapstar'],
#   '31': ['Heartbreak Anniversary',
#    'Giveon',
#    '',
#    '/wiki/Heartbreak_Anniversary'],
#   '32': ['For the Night', 'Lil Baby', 'DaBaby', '/wiki/For_the_Night'],
#   '33': ['Calling My Phone', 'Lil Tjay', '6lack', '/wiki/Calling_My_Phone'],
#   '34': ['Beautiful Mistakes', 'Maroon 5', '', '/wiki/Beautiful_Mistakes'],
#   '35': ['Holy', 'Chance the Rapper', '', '/wiki/Holy_(Justin_Bieber_song)'],
#   '36': ['On Me', 'Lil Baby', '', '/wiki/On_Me_(Lil_Baby_song)'],
#   '37': ['You Broke Me First', 'Tate McRae', '', '/wiki/You_Broke_Me_First'],
#   '38': ['Traitor', 'Olivia Rodrigo', '', '/wiki/Traitor_(song)'],
#   '39': ['Back in Blood',
#    'Pooh Shiesty',
#    'Lil Durk',
#    '/wiki/Back_in_Blood_(song)'],
#   '40': ['I Hope',
#    'Gabby Barrett',
#    'Charlie Puth',
#    '/wiki/I_Hope_(Gabby_Barrett_song)'],
#   '41': ['Dynamite', 'BTS', '', '/wiki/Dynamite_(BTS_song)'],
#   '42': ['Wockesha', 'Moneybagg Yo', '', '/wiki/Wockesha'],
#   '43': ['You Right', 'Doja Cat and the Weeknd', '', '/wiki/You_Right'],
#   '44': ['Beat Box', 'SpotemGottem', '', '/wiki/Beat_Box_(SpotemGottem_song)'],
#   '45': ['Laugh Now Cry Later', 'Drake', '', '/wiki/Laugh_Now_Cry_Later'],
#   '46': ['Need to Know', 'Doja Cat', '', '/wiki/Need_to_Know_(Doja_Cat_song)'],
#   '47': ['Wants and Needs',
#    'Drake featuring Lil Baby',
#    '',
#    '/wiki/Wants_and_Needs'],
#   '48': ['Way 2 Sexy', 'Future', '', '/wiki/Way_2_Sexy'],
#   '49': ['Telepatía', 'Kali Uchis', '', '/wiki/Telepat%C3%ADa'],
#   '50': ['Whoopty', 'CJ', '', '/wiki/Whoopty'],
#   '51': ['Lemonade',
#    'Internet Money',
#    'Gunna',
#    '/wiki/Lemonade_(Internet_Money_and_Gunna_song)'],
#   '52': ['Good Days', 'SZA', '', '/wiki/Good_Days'],
#   '53': ['Starting Over',
#    'Chris Stapleton',
#    '',
#    '/wiki/Starting_Over_(Chris_Stapleton_song)'],
#   '54': ['Body',
#    'Megan Thee Stallion',
#    '',
#    '/wiki/Body_(Megan_Thee_Stallion_song)'],
#   '55': ['Willow', 'Taylor Swift', '', '/wiki/Willow_(song)'],
#   '56': ['Bang!', 'AJR', '', '/wiki/Bang!_(AJR_song)'],
#   '57': ['Better Together',
#    'Luke Combs',
#    '',
#    '/wiki/Better_Together_(Luke_Combs_song)'],
#   '58': ["You're Mines Still", 'Yung Bleu', '', '/wiki/You%27re_Mines_Still'],
#   '59': ['Every Chance I Get',
#    'DJ Khaled',
#    '',
#    '/wiki/Every_Chance_I_Get_(song)'],
#   '60': ['Essence', 'Wizkid', 'Tems', '/wiki/Essence_(song)'],
#   '61': ['Chasing After You',
#    'Ryan Hurd',
#    'Maren Morris',
#    '/wiki/Chasing_After_You'],
#   '62': ['The Good Ones',
#    'Gabby Barrett',
#    '',
#    '/wiki/The_Good_Ones_(Gabby_Barrett_song)'],
#   '63': ['Leave Before You Love Me',
#    'Marshmello',
#    'Jonas Brothers',
#    '/wiki/Leave_Before_You_Love_Me'],
#   '64': ['Glad You Exist', 'Dan + Shay', '', '/wiki/Glad_You_Exist'],
#   '65': ['Lonely',
#    'Benny Blanco',
#    '',
#    '/wiki/Lonely_(Justin_Bieber_and_Benny_Blanco_song)'],
#   '66': ["Beggin'", 'Måneskin', '', '/wiki/Beggin%27#Måneskin_version'],
#   '67': ['Streets', 'Doja Cat', '', '/wiki/Streets_(song)'],
#   '68': ["What's Next", 'Drake', '', '/wiki/What%27s_Next_(Drake_song)'],
#   '69': ['Famous Friends',
#    'Chris Young',
#    'Kane Brown',
#    '/wiki/Famous_Friends'],
#   '70': ['Lil Bit', 'Nelly', 'Florida Georgia Line', '/wiki/Lil_Bit'],
#   '71': ['Thot Shit', 'Megan Thee Stallion', '', '/wiki/Thot_Shit'],
#   '72': ['Late at Night',
#    'Roddy Ricch',
#    '',
#    '/wiki/Late_at_Night_(Roddy_Ricch_song)'],
#   '73': ['Kings & Queens',
#    'Ava Max',
#    '',
#    '/wiki/Kings_%26_Queens_(Ava_Max_song)'],
#   '74': ['Anyone', 'Justin Bieber', '', '/wiki/Anyone_(Justin_Bieber_song)'],
#   '75': ['Track Star', 'Mooski', '', '/wiki/Track_Star_(song)'],
#   '76': ['Time Today', 'Moneybagg Yo', '', '/wiki/Time_Today'],
#   '77': ['Cry Baby',
#    'Megan Thee Stallion featuring DaBaby',
#    '',
#    '/wiki/Cry_Baby_(Megan_Thee_Stallion_song)'],
#   '78': ['All I Want for Christmas Is You',
#    'Mariah Carey',
#    '',
#    '/wiki/All_I_Want_for_Christmas_Is_You'],
#   '79': ['No More Parties', 'Coi Leray', '', '/wiki/No_More_Parties'],
#   '80': ["What's Your Country Song",
#    'Thomas Rhett',
#    '',
#    '/wiki/What%27s_Your_Country_Song'],
#   '81': ['One Too Many', 'Keith Urban', 'Pink', '/wiki/One_Too_Many_(song)'],
#   '82': ['Arcade', 'Duncan Laurence', '', '/wiki/Arcade_(song)'],
#   '83': ['Yonaguni', 'Bad Bunny', '', '/wiki/Yonaguni_(song)'],
#   '84': ['Good Time', 'Niko Moon', '', '/wiki/Good_Time_(Niko_Moon_song)'],
#   '85': ["If I Didn't Love You",
#    'Jason Aldean',
#    'Carrie Underwood',
#    '/wiki/If_I_Didn%27t_Love_You_(Jason_Aldean_and_Carrie_Underwood_song)'],
#   '86': ['Knife Talk', '21 Savage', 'Project Pat', '/wiki/Knife_Talk'],
#   '87': ['POV', 'Ariana Grande', '', '/wiki/POV_(song)'],
#   '88': ['Just the Way', 'Parmalee', 'Blanco Brown', '/wiki/Just_the_Way'],
#   '89': ['Take My Breath', 'The Weeknd', '', '/wiki/Take_My_Breath'],
#   '90': ["We're Good", 'Dua Lipa', '', '/wiki/We%27re_Good'],
#   '91': ['Hell of a View', 'Eric Church', '', '/wiki/Hell_of_a_View'],
#   '92': ["Rockin' Around the Christmas Tree",
#    'Brenda Lee',
#    '',
#    '/wiki/Rockin%27_Around_the_Christmas_Tree'],
#   '93': ['Put Your Records On',
#    'Ritt Momney',
#    '',
#    '/wiki/Put_Your_Records_On#Ritt_Momney_version'],
#   '94': ['Happier Than Ever',
#    'Billie Eilish',
#    '',
#    '/wiki/Happier_Than_Ever_(song)'],
#   '95': ['Single Saturday Night',
#    'Cole Swindell',
#    '',
#    '/wiki/Single_Saturday_Night'],
#   '96': ['Things a Man Oughta Know',
#    'Lainey Wilson',
#    '',
#    '/wiki/Things_a_Man_Oughta_Know'],
#   '97': ['Throat Baby (Go Baby)',
#    'BRS Kash',
#    '',
#    '/wiki/Throat_Baby_(Go_Baby)'],
#   '98': ['Tombstone', 'Rod Wave', '', '/wiki/Tombstone_(song)'],
#   '99': ["Drinkin' Beer. Talkin' God. Amen.",
#    'Chase Rice',
#    'Florida Georgia Line',
#    '/wiki/Drinkin%27_Beer._Talkin%27_God._Amen.'],
#   '100': ['Todo de Ti', 'Rauw Alejandro', '', '/wiki/Todo_de_Ti']}}

# %% [markdown]
# ## Turn it into a dataframe

# %%
import pandas as pd

def make_data_into_dataframe(billboard_data):
    data_list = []
    for year, value in billboard_data.items():
        for place, song in value.items():
            list_song = [year, place, song[0], song[1], song[2], song[3]]
            data_list.append(list_song)
    return pd.DataFrame(data_list, columns=['Year', 'Place', 'Title', 'Artist', 'Featuring','Title_url'])
   
df_to_csv = make_data_into_dataframe(billboard_data)
df_to_csv
# Out:
#       Year Place                              Title          Artist  \
# 0     1959     1          The Battle of New Orleans   Johnny Horton
# 1     1959     2                     Mack the Knife     Bobby Darin
# 2     1959     3                        Personality     Lloyd Price
# 3     1959     4                              Venus  Frankie Avalon
# 4     1959     5                         Lonely Boy       Paul Anka
# ...    ...   ...                                ...             ...
# 6296  2021    96           Things a Man Oughta Know   Lainey Wilson
# 6297  2021    97              Throat Baby (Go Baby)        BRS Kash
# 6298  2021    98                          Tombstone        Rod Wave
# 6299  2021    99  Drinkin' Beer. Talkin' God. Amen.      Chase Rice
# 6300  2021   100                         Todo de Ti  Rauw Alejandro
#
#                  Featuring                                    Title_url
# 0                                       /wiki/The_Battle_of_New_Orleans
# 1                                                  /wiki/Mack_the_Knife
# 2                                  /wiki/Personality_(Lloyd_Price_song)
# 3                                     /wiki/Venus_(Frankie_Avalon_song)
# 4                                     /wiki/Lonely_Boy_(Paul_Anka_song)
# ...                    ...                                          ...
# 6296                                     /wiki/Things_a_Man_Oughta_Know
# 6297                                        /wiki/Throat_Baby_(Go_Baby)
# 6298                                             /wiki/Tombstone_(song)
# 6299  Florida Georgia Line  /wiki/Drinkin%27_Beer._Talkin%27_God._Amen.
# 6300                                                   /wiki/Todo_de_Ti
#
# [6301 rows x 6 columns]

# %% [markdown]
# ## Save as CSV. So i dont have to scrape it everyday..

# %%
#df_to_csv = pd.DataFrame.from_dict(billboard_data) 
df_to_csv.to_csv ('data/raw_top100_1959_2021.csv', index = False, header=True)

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
df = pd.read_csv('data/raw_top100_1959_2021.csv' )
df
# Out:
#       Year Place                              Title          Artist  \
# 0     1959     1          The Battle of New Orleans   Johnny Horton
# 1     1959     2                     Mack the Knife     Bobby Darin
# 2     1959     3                        Personality     Lloyd Price
# 3     1959     4                              Venus  Frankie Avalon
# 4     1959     5                         Lonely Boy       Paul Anka
# ...    ...   ...                                ...             ...
# 6296  2021    96           Things a Man Oughta Know   Lainey Wilson
# 6297  2021    97              Throat Baby (Go Baby)        BRS Kash
# 6298  2021    98                          Tombstone        Rod Wave
# 6299  2021    99  Drinkin' Beer. Talkin' God. Amen.      Chase Rice
# 6300  2021   100                         Todo de Ti  Rauw Alejandro
#
#                  Featuring                                    Title_url
# 0                      NaN              /wiki/The_Battle_of_New_Orleans
# 1                      NaN                         /wiki/Mack_the_Knife
# 2                      NaN         /wiki/Personality_(Lloyd_Price_song)
# 3                      NaN            /wiki/Venus_(Frankie_Avalon_song)
# 4                      NaN            /wiki/Lonely_Boy_(Paul_Anka_song)
# ...                    ...                                          ...
# 6296                   NaN               /wiki/Things_a_Man_Oughta_Know
# 6297                   NaN                  /wiki/Throat_Baby_(Go_Baby)
# 6298                   NaN                       /wiki/Tombstone_(song)
# 6299  Florida Georgia Line  /wiki/Drinkin%27_Beer._Talkin%27_God._Amen.
# 6300                   NaN                             /wiki/Todo_de_Ti
#
# [6301 rows x 6 columns]

# %% [markdown]
# ## Testing the data:

# %%
df[df['Title'] == '"Venus"']
# Out:
#       Year Place    Title          Artist                          Title_url
# 3     1959     4  "Venus"  Frankie Avalon  /wiki/Venus_(Frankie_Avalon_song)
# 1133  1970    33  "Venus"   Shocking Blue   /wiki/Venus_(Shocking_Blue_song)
# 2738  1986    38  "Venus"      Bananarama   /wiki/Venus_(Shocking_Blue_song)

# %%
df[df['Artist'] == 'The Beatles']
# Out:
#       Year Place                         Title       Artist      Featuring  \
# 500   1964     1      I Want to Hold Your Hand  The Beatles            NaN
# 501   1964     2                 She Loves You  The Beatles            NaN
# 512   1964    13            A Hard Day's Night  The Beatles            NaN
# 513   1964    14                    Love Me Do  The Beatles            NaN
# 515   1964    16              Please Please Me  The Beatles            NaN
# 539   1964    40               Twist and Shout  The Beatles            NaN
# 551   1964    52             Can't Buy Me Love  The Beatles            NaN
# 554   1964    55  Do You Want to Know a Secret  The Beatles            NaN
# 594   1964    95      I Saw Her Standing There  The Beatles            NaN
# 606   1965     7                         Help!  The Beatles            NaN
# 630   1965    31                Ticket to Ride  The Beatles            NaN
# 654   1965    55             Eight Days a Week  The Beatles            NaN
# 748   1966    49            We Can Work It Out  The Beatles            NaN
# 756   1966    57              Paperback Writer  The Beatles            NaN
# 783   1966    84                   Nowhere Man  The Beatles            NaN
# 789   1966    90              Yellow Submarine  The Beatles            NaN
# 829   1967    30          All You Need Is Love  The Beatles            NaN
# 854   1967    55                    Penny Lane  The Beatles            NaN
# 900   1968     1                      Hey Jude  The Beatles            NaN
# 959   1968    60                  Lady Madonna  The Beatles            NaN
# 977   1968    78                    Revolution  The Beatles            NaN
# 1024  1969    25                      Get Back  The Beatles  Billy Preston
# 1082  1969    83                     Something  The Beatles            NaN
# 1084  1969    85                 Come Together  The Beatles            NaN
# 1109  1970     9                     Let It Be  The Beatles            NaN
# 1141  1970    41     The Long and Winding Road  The Beatles            NaN
# 1778  1976    78   Got to Get You into My Life  The Beatles            NaN
#
#                                Title_url
# 500       /wiki/I_Want_to_Hold_Your_Hand
# 501                  /wiki/She_Loves_You
# 512    /wiki/A_Hard_Day%27s_Night_(song)
# 513                     /wiki/Love_Me_Do
# 515        /wiki/Please_Please_Me_(song)
# 539                /wiki/Twist_and_Shout
# 551            /wiki/Can%27t_Buy_Me_Love
# 554   /wiki/Do_You_Want_to_Know_a_Secret
# 594       /wiki/I_Saw_Her_Standing_There
# 606                   /wiki/Help!_(song)
# 630          /wiki/Ticket_to_Ride_(song)
# 654              /wiki/Eight_Days_a_Week
# 748             /wiki/We_Can_Work_It_Out
# 756               /wiki/Paperback_Writer
# 783             /wiki/Nowhere_Man_(song)
# 789        /wiki/Yellow_Submarine_(song)
# 829           /wiki/All_You_Need_Is_Love
# 854                     /wiki/Penny_Lane
# 900                       /wiki/Hey_Jude
# 959                   /wiki/Lady_Madonna
# 977      /wiki/Revolution_(Beatles_song)
# 1024                      /wiki/Get_Back
# 1082      /wiki/Something_(Beatles_song)
# 1084                 /wiki/Come_Together
# 1109      /wiki/Let_It_Be_(Beatles_song)
# 1141     /wiki/The_Long_and_Winding_Road
# 1778   /wiki/Got_to_Get_You_into_My_Life

# %% [markdown]
# #### Issue with songs with featuring artists. Need to refactor the code:

# %%
# How many songs have a featurin artist for the song:
print("Featuring artists: ",df['Artist'].str.contains('featuring').sum())
print("AND in the name: ",df['Artist'].str.contains('and').sum()) # OBS.: This could also be Andrew, Andy etc.. not valid!
# Out:
# Featuring artists:  718
# AND in the name:  586

# %% [markdown]
# #### Testing featuring after refactoring the web scrapper:

# %%
# How many songs have a featurin artist for the song:
print("Featuring artists: ",df['Artist'].str.contains('featuring').sum())
print("AND in the name: ",df['Artist'].str.contains('and').sum()) # OBS.: This could also be Andrew, Andy etc.. not valid!
# Out:
# Featuring artists:  4
# AND in the name:  273

# %%
df[df['Artist'].str.contains('featuring')]
# Out:
#       Year Place            Title                                Artist  \
# 6140  2020    40     High Fashion         Roddy Ricch featuring Mustard
# 6190  2020    90      Rags2Riches        Rod Wave featuring ATR Son Son
# 6247  2021    47  Wants and Needs              Drake featuring Lil Baby
# 6277  2021    77         Cry Baby  Megan Thee Stallion featuring DaBaby
#
#      Featuring                                  Title_url
# 6140       NaN                  /wiki/High_Fashion_(song)
# 6190       NaN                   /wiki/Rags2Riches_(song)
# 6247       NaN                      /wiki/Wants_and_Needs
# 6277       NaN  /wiki/Cry_Baby_(Megan_Thee_Stallion_song)

# %%
# It's usually used if there is a third featuring person/band. DRAKE featuring 21 SAVAGE and PROJECT PAT
# Might have to change the way i crawl the data!
df[df['Artist'].str.contains('and')]
# Out:
#       Year Place               Title                     Artist Featuring  \
# 24    1959    25  A Teenager in Love      Dion and the Belmonts       NaN
# 30    1959    31      Red River Rock  Johnny and the Hurricanes       NaN
# 35    1959    36           Teen Beat               Sandy Nelson       NaN
# 59    1959    60         Tell Him No             Travis and Bob       NaN
# 74    1959    75        Petite Fleur   Chris Barber's Jazz Band       NaN
# ...    ...   ...                 ...                        ...       ...
# 6191  2020    91            Bluebird            Miranda Lambert       NaN
# 6214  2021    14           Positions              Ariana Grande       NaN
# 6243  2021    43           You Right    Doja Cat and the Weeknd       NaN
# 6287  2021    87                 POV              Ariana Grande       NaN
# 6300  2021   100          Todo de Ti             Rauw Alejandro       NaN
#
#                                   Title_url
# 24                 /wiki/A_Teenager_in_Love
# 30            /wiki/Red_River_Valley_(song)
# 35                   /wiki/Teen_Beat_(song)
# 59                        /wiki/Tell_Him_No
# 74                       /wiki/Petite_Fleur
# ...                                     ...
# 6191  /wiki/Bluebird_(Miranda_Lambert_song)
# 6214                 /wiki/Positions_(song)
# 6243                        /wiki/You_Right
# 6287                       /wiki/POV_(song)
# 6300                       /wiki/Todo_de_Ti
#
# [273 rows x 6 columns]

# %%
df[df['Title'] == 'Leave the Door Open'] # This title's artist got '()' in the name....FIXED
# Out:
#       Year Place                Title      Artist   Featuring  \
# 6207  2021     7  Leave the Door Open  Silk Sonic  Bruno Mars
#
#                       Title_url
# 6207  /wiki/Leave_the_Door_Open

# %%
df[df['Title'] == 'Peaches'] # This title's artist(s) ot featuring + and in the name. FIXED
# Out:
#       Year Place    Title         Artist      Featuring  \
# 6210  2021    10  Peaches  Justin Bieber  Daniel Caesar
#
#                                Title_url
# 6210  /wiki/Peaches_(Justin_Bieber_song)

# %%
print("Number of songs: ",len(df))
print("Years: ", len(df["Year"].drop_duplicates()))
# Out:
# Number of songs:  6301
# Years:  63

# %%
# Find all the no.1 songs

df[df['Place'] == "1"]
# Out:
#       Year Place                      Title                          Artist  \
# 0     1959     1  The Battle of New Orleans                   Johnny Horton
# 100   1960     1  Theme from A Summer Place                     Percy Faith
# 200   1961     1        Tossin' and Turnin'                     Bobby Lewis
# 300   1962     1      Stranger on the Shore                      Acker Bilk
# 400   1963     1                Sugar Shack  Jimmy Gilmer and the Fireballs
# ...    ...   ...                        ...                             ...
# 5801  2017     1               Shape of You                      Ed Sheeran
# 5901  2018     1                 God's Plan                           Drake
# 6001  2019     1              Old Town Road                       Lil Nas X
# 6101  2020     1            Blinding Lights                      The Weeknd
# 6201  2021     1                 Levitating                        Dua Lipa
#
#             Featuring                        Title_url
# 0                 NaN  /wiki/The_Battle_of_New_Orleans
# 100               NaN  /wiki/Theme_from_A_Summer_Place
# 200               NaN    /wiki/Tossin%27_and_Turnin%27
# 300               NaN      /wiki/Stranger_on_the_Shore
# 400               NaN                /wiki/Sugar_Shack
# ...               ...                              ...
# 5801              NaN               /wiki/Shape_of_You
# 5901              NaN        /wiki/God%27s_Plan_(song)
# 6001  Billy Ray Cyrus              /wiki/Old_Town_Road
# 6101              NaN            /wiki/Blinding_Lights
# 6201              NaN          /wiki/Levitating_(song)
#
# [63 rows x 6 columns]

# %%
songs_without_url = df[df['Title_url'].isnull()]

# %%
# Find songs that don't have a link.
            
print(len(songs_without_url), " out of ", len(df), " Songs.",  (len(songs_without_url) / len(df))*100, "%")
songs_without_url
# Out:
# 74  out of  6301  Songs. 1.1744167592445642 %
#       Year Place                             Title                 Artist  \
# 112   1960    13                     "Greenfields"      The Brothers Four
# 139   1960    40  "Way Down Yonder in New Orleans"          Freddy Cannon
# 165   1960    66                "It's Time to Cry"              Paul Anka
# 181   1960    82                       "Lady Luck"            Lloyd Price
# 182   1960    83                    "Step by Step"             The Crests
# ...    ...   ...                               ...                    ...
# 4061  1999    61                          "If You"                   Silk
# 4081  1999    81                  "Faded Pictures"     Case featuring Joe
# 4289  2001    89                      "I'm a Thug"            Trick Daddy
# 4388  2002    88                        "Anything"  Jaheim featuring Next
# 4482  2003    82            "Put That Woman First"                 Jaheim
#
#      Title_url
# 112        NaN
# 139        NaN
# 165        NaN
# 181        NaN
# 182        NaN
# ...        ...
# 4061       NaN
# 4081       NaN
# 4289       NaN
# 4388       NaN
# 4482       NaN
#
# [74 rows x 5 columns]

# %% [markdown]
# ### Notes after testing

# %%
# Notice 1986: Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder)
# Need a a clever way to break that down.
# Also 2004, 2012 (and others) have "feature" or "and". Need to be able to break down aswell 
# 74 songs wont get extra data. Which is acceptable

# %%
import pandas as pd

def make_data_into_dataframe(billboard_data):
    data_list = []
    for year, value in billboard_data.items():
        for place, song in value.items():
            list_song = [year, place, song[0], song[1], song[2]]
            data_list.append(list_song)
    return pd.DataFrame(data_list, columns=['Year', 'Place', 'Title', 'Artist', 'Title_url'])
   
df = make_data_into_dataframe(data)
df
# Out:
#       Year Place                                Title  \
# 0     1959     1          "The Battle of New Orleans"
# 1     1959     2                     "Mack the Knife"
# 2     1959     3                        "Personality"
# 3     1959     4                              "Venus"
# 4     1959     5                         "Lonely Boy"
# ...    ...   ...                                  ...
# 6296  2021    96           "Things a Man Oughta Know"
# 6297  2021    97              "Throat Baby (Go Baby)"
# 6298  2021    98                          "Tombstone"
# 6299  2021    99  "Drinkin' Beer. Talkin' God. Amen."
# 6300  2021   100                         "Todo de Ti"
#
#                                          Artist  \
# 0                                 Johnny Horton
# 1                                   Bobby Darin
# 2                                   Lloyd Price
# 3                                Frankie Avalon
# 4                                     Paul Anka
# ...                                         ...
# 6296                              Lainey Wilson
# 6297                                   BRS Kash
# 6298                                   Rod Wave
# 6299  Chase Rice featuring Florida Georgia Line
# 6300                             Rauw Alejandro
#
#                                         Title_url
# 0                 /wiki/The_Battle_of_New_Orleans
# 1                            /wiki/Mack_the_Knife
# 2            /wiki/Personality_(Lloyd_Price_song)
# 3               /wiki/Venus_(Frankie_Avalon_song)
# 4               /wiki/Lonely_Boy_(Paul_Anka_song)
# ...                                           ...
# 6296               /wiki/Things_a_Man_Oughta_Know
# 6297                  /wiki/Throat_Baby_(Go_Baby)
# 6298                       /wiki/Tombstone_(song)
# 6299  /wiki/Drinkin%27_Beer._Talkin%27_God._Amen.
# 6300                             /wiki/Todo_de_Ti
#
# [6301 rows x 5 columns]

# %% [markdown]
# ### Notes after converting:

# %%
# link for each songs lyrics
# number of words in lyrics
# (maybe) lenth of song?
# (maybe) Link for youtube video of the song

# Turn it into a csv file

# %% [markdown]
# ## Get additional data from wikipedia link

# %%
import bs4
import requests
import re


def get_additional_song_data(link):
    result_dict = dict()
    
    url = "https://en.wikipedia.org/"+link
    
    r = requests.get(url)
    r.raise_for_status()
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    # Some songs have more than one infobox. We only want the first.
    infobox = soup.select('.infobox')
    table = infobox[0].select('tbody > tr')
    
    # All the data we want to extract (Will convert it into an Object!)
    released = ""
    genres = [""]
    length = ""
    label = ""
    total_labels = ""
    writer = [""]
    youtube = ""
    
    
    for el in table:

        
        if(el.find('th')):
            th = el.select('th')
            td = el.select('td')
            if(len(td) > 0):
                #print(th[0].text, td[0].text)
                match th[0].text:
                    case "Released":
                        released =  extract_released_year(td[0])
                        #print("Released", extract_released_year(td[0]))
                    case "Genre":
                        genres = extract_genre(td[0])
                        #print("Genre:", extract_genre(td[0]))
                    case "Length":
                        length = extract_length(td[0])
                        #print("Length", extract_length(td[0]))
                    case "Label":
                        label_data = extract_label(td[0])
                        label = label_data[0]
                        total_labels = label_data[1]
                        #print("Label", extract_label(td[0]))
                    case "Songwriter(s)":
                        writer = extract_songwriter(td[0])
                        #print("Songwriter(s)", extract_songwriter(td[0]))
                        
        # Search for YT link
        if(el.find('a', {'title': 'YouTube'})):
            youtube = el.find('a', {'class': 'external'}).get('href')
            #print(el.find('a', {'class': 'external'}).get('href'))
                    
                
    return [released, genres, length, label, total_labels, writer, youtube]
    
    

def extract_released_year(element):
    """This function will return the year the song was released. But tests shows that is different scenarios. 
    1. Multiple release days, release etc., 
    2. Sometimes only the Year and Month(or Just the year), 
    
    I am using regex and split to make a list of 4 digit numbers and only returns index 0(Incase there was a rerelease later)
    """    
    years_reg = re.compile(r"\b(19|20)\d{2}\b")
        
    return [year for year in element.text.split() if re.search(years_reg, year)][0]
    
                        
def extract_genre(element):
    """This function will return a list of up to 3 genres. But tests shows that is different scenarios. 
    1. Only one Genre, 
    2. Multiple genres in an unordered list(ul), 
    3. Multiple genres with a bookmark like this. Pop[1], Rock[2].
    
    Which is handle but simple if statements.
    """
    letters_reg = re.compile(r"[a-zA-Z]")    
    
    if(element.find('ul')):
        result_list = [x.text for x in element.select('a')]
    else:
        result_list = element.text.split()
        
    return [genre for genre in result_list if re.search(letters_reg, genre)][:3]
    
    
def extract_length(element):
    """This function will return the length of the song. In some cases there is a single and an album version etc.,
    but i decided to return just the longest version. 
    1. The function splits the text elements into a list if it contains ':'.
    2. It cleans up the result for any letters or symbols(not ':' obviously).
    3. Return the max value."""

    # c = character   l = length
    lengths = ["".join([c for c in l if int(c.isnumeric()) or c == ":"]) for l in element.text.split() if ":" in l] 
    
    return max(lengths)
    
def extract_label(element):
    """This function will return only the first mentioned Label. Some singers/song change labels for whatever reason.
    Sometimes up tp two or three times. For simplicity I only return the first mentioned and the amount of different
    labels that the song have had. Maybe we can use that information for something interresting."""
    
    if(element.find('a')):
        result_list = [x.text for x in element.select('a')]
    elif(element.find('li')):
        result_list = [x.text for x in element.select('li')]
    else:
        result_list = element.text.split()
    
    # Returning originale label and the amount of different labels.
    return [[label for label in result_list][0], len(result_list)]

def extract_songwriter(element):
    """This function will return only the first mentioned songwriter. Some singers/song change labels for whatever reason.
    Sometimes up tp two or three times. For simplicity I only return the first mentioned and the amount of different
    labels that the song have had. Maybe we can use that information for something interresting."""
    
    if(element.find('a')):
        result_list = [x.text for x in element.select('a')]
        
    else:
        result_list = re.split('; |,',element.text) 
    
    # Returning originale label and the amount of different labels.
    return [writer for writer in result_list][:2]
    
    
    
get_additional_song_data("/wiki/Thrift_Shop")

# Some songs have up to 7 genres! Limit it to 3!?
# Length can be different aswell, album and single (Think i should go with the longest one)
# Multiple recording days. (Take the earliest)
# More than one label! (Like Wham - Careless whispers...)
# Song writers is often more than one. Some weird ones like Andy Gibb - shadow song:  "Barry, Robin & Maurice Gibb; Andy Gibb"
# Out:
# ['2012',
#  ['Pop-rap', 'comedy hip hop'],
#  '3:55',
#  'Macklemore LLC',
#  1,
#  ['Ben Haggerty', 'Ryan Lewis'],
#  'https://www.youtube.com/watch?v=QK8mJJJvaes']

# %%
test1 = "/wiki/The_First_Time_Ever_I_Saw_Your_Face" # 2 different lenghts + label also have a number after
test2 = "/wiki/When_Doves_Cry" # 7 different genres! And 3  dates..
test3 = "/wiki/Shadow_Dancing_(song)" # Songwriters: "Barry, Robin & Maurice Gibb; Andy Gibb"
test4 = "/wiki/Careless_Whisper" # Genre has this [1] etc + multiple labels
test5 = "/wiki/The_Way_We_Were_(song)" # No genre
test6 = "/wiki/The_Sign_(song)" # the genres prints like this: Techno-reggaepopEuropop (Make sure it's splits correctly)

get_additional_song_data(test1)
get_additional_song_data(test2)
get_additional_song_data(test3)
get_additional_song_data(test4)
get_additional_song_data(test5)
get_additional_song_data(test6)
# Out:
# Released 1972
# Genre: ['Soul', 'vocal jazz']
# Length 5:22
# Label ['Atlantic', 2]
# Songwriter(s) ['Ewan MacColl']
# Released 1984
# Genre: ['Experimental pop', 'neo-psychedelia', 'soul']
# Length 5:52
# Label ['Warner', 2]
# Songwriter(s) ['Prince']
# https://www.youtube.com/watch?v=UG3VcCAlUgE
# Released 1978
# Genre: ['Disco']
# Length 4:34
# Label ['RSO', 2]
# Songwriter(s) ['Barry, Robin & Maurice Gibb', 'Andy Gibb']
# Released 1984
# Genre: ['Pop', 'soul', 'R&B']
# Length 6:30
# Label ['Epic', 3]
# Songwriter(s) ['George Michael', 'Andrew Ridgeley']
# https://www.youtube.com/watch?v=izGwDsrQ1eQ
# Released 1973
# Length 3:29
# Label ['Columbia', 1]
# Songwriter(s) ['Alan Bergman', 'Marilyn Bergman']
# Released 1993
# Genre: ['Techno-reggae', 'pop', 'Europop']
# Length 3:08
# Label ['Arista', 2]
# Songwriter(s) ['Jonas Berggren']
# https://www.youtube.com/watch?v=iqu132vTl5Y

# %%
list123 = [['"The Battle of New Orleans"', 'Johnny Horton', '/wiki/The_Battle_of_New_Orleans']
,['"Theme from A Summer Place"', 'Percy Faith', '/wiki/Theme_from_A_Summer_Place']
,['"Tossin\' and Turnin\'"', 'Bobby Lewis', '/wiki/Tossin%27_and_Turnin%27']
,['"Stranger on the Shore"', 'Acker Bilk', '/wiki/Stranger_on_the_Shore']
,['"Sugar Shack"', 'Jimmy Gilmer and the Fireballs', '/wiki/Sugar_Shack']
,['"I Want to Hold Your Hand"', 'The Beatles', '/wiki/I_Want_to_Hold_Your_Hand']
,['"Wooly Bully"', 'Sam the Sham and the Pharaohs', '/wiki/Wooly_Bully']
,['"California Dreamin\'"', 'The Mamas & the Papas', '/wiki/California_Dreamin%27']
,['"To Sir With Love"', 'Lulu', '/wiki/To_Sir_with_Love_(song)']
,['"Hey Jude"', 'The Beatles', '/wiki/Hey_Jude']
,['"Sugar, Sugar"', 'The Archies', '/wiki/Sugar,_Sugar']
,['"Bridge Over Troubled Water"', 'Simon & Garfunkel', '/wiki/Bridge_Over_Troubled_Water_(song)']
,['"Joy to the World"', 'Three Dog Night', '/wiki/Joy_to_the_World_(Hoyt_Axton_song)']
,['"The First Time Ever I Saw Your Face"', 'Roberta Flack', '/wiki/The_First_Time_Ever_I_Saw_Your_Face']
,['"Tie a Yellow Ribbon Round the Ole Oak Tree"', 'Tony Orlando and Dawn', '/wiki/Tie_a_Yellow_Ribbon_Round_the_Ole_Oak_Tree']
,['"The Way We Were"', 'Barbra Streisand', '/wiki/The_Way_We_Were_(song)']
,['"Love Will Keep Us Together"', 'Captain & Tennille', '/wiki/Love_Will_Keep_Us_Together#Captain_&_Tennille_version']
,['"Silly Love Songs"', 'Wings', '/wiki/Silly_Love_Songs']
,['"Tonight\'s the Night (Gonna Be Alright)"', 'Rod Stewart', '/wiki/Tonight%27s_the_Night_(Gonna_Be_Alright)']
,['"Shadow Dancing"', 'Andy Gibb', '/wiki/Shadow_Dancing_(song)']
,['"My Sharona"', 'The Knack', '/wiki/My_Sharona']
,['"Call Me"', 'Blondie', '/wiki/Call_Me_(Blondie_song)']
,['"Bette Davis Eyes"', 'Kim Carnes', '/wiki/Bette_Davis_Eyes']
,['"Physical"', 'Olivia Newton-John', '/wiki/Physical_(Olivia_Newton-John_song)']
,['"Every Breath You Take"', 'The Police', '/wiki/Every_Breath_You_Take']
,['"When Doves Cry"', 'Prince', '/wiki/When_Doves_Cry']
,['"Careless Whisper"', 'Wham!', '/wiki/Careless_Whisper']
,['"That\'s What Friends Are For"', 'Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder)', '/wiki/That%27s_What_Friends_Are_For']
,['"Walk Like An Egyptian"', 'The Bangles', '/wiki/Walk_Like_An_Egyptian']
,['"Faith"', 'George Michael', '/wiki/Faith_(George_Michael_song)']
,['"Look Away"', 'Chicago', '/wiki/Look_Away']
,['"Hold On"', 'Wilson Phillips', '/wiki/Hold_On_(Wilson_Phillips_song)']
,['"(Everything I Do) I Do It for You"', 'Bryan Adams', '/wiki/(Everything_I_Do)_I_Do_It_for_You']
,['"End of the Road"', 'Boyz II Men', '/wiki/End_of_the_Road_(Boyz_II_Men_song)']
,['"I Will Always Love You"', 'Whitney Houston', '/wiki/I_Will_Always_Love_You#Whitney_Houston_version']
,['"The Sign"', 'Ace of Base', '/wiki/The_Sign_(song)']
,['"Gangsta\'s Paradise"', 'Coolio featuring L.V.', '/wiki/Gangsta%27s_Paradise']
,['"Macarena (Bayside Boys Mix)"', 'Los del Río', '/wiki/Macarena_(song)']
,['"Candle in the Wind 1997" / "Something About the Way You Look Tonight"', 'Elton John', '/wiki/Candle_in_the_Wind_1997']
,['"Too Close"', 'Next', '/wiki/Too_Close_(Next_song)']
,['"Believe"', 'Cher', '/wiki/Believe_(Cher_song)']
,['"Breathe"', 'Faith Hill', '/wiki/Breathe_(Faith_Hill_song)']
,['"Hanging by a Moment"', 'Lifehouse', '/wiki/Hanging_by_a_Moment']
,['"How You Remind Me"', 'Nickelback', '/wiki/How_You_Remind_Me']
,['"In da Club"', '50 Cent', '/wiki/In_da_Club']
,['"Yeah!"', 'Usher featuring Lil Jon and Ludacris', '/wiki/Yeah!_(Usher_song)']
,['"We Belong Together"', 'Mariah Carey', '/wiki/We_Belong_Together_(Mariah_Carey_song)']
,['"Bad Day"', 'Daniel Powter', '/wiki/Bad_Day_(Daniel_Powter_song)']
,['"Irreplaceable"', 'Beyoncé', '/wiki/Irreplaceable']
,['"Low"', 'Flo Rida featuring T-Pain', '/wiki/Low_(Flo_Rida_song)']
,['"Boom Boom Pow"', 'The Black Eyed Peas', '/wiki/Boom_Boom_Pow']
,['"Tik Tok"', 'Kesha', '/wiki/Tik_Tok_(song)']
,['"Rolling in the Deep"', 'Adele', '/wiki/Rolling_in_the_Deep']
,['"Somebody That I Used to Know"', 'Gotye featuring Kimbra', '/wiki/Somebody_That_I_Used_to_Know']
,['"Thrift Shop"', 'Macklemore & Ryan Lewis featuring Wanz', '/wiki/Thrift_Shop']
,['"Happy"', 'Pharrell Williams', '/wiki/Happy_(Pharrell_Williams_song)']
,['"Uptown Funk"', 'Mark Ronson featuring Bruno Mars', '/wiki/Uptown_Funk']
,['"Love Yourself"', 'Justin Bieber', '/wiki/Love_Yourself']
,['"Shape of You"', 'Ed Sheeran', '/wiki/Shape_of_You']
,['"God\'s Plan"', 'Drake', '/wiki/God%27s_Plan_(song)']
,['"Old Town Road"', 'Lil Nas X featuring Billy Ray Cyrus', '/wiki/Old_Town_Road']
,['"Blinding Lights"', 'The Weeknd', '/wiki/Blinding_Lights']
,['"Levitating"', 'Dua Lipa', '/wiki/Levitating_(song)']]

# %%
for song in list123:
    print("================")
    print(song[1],song[0])
    print(get_additional_song_data(song[2]))
# Out:
# ================
# Johnny Horton "The Battle of New Orleans"
# ['1959', ['Country'], '2:33', 'Columbia', 1, ['Jimmy Driftwood'], '']
# ================
# Percy Faith "Theme from A Summer Place"
# ['1959[4]', ['Easy', 'listening'], '2:25', 'Columbia Records', 1, ['Max Steiner'], 'https://www.youtube.com/watch?v=fRV0yHiEua8']
# ================
# Bobby Lewis "Tossin' and Turnin'"
# ['1961', ['R&B'], '2:29', 'Beltone', 1, ['Ritchie Adams'], '']
# ================
# Acker Bilk "Stranger on the Shore"
# ['1961', ['Easy', 'listening', 'Jazz'], '2:52', 'Columbia', 2, ['Acker Bilk', 'Robert Mellin'], '']
# ================
# Jimmy Gilmer and the Fireballs "Sugar Shack"
# ['1963', ['Garage', 'rock,', 'rock'], '2:00', 'Dot', 1, ['Keith McCormack'], '']
# ================
# The Beatles "I Want to Hold Your Hand"
# ['1963', ['Rock and roll', 'pop'], '2:24', 'Parlophone', 2, ['Lennon–McCartney'], 'https://www.youtube.com/watch?v=XT4pwRi2JmY']
# ================
# Sam the Sham and the Pharaohs "Wooly Bully"
# ['1965', ['Rock and roll', 'garage rock'], '2:20', 'MGM', 1, ['Domingo Samudio'], '']
# ================
# The Mamas & the Papas "California Dreamin'"
# ['1965', ['Sunshine pop', 'folk rock'], '2:42', 'Dunhill', 2, ['John Phillips', 'Michelle Phillips'], '']
# ================
# Lulu "To Sir With Love"
# ['1967', ['Pop'], '2:47', 'Epic', 1, [''], '']
# ================
# The Beatles "Hey Jude"
# ['1968', ['Pop', 'rock'], '7:11', 'Apple', 1, ['Lennon–McCartney'], 'https://www.youtube.com/watch?v=A_MjCqQoLLA']
# ================
# The Archies "Sugar, Sugar"
# ['1969', ['Bubblegum', 'pop[1]'], '2:48', 'Calendar', 3, ['Andy Kim', 'Jeff Barry'], 'https://www.youtube.com/watch?v=h9nE2spOw_o']
# ================
# Simon & Garfunkel "Bridge Over Troubled Water"
# ['1970', ['Pop rock', 'gospel'], '4:55', 'Columbia', 1, ['Paul Simon'], 'https://www.youtube.com/watch?v=4G-YQA_bsOU']
# ================
# Three Dog Night "Joy to the World"
# ['1971', ['Soft', 'rock[2]'], '3:40', 'Dunhill', 1, ['Hoyt Axton'], '']
# ================
# Roberta Flack "The First Time Ever I Saw Your Face"
# ['1972', ['Soul', 'vocal jazz'], '5:22', 'Atlantic', 1, ['Ewan MacColl'], '']
# ================
# Tony Orlando and Dawn "Tie a Yellow Ribbon Round the Ole Oak Tree"
# ['1973', ['Pop'], '3:20', 'Bell', 1, ['Irwin Levine', 'L. Russell Brown'], '']
# ================
# Barbra Streisand "The Way We Were"
# ['1973', [''], '3:29', 'Columbia', 1, ['Alan Bergman', 'Marilyn Bergman'], '']
# ================
# Captain & Tennille "Love Will Keep Us Together"
# ['1973', ['Pop'], '', 'MGM', 1, [''], '']
# ================
# Wings "Silly Love Songs"
# ['1976', ['Disco', 'funk'], '5:54', 'Capitol', 1, ['Paul McCartney', 'Linda McCartney'], 'https://www.youtube.com/watch?v=ap87QgZKTNw']
# ================
# Rod Stewart "Tonight's the Night (Gonna Be Alright)"
# ['1976', ['Soft', 'rock[1]'], '3:56', 'Riva', 2, ['Rod Stewart'], 'https://www.youtube.com/watch?v=IZr6AE-u2UM']
# ================
# Andy Gibb "Shadow Dancing"
# ['1978', ['Disco'], '4:34', 'RSO Records', 1, ['Barry, Robin & Maurice Gibb', 'Andy Gibb'], '']
# ================
# The Knack "My Sharona"
# ['1979', ['Power pop', 'new wave'], '4:52', 'Capitol', 1, ['Doug Fieger', 'Berton Averre'], 'https://www.youtube.com/watch?v=bbr60I0u2Ng']
# ================
# Blondie "Call Me"
# ['1980', ['Dance-rock', 'hard rock', 'new wave'], '8:05', 'Polydor', 3, ['Debbie Harry', 'Giorgio Moroder'], 'https://www.youtube.com/watch?v=StKVS0eI85I']
# ================
# Kim Carnes "Bette Davis Eyes"
# ['1981', ['New wave', 'soft rock'], '3:48', 'EMI America', 1, ['Donna Weiss', 'Jackie DeShannon'], 'https://www.youtube.com/watch?v=EPOIS5taqA8']
# ================
# Olivia Newton-John "Physical"
# ['1981', ['Pop rock', 'dance-pop', 'post-disco'], '3:44', 'EMI', 2, ['Steve Kipner'], 'https://www.youtube.com/watch?v=KDGvSZb9syw']
# ================
# The Police "Every Breath You Take"
# ['1983', ['New wave', 'soft rock'], '4:13', 'A&M', 1, ['Sting'], 'https://www.youtube.com/watch?v=OMOGaugKpzs']
# ================
# Prince "When Doves Cry"
# ['1984', ['Experimental pop', 'neo-psychedelia', 'soul'], '5:52', 'Warner Bros.', 1, ['Prince'], 'https://www.youtube.com/watch?v=UG3VcCAlUgE']
# ================
# Wham! "Careless Whisper"
# ['1984', ['Pop', 'soul', 'R&B'], '6:30', 'Epic', 3, ['George Michael', 'Andrew Ridgeley'], 'https://www.youtube.com/watch?v=izGwDsrQ1eQ']
# ================
# Dionne and Friends (Dionne Warwick, Gladys Knight, Elton John and Stevie Wonder) "That's What Friends Are For"
# ['1982', ['Pop'], '3:54', 'Warner Bros.', 1, ['Burt Bacharach', 'Carole Bayer Sager'], '']
# ================
# The Bangles "Walk Like An Egyptian"
# ['1986', ['Pop rock', 'novelty'], '3:24', 'Columbia', 2, ['Liam Sternberg'], 'https://www.youtube.com/watch?v=Cv6tuzHUuuk']
# ================
# George Michael "Faith"
# ['1987', ['Pop', 'rock and roll'], '3:16', 'Columbia', 1, ['George Michael'], 'https://www.youtube.com/watch?v=6Cs3Pvmmv0E']
# ================
# Chicago "Look Away"
# ['1988[1]', ['Rock'], '4:02', 'Full Moon', 2, ['Diane Warren'], '']
# ================
# Wilson Phillips "Hold On"
# ['1990', ['Pop,', 'pop', 'rock,'], '4:27', 'SBK', 1, ['Carnie Wilson', 'Chynna Phillips'], 'https://www.youtube.com/watch?v=uIbXvaE39wM']
# ================
# Bryan Adams "(Everything I Do) I Do It for You"
# ['1991', ['Soft rock'], '6:34', 'A&M', 1, ['Bryan Adams', 'Michael Kamen'], 'https://www.youtube.com/watch?v=Y0pdQU87dc8']
# ================
# Boyz II Men "End of the Road"
# ['1992', ['R&B'], '5:48', 'LaFace', 3, ['Kenneth "Babyface" Edmonds', 'Antonio "L.A." Reid'], 'https://www.youtube.com/watch?v=zDKO6XYXioc']
# ================
# Whitney Houston "I Will Always Love You"
# ['1974', ['Country'], '2:54', 'RCA Victor', 1, ['Dolly Parton'], 'https://www.youtube.com/watch?v=lKsQR72HY0s']
# ================
# Ace of Base "The Sign"
# ['1993', ['Techno-reggae', 'pop', 'Europop'], '3:08', 'Arista', 2, ['Jonas Berggren'], 'https://www.youtube.com/watch?v=iqu132vTl5Y']
# ================
# Coolio featuring L.V. "Gangsta's Paradise"
# ['1995', ['Hip hop', 'gangsta rap', 'G-funk'], '4:04', 'Tommy Boy', 3, [''], 'https://www.youtube.com/watch?v=fPO76Jlnz6c']
# ================
# Los del Río "Macarena (Bayside Boys Mix)"
# ['1993', ['Flamenco', 'pop'], '4:12', 'RCA', 1, ['\nRafael Ruiz Perdigones\nAntonio Romero Monge\n'], 'https://www.youtube.com/watch?v=zWaymcVmJ-A']
# ================
# Elton John "Candle in the Wind 1997" / "Something About the Way You Look Tonight"
# ['1997', ['Pop', 'rock'], '4:11', 'Rocket', 2, ['Bernie Taupin'], '']
# ================
# Next "Too Close"
# ['1998', [''], '4:20', 'Arista', 1, ['Kay Gee', ' Terry Brown'], 'https://www.youtube.com/watch?v=kwEZRPkAAu8']
# ================
# Cher "Believe"
# ['1998', ['Electropop', 'dance-pop'], '3:59', 'Warner Bros.', 1, ['Brian Higgins', 'Paul Barry'], 'https://www.youtube.com/watch?v=nZXRV4MezEw']
# ================
# Faith Hill "Breathe"
# ['1999', ['Country', 'pop'], '4:09', 'Warner Bros. Nashville', 1, ['Stephanie Bentley', 'Holly Lamar'], 'https://www.youtube.com/watch?v=yCmsZUN4r_s']
# ================
# Lifehouse "Hanging by a Moment"
# ['2000', ['Post-grunge', 'alternative rock'], '3:36', 'DreamWorks', 1, ['Jason Wade'], '']
# ================
# Nickelback "How You Remind Me"
# ['2001', ['Post-grunge', 'alternative rock', 'hard rock'], '3:43', 'Roadrunner', 1, [''], 'https://www.youtube.com/watch?v=1cQh1ccqu8M']
# ================
# 50 Cent "In da Club"
# ['2003', ['East Coast hip hop', 'gangsta rap'], '3:13', 'Aftermath', 3, ['Curtis Jackson', 'Andre Young'], 'https://www.youtube.com/watch?v=5qm8PH4xAss']
# ================
# Usher featuring Lil Jon and Ludacris "Yeah!"
# ['2004', ['Hip hop', 'crunk&B'], '4:10', 'Arista', 1, ['Christopher Bridges', 'James Phillips'], '']
# ================
# Mariah Carey "We Belong Together"
# ['2005', ['R&B'], '3:21', 'Island Def Jam', 1, ['Jermaine Dupri', 'Manuel Seal'], 'https://www.youtube.com/watch?v=0habxsuXW4g']
# ================
# Daniel Powter "Bad Day"
# ['2005', ['Pop'], '3:55', 'Warner Bros.', 1, ['Daniel Powter'], '']
# ================
# Beyoncé "Irreplaceable"
# ['2006', ['Pop', 'R&B'], '3:47', 'Columbia', 1, ['Shaffer "Ne-Yo" Smith', 'Mikkel S. Eriksen'], 'https://www.youtube.com/watch?v=2EwViQxSJJQ']
# ================
# Flo Rida featuring T-Pain "Low"
# ['2007', ['Southern hip hop', 'crunk'], '3:50', 'Atlantic', 2, ['Tramar Dillard', 'Faheem Najm'], '']
# ================
# The Black Eyed Peas "Boom Boom Pow"
# ['2009', [''], '5:08', 'Interscope', 1, ['William Adams', 'Allan Pineda'], 'https://www.youtube.com/watch?v=4m48GqaOz90']
# ================
# Kesha "Tik Tok"
# ['2009', ['Dance-pop', 'electropop'], '3:20', 'RCA', 1, ['Kesha Sebert', 'Dr. Luke'], 'https://www.youtube.com/watch?v=iP6XpLQM2Cs']
# ================
# Adele "Rolling in the Deep"
# ['2010', ['Rhythm and blues', 'soul'], '3:48', 'XL', 2, ['Adele Adkins', 'Paul Epworth'], 'https://www.youtube.com/watch?v=rYEDA3JcQqw']
# ================
# Gotye featuring Kimbra "Somebody That I Used to Know"
# ['2011', ['Art pop', 'alternative rock'], '4:04', 'Eleven', 1, ['Wally de Backer'], '']
# ================
# Macklemore & Ryan Lewis featuring Wanz "Thrift Shop"
# ['2012', ['Pop-rap', 'comedy hip hop'], '3:55', 'Macklemore LLC', 1, ['Ben Haggerty', 'Ryan Lewis'], 'https://www.youtube.com/watch?v=QK8mJJJvaes']
# ================
# Pharrell Williams "Happy"
# ['2013', ['Soul', 'neo soul'], '3:55', 'i Am Other', 2, ['Pharrell Williams'], 'https://www.youtube.com/watch?v=y6Sxv-sUYtM']
# ================
# Mark Ronson featuring Bruno Mars "Uptown Funk"
# ['2014', ['Funk', 'pop', 'soul'], '4:30', 'Columbia', 3, ['Mark Ronson', 'Bruno Mars'], 'https://www.youtube.com/watch?v=OPf0YbXqDm0']
# ================
# Justin Bieber "Love Yourself"
# ['2015', ['Pop[1][2]'], '3:53', 'Def Jam', 1, ['Justin Bieber', 'Benjamin Levin'], 'https://www.youtube.com/watch?v=oyEuk8j8imI']
# ================
# Ed Sheeran "Shape of You"
# ['2017', ['Pop', 'dancehall', 'tropical house'], '3:541', 'Asylum', 2, ['Ed Sheeran', 'Johnny McDaid'], 'https://www.youtube.com/watch?v=JGwWNGJdvx8']
# ================
# Drake "God's Plan"
# ['2018', ['Pop', 'pop-rap', 'trap'], '3:19', 'Young Money', 3, ['Aubrey Graham', 'Ronald LaTour'], 'https://www.youtube.com/watch?v=xpVfcZ0ZcFM']
# ================
# Lil Nas X featuring Billy Ray Cyrus "Old Town Road"
# ['2018', ['Country rap', 'country trap', 'pop'], '2:37', 'Columbia', 1, ['Montero Hill', 'Trent Reznor'], 'https://www.youtube.com/watch?v=w2Ov5jzm3j8']
# ================
# The Weeknd "Blinding Lights"
# ['2019', ['Synthwave', 'synth-pop', 'electropop'], '3:21', 'XO', 2, ['Abel Tesfaye', 'Ahmad Balshe'], 'https://www.youtube.com/watch?v=4NRXx6U8ABQ']
# ================
# Dua Lipa "Levitating"
# ['2020', ['Electro', 'disco', 'nu-disco'], '3:23', 'Warner', 1, ['Clarence Coffee Jr.', 'Sarah Hudson'], 'https://www.youtube.com/watch?v=N000qglmmY0']

# %% [markdown]
# ## Web scrape all the lyrics

# %% [markdown]
# ## Textblob (For the lyrics)
# - https://www.youtube.com/watch?v=ea4IadDRwuc&list=PL_92WMXSLe_-RkWW5zAQZ-gMdVqZ7T-_F&index=3
# - https://textblob.readthedocs.io/en/dev/quickstart.html

# %%
# Research more
