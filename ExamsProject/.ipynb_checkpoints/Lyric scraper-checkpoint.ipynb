# %% [markdown]
# ## Web scrape all the lyrics

# %% [markdown]
# ## Textblob (For the lyrics)
# - https://www.youtube.com/watch?v=ea4IadDRwuc&list=PL_92WMXSLe_-RkWW5zAQZ-gMdVqZ7T-_F&index=3
# - https://textblob.readthedocs.io/en/dev/quickstart.html

# %% [markdown]
# ## Load Song from the last 30 years (With additional data)

# %%
import pandas as pd

df = pd.read_csv('data/year1992_2021_test.csv')

df
# Out:
#       Year  Place                              Title            Artist  \
# 0     1992      1                    End of the Road       Boyz II Men
# 1     1992      2                      Baby Got Back     Sir Mix-a-Lot
# 2     1992      3                               Jump        Kris Kross
# 3     1992      4             Save the Best for Last  Vanessa Williams
# 4     1992      5                     Baby-Baby-Baby               TLC
# ...    ...    ...                                ...               ...
# 2995  2021     96           Things a Man Oughta Know     Lainey Wilson
# 2996  2021     97              Throat Baby (Go Baby)          BRS Kash
# 2997  2021     98                          Tombstone          Rod Wave
# 2998  2021     99  Drinkin' Beer. Talkin' God. Amen.        Chase Rice
# 2999  2021    100                         Todo de Ti    Rauw Alejandro
#
#                  Featuring                                    Title_url  \
# 0                      NaN     /wiki/End_of_the_Road_(Boyz_II_Men_song)
# 1                      NaN                          /wiki/Baby_Got_Back
# 2                      NaN                 /wiki/Jump_(Kris_Kross_song)
# 3                      NaN                 /wiki/Save_the_Best_for_Last
# 4                      NaN                         /wiki/Baby-Baby-Baby
# ...                    ...                                          ...
# 2995                   NaN               /wiki/Things_a_Man_Oughta_Know
# 2996                   NaN                  /wiki/Throat_Baby_(Go_Baby)
# 2997                   NaN                       /wiki/Tombstone_(song)
# 2998  Florida Georgia Line  /wiki/Drinkin%27_Beer._Talkin%27_God._Amen.
# 2999                   NaN                             /wiki/Todo_de_Ti
#
#       Released    Genre 1     Genre 2     Genre 3 Length         Label  \
# 0       1992.0        R&b         NaN         NaN   5:48        LaFace
# 1       1992.0    Hip hop   Dirty rap  Miami bass   4:21  Def American
# 2       1992.0    Hip hop         NaN         NaN   5:09     Ruffhouse
# 3       1992.0        Pop        Soul         NaN   3:40          Wing
# 4       1992.0        NaN         NaN         NaN   5:15        LaFace
# ...        ...        ...         ...         ...    ...           ...
# 2995    2020.0    Country         NaN         NaN   3:26    Broken Bow
# 2996    2020.0  Dirty rap         R&b         NaN   3:38          LVRN
# 2997    2021.0        NaN         NaN         NaN   2:40         Alamo
# 2998    2020.0    Country         NaN         NaN   2:40    Broken Bow
# 2999    2021.0  Dance-pop  Electropop         NaN   3:19    Sony Latin
#
#       Total Labels                    Writer 1                  Writer 2  \
# 0              3.0  Kenneth "Babyface" Edmonds       Antonio "L.A." Reid
# 1              2.0               Sir Mix-a-Lot                       NaN
# 2              2.0              Jermaine Dupri  Joe "The Butcher" Nicolo
# 3              2.0               Phil Galdston             Wendy Waldman
# 4              2.0             Kenneth Edmonds              Antonio Reid
# ...            ...                         ...                       ...
# 2995           1.0               Lainey Wilson                 Jason Nix
# 2996           2.0              Kenneth Duncan                       NaN
# 2997           1.0              Rodarius Green            Eric Foley Jr.
# 2998           2.0                  Chase Rice                Cale Dodds
# 2999           1.0   Eric "Duars" Pérez Rovira   José M. Collazo "Colla"
#
#                                           Youtube
# 0     https://www.youtube.com/watch?v=zDKO6XYXioc
# 1     https://www.youtube.com/watch?v=X53ZSxkQ3Ho
# 2     https://www.youtube.com/watch?v=010KyIQjkTk
# 3     https://www.youtube.com/watch?v=5EdmHSTwmWY
# 4                                             NaN
# ...                                           ...
# 2995  https://www.youtube.com/watch?v=ScKbhJtfuLg
# 2996  https://www.youtube.com/watch?v=fmNzZOZj3W0
# 2997  https://www.youtube.com/watch?v=wo9AlOrQ3iE
# 2998  https://www.youtube.com/watch?v=wpS2oX9ASLc
# 2999  https://www.youtube.com/watch?v=CFPLIaMpGrY
#
# [3000 rows x 16 columns]

# %% [markdown]
# # Save all the songs as text files

# %%
# Make a folder for each year
import os

try:
    for year in range(1992,2022):
        os.mkdir('data/lyrics/'+str(year))
except Exception as e:
    print(e)
# Out:
# [Errno 17] File exists: 'data/lyrics/1992'

# %%
def fetch_all_lyrics_from_df(df):
    df['Lyrics'] = df.apply(lambda row: fetch_lyric(row), axis=1)
    
    for index, row in df.iterrows():
        # Only try to save, if not null
        if(row['Lyrics'] != ""):
            save_lyrics(row['Title'], row['Artist'], row['Year'], row['Lyrics'])
    
    return df

def fetch_lyric(row):  
    title = row['Title']
    artist = row['Artist']
    
    return get_lyrics_via_search(title, artist)

def save_lyrics(title, artist, year, lyrics):
    name = underscore_title_artist(title, artist)
    try:
        with open(f'data/lyrics/{year}/{name}.txt', 'w') as f:
            f.write(lyrics)
    except FileNotFoundError:
        print("The 'docs' directory does not exist")
        
def underscore_title_artist(title, artist):
    return f'{title} {artist}'.replace(" ", "_")

# %%
def get_year(df, year): 
    df_lyrics = df[df['Year'] == year].reset_index(drop=True)
    df_lyrics = df_lyrics[['Year', 'Place', 'Title', 'Artist', 'Genre 1']]
    
    
    result = fetch_all_lyrics_from_df(df_lyrics)
    print("Songs without lyrics:", result[result['Lyrics'] == ''].shape[0])
    
    return result

# %%
get_year(df, 1993)
# Out:
# Tag Team Whoomp!   had no Result!
# Shai If I Ever Fall in Love  had no Result!
# Wreckx-n-Effect Rump Shaker  had no Result!
# Snow Informer  had no Result!
# Boyz II Men In the Still of the Nite  had no Result!
# Jade Don't Walk Away  had no Result!
# H-Town Knockin' da Boots  had no Result!
# Jodeci Lately  had no Result!
# Duice Dazzey Duks  had no Result!
# SWV I'm So Into You  had no Result!
# Exposé I'll Never Get Over You   had no Result!
# SWV Right Here   had no Result!
# Tony! Toni! Toné! If I Had No Loot  had no Result!
# P.M. Dawn Looking Through Patient Eyes  had no Result!
# Shai Baby I'm Yours  had no Result!
# P.M. Dawn I'd Die Without You  had no Result!
# 95 South Whoot, There It Is  had no Result!
# Shai Comforter  had no Result!
# Prince 7  had no Result!
# Portrait Here We Go Again!  had no Result!
# Ugly Kid Joe Cat's in the Cradle  had no Result!
# Positive K I Got a Man  had no Result!
# Zhané Hey Mr. D.J.  had no Result!
# Boy Krazy That's What Love Can Do  had no Result!
# Jon Secada Do You Believe in Us  had no Result!
# Kenny G Forever in Love  had no Result!
# Restless Heart When She Cries  had no Result!
# The Heights How Do You Talk to an Angel  had no Result!
# Kris Kross Alright  had no Result!
# Dino Ooh Child  had no Result!
# Go West Faithful  had no Result!
# Joey Lawrence Nothin' My Love Can't Fix  had no Result!
# Green Jellÿ Three Little Pigs  had no Result!
# Tony! Toni! Toné! Anniversary  had no Result!
# Jade One Woman  had no Result!
# Songs without lyrics: 35
#     Year  Place                           Title             Artist  \
# 0   1993      1          I Will Always Love You    Whitney Houston
# 1   1993      2           Whoomp! (There It Is)           Tag Team
# 2   1993      3      Can't Help Falling in Love               UB40
# 3   1993      4        That's the Way Love Goes      Janet Jackson
# 4   1993      5                        Freak Me               Silk
# ..   ...    ...                             ...                ...
# 95  1993     96  If I Ever Lose My Faith in You              Sting
# 96  1993     97                     Anniversary  Tony! Toni! Toné!
# 97  1993     98                       One Woman               Jade
# 98  1993     99   Can't Get Enough of Your Love       Taylor Dayne
# 99  1993    100                Two Steps Behind        Def Leppard
#
#        Genre 1                                             Lyrics
# 0      Country  If I  Should stay  I would only be in your way...
# 1   Miami bass
# 2          Pop  Wise men say - Only fools rush in,  But I can'...
# 3          R&b  That's the way love goes...  Ooh.. that's the ...
# 4          R&b  Freak me, baby (Ah, yeah)  Freak me, baby (Mmm...
# ..         ...                                                ...
# 95         NaN  You could say I lost my faith in science and p...
# 96         R&b
# 97         NaN
# 98        Soul  I've heard people say that Too much of anythin...
# 99         NaN  Walk away if you want to  it's ok, if you need...
#
# [100 rows x 6 columns]

# %%
fetch_all_lyrics_from_df(df_lyrics)
# Out:
# Kris Kross Jump  had no Result!
# Shanice I Love Your Smile  had no Result!
# Mariah Carey I'll Be There  had no Result!
# Tom Cochrane Life Is a Highway  had no Result!
# CeCe Peniston Finally  had no Result!
# Prince Diamonds and Pearls  had no Result!
# Atlantic Starr Masterpiece  had no Result!
# Joe Public Live and Learn  had no Result!
# Jodeci Come and Talk to Me  had no Result!
# Tevin Campbell Tell Me What You Want Me to Do  had no Result!
# Technotronic Move This  had no Result!
# Luther Vandross The Best Things in Life Are Free  had no Result!
# Hammer 2 Legit 2 Quit  had no Result!
# KWS Please Don't Go  had no Result!
# Mint Condition Breakin' My Heart   had no Result!
# The Cover Girls Wishing on a Star  had no Result!
# Hi-Five She's Playing Hard to Get  had no Result!
# P.M. Dawn I'd Die Without You  had no Result!
# The Heights How Do You Talk to an Angel  had no Result!
# CeCe Peniston Keep on Walkin'  had no Result!
# Karyn White The Way I Feel About You  had no Result!
# Kris Kross Warm It Up  had no Result!
# Marky Mark and the Funky Bunch Wildside  had no Result!
# Hammer Addams Groove  had no Result!
# N2Deep Back to the Hotel  had no Result!
# Kathy Troccoli Everything Changes  had no Result!
# Jade I Wanna Love You  had no Result!
# The KLF Justified and Ancient  had no Result!
# Keith Sweat Keep It Comin'  had no Result!
# CeCe Peniston We Got a Love Thang  had no Result!
#     Year  Place                     Title            Artist  Genre 1  \
# 0   1992      1           End of the Road       Boyz II Men      R&b
# 1   1992      2             Baby Got Back     Sir Mix-a-Lot  Hip hop
# 2   1992      3                      Jump        Kris Kross  Hip hop
# 3   1992      4    Save the Best for Last  Vanessa Williams      Pop
# 4   1992      5            Baby-Baby-Baby               TLC      NaN
# ..   ...    ...                       ...               ...      ...
# 95  1992     96       I Will Remember You         Amy Grant      Ccm
# 96  1992     97       We Got a Love Thang     CeCe Peniston    House
# 97  1992     98          Let's Get Rocked       Def Leppard      NaN
# 98  1992     99             They Want EFX           Das EFX  Hip hop
# 99  1992    100  I Can't Make You Love Me      Bonnie Raitt      Pop
#
#                                                Lyrics
# 0   Girl you know we belong together  I have no ti...
# 1   Oh, my, god. Becky, look at her butt.  It is s...
# 2
# 3   Sometimes the snow comes down in June       So...
# 4   And you want my love Well that's alright Well ...
# ..                                                ...
# 95  I will be walking one day Down a street far aw...
# 96
# 97  Do ya wanna get rocked   Let's get, let's get,...
# 98  Bum stiggedy bum stiggedy bum, hon, I got the ...
# 99  Turn down the lights, turn down the bed  Turn ...
#
# [100 rows x 6 columns]

# %% [markdown]
# # Get the last 10 years
# - Year, Place, Title, Artist, Genre 1

# %%
df_lyrics = df[df['Year'] >= 2012].reset_index(drop=True)
df_lyrics = df_lyrics[['Year', 'Place', 'Title', 'Artist', 'Genre 1']]
df_lyrics
# Out:
#      Year  Place                              Title            Artist  \
# 0    2012      1       Somebody That I Used to Know             Gotye
# 1    2012      2                      Call Me Maybe  Carly Rae Jepsen
# 2    2012      3                       We Are Young               Fun
# 3    2012      4                           Payphone          Maroon 5
# 4    2012      5                             Lights    Ellie Goulding
# ..    ...    ...                                ...               ...
# 995  2021     96           Things a Man Oughta Know     Lainey Wilson
# 996  2021     97              Throat Baby (Go Baby)          BRS Kash
# 997  2021     98                          Tombstone          Rod Wave
# 998  2021     99  Drinkin' Beer. Talkin' God. Amen.        Chase Rice
# 999  2021    100                         Todo de Ti    Rauw Alejandro
#
#           Genre 1
# 0         Art pop
# 1             Pop
# 2    Stadium rock
# 3             Pop
# 4       Synth-pop
# ..            ...
# 995       Country
# 996     Dirty rap
# 997           NaN
# 998       Country
# 999     Dance-pop
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Let's Test with a smaller subset. 1992

# %%
df_1992 = df[df['Year'] == 1992].reset_index(drop=True)
df_1992
# Out:
#     Year  Place                     Title            Artist Featuring  \
# 0   1992      1           End of the Road       Boyz II Men       NaN
# 1   1992      2             Baby Got Back     Sir Mix-a-Lot       NaN
# 2   1992      3                      Jump        Kris Kross       NaN
# 3   1992      4    Save the Best for Last  Vanessa Williams       NaN
# 4   1992      5            Baby-Baby-Baby               TLC       NaN
# ..   ...    ...                       ...               ...       ...
# 95  1992     96       I Will Remember You         Amy Grant       NaN
# 96  1992     97       We Got a Love Thang     CeCe Peniston       NaN
# 97  1992     98          Let's Get Rocked       Def Leppard       NaN
# 98  1992     99             They Want EFX           Das EFX       NaN
# 99  1992    100  I Can't Make You Love Me      Bonnie Raitt       NaN
#
#                                      Title_url  Released  Genre 1  \
# 0     /wiki/End_of_the_Road_(Boyz_II_Men_song)    1992.0      R&b
# 1                          /wiki/Baby_Got_Back    1992.0  Hip hop
# 2                 /wiki/Jump_(Kris_Kross_song)    1992.0  Hip hop
# 3                 /wiki/Save_the_Best_for_Last    1992.0      Pop
# 4                         /wiki/Baby-Baby-Baby    1992.0      NaN
# ..                                         ...       ...      ...
# 95  /wiki/I_Will_Remember_You_(Amy_Grant_song)    1992.0      Ccm
# 96                   /wiki/We_Got_a_Love_Thang    1992.0    House
# 97                    /wiki/Let%27s_Get_Rocked    1992.0      NaN
# 98                         /wiki/They_Want_EFX    1992.0  Hip hop
# 99            /wiki/I_Can%27t_Make_You_Love_Me    1991.0      Pop
#
#                Genre 2     Genre 3 Length         Label  Total Labels  \
# 0                  NaN         NaN   5:48        LaFace           3.0
# 1            Dirty rap  Miami bass   4:21  Def American           2.0
# 2                  NaN         NaN   5:09     Ruffhouse           2.0
# 3                 Soul         NaN   3:40          Wing           2.0
# 4                  NaN         NaN   5:15        LaFace           2.0
# ..                 ...         ...    ...           ...           ...
# 95                 Pop         NaN   5:06           A&M           1.0
# 96               Dance         NaN   5:29           A&M           2.0
# 97                 NaN         NaN   4:56       Mercury           1.0
# 98  East coast hip hop         NaN   3:39     East West           2.0
# 99                 NaN         NaN   5:33       Capitol           1.0
#
#                       Writer 1                  Writer 2  \
# 0   Kenneth "Babyface" Edmonds       Antonio "L.A." Reid
# 1                Sir Mix-a-Lot                       NaN
# 2               Jermaine Dupri  Joe "The Butcher" Nicolo
# 3                Phil Galdston             Wendy Waldman
# 4              Kenneth Edmonds              Antonio Reid
# ..                         ...                       ...
# 95                   Amy Grant              Gary Chapman
# 96                      Miller                McAllister
# 97                 Joe Elliott               Phil Collen
# 98                 James Brown               Fred Wesley
# 99                   Mike Reid            Allen Shamblin
#
#                                         Youtube
# 0   https://www.youtube.com/watch?v=zDKO6XYXioc
# 1   https://www.youtube.com/watch?v=X53ZSxkQ3Ho
# 2   https://www.youtube.com/watch?v=010KyIQjkTk
# 3   https://www.youtube.com/watch?v=5EdmHSTwmWY
# 4                                           NaN
# ..                                          ...
# 95  https://www.youtube.com/watch?v=W2wrtoloJ6k
# 96  https://www.youtube.com/watch?v=__ugaiz323k
# 97  https://www.youtube.com/watch?v=BO1Nae_EBvQ
# 98                                          NaN
# 99  https://www.youtube.com/watch?v=nW9Cu6GYqxo
#
# [100 rows x 16 columns]

# %%
titles_and_artists = df_1992[['Title', 'Artist']]

# %%
titles_and_artists
# Out:
#                        Title            Artist
# 0            End of the Road       Boyz II Men
# 1              Baby Got Back     Sir Mix-a-Lot
# 2                       Jump        Kris Kross
# 3     Save the Best for Last  Vanessa Williams
# 4             Baby-Baby-Baby               TLC
# ..                       ...               ...
# 95       I Will Remember You         Amy Grant
# 96       We Got a Love Thang     CeCe Peniston
# 97          Let's Get Rocked       Def Leppard
# 98             They Want EFX           Das EFX
# 99  I Can't Make You Love Me      Bonnie Raitt
#
# [100 rows x 2 columns]

# %%
test_song = "End of the Road Boyz II Men"
#test_song = "Halo beyonce"

# %%
import bs4
import requests
import re

def get_lyrics_via_search(title, artist):
    '''Searching for the lyrics via mldb.org. If there is only one clear result'''
    result = ''
    
    search_string = f'{title} {artist}'.replace(" ", "+")
    
    # For testing!
    #print("======================")
    #print(search_string)
    
    
    url =  "https://www.mldb.org/search?mq=" + search_string


    try:
        r = requests.get(url)
        r.raise_for_status()
    except Exception as e:
        print(e)
        return 'ERROR'
        
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    if(soup.select('.songtext')):
        
        songtext = soup.select('.songtext')
        
        # For testing
        #print("Single search result.")
        
        
        for line in songtext:
            result += line.text
        
    elif(soup.find(id='thelist')):
        table = soup.find(id='thelist')
        
        links = table.select('.ft > a')
        
        link = links[0].get('href')
        
        # For testing
        #print(link)
        
        result = get_lyrics_via_link(link)
    else:
        if(re.search('\(', title)):
            #print("Splitting the title!")
            new_title = title.split('(')
            result = get_lyrics_via_search(new_title[0], artist)
        else:
            print(artist, title ," had no Result!")

    
    # Some lyrics are incomplete. One song was only one verse. http://www.mldb.org/song-233265-when-i-look-into-your-eyes.html
    if(len(result) <= 500):
        result = ""
    
    return remove_line_breaks(result)
    
    

def get_lyrics_via_link(link):                   
    result = ''

    try:
        r = requests.get('https://www.mldb.org/'+link)
        r.raise_for_status()
    except Exception as e:
        print(e)
        return 'ERROR'
        
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    
    if(soup.select('.songtext')):
        
        songtext = soup.select('.songtext')
        
        for line in songtext:
            result += line.text
            
    return result

def remove_line_breaks(text):
    splitted = [x for x in text.split('\n') if '[' not in x ]
    return ' '.join(splitted)

# %%
#get_lyrics_via_search("My Lovin' (You're Never Gonna Get It)","En Vogue")

# %%
print(get_lyrics_via_search("Baby Got Back","Sir Mix-a-Lot"))
# Out:
# Oh, my, god. Becky, look at her butt.  It is so big. *scoff* She looks like,  one of those rap guys' girlfriends.  But, y'know, who understands those rap guys *scoff*  They only talk to her, because,  she looks like a total prostitute, 'kay  I mean, her butt, is just so big. *scoff*  I can't believe it's just so round, it's like,  out there, I mean - gross. Look!  She's just so ... black!  I like big butts and I can not lie You other brothers can't deny That when a girl walks in with an itty bitty waste And a round thing in your face You get sprung, wanna pull up tough 'Cause you notice that butt was stuffed Deep in the jeans she's wearing I'm hooked and I can't stop staring Oh baby, I wanna get wit'cha  And take your picture My homeboys tried to warn me But with that butt you got makes  Ooh, Rump-o'-smooth-skin You say you wanna get in my Benz Well, use me, use me  'Cause you ain't that average groupy I've seen them dancin'  The hell with romancin' She's wet, wet,  Got it goin' like a turbo 'Vette I'm tired of magazines Sayin' flat butts are the thing Take the average black man and ask him that She gotta pack much back So, fellas! (Yeah!) Fellas! (Yeah!) Has your girlfriend got the butt (Hell yeah!) Tell 'em to shake it! (Shake it!) Shake it! (Shake it!) Shake that healthy butt! Baby got back!  (LA face with Oakland booty) Baby got back!  I like 'em round, and big And when I'm throwin' a gig I just can't help myself, I'm actin' like an animal Now here's my scandal I wanna get you home And ugh, double-up, ugh, ugh I ain't talkin' bout Playboy 'Cause silicone parts are made for toys I want 'em real thick and juicy So find that juicy double Mix-a-Lot's in trouble Beggin' for a piece of that bubble So I'm lookin' at rock videos Watchin' these bimbos walkin' like hoes You can have them bimbos I'll keep my women like Flo Jo A word to the thick soul sistas, I wanna get with ya I won't cuss or hit ya But I gotta be straight when I say I wanna *fuck* Til the break of dawn Baby got it goin' on A lot of simps won't like this song 'Cause them punks like to hit it and quit it And I'd rather stay and play 'Cause I'm long, and I'm strong And I'm down to get the friction on So, ladies! {Yeah!} Ladies! {Yeah} If you wanna role in my Mercedes {Yeah!} Then turn around! Stick it out! Even white boys got to shout Baby got back!  Baby got back! Yeah, baby ... when it comes to females, Cosmo ain't got nothin'  to do with my selection. 36-24-36 Ha ha, only if she's 5'3 quot;.  So your girlfriend rolls a Honda, playin' workout tapes by Fonda But Fonda ain't got a motor in the back of her Honda My anaconda don't want none  Unless you've got buns, hon You can do side bends or sit-ups,  But please don't lose that butt Some brothers wanna play that  quot;hard quot; role  And tell you that the butt ain't go So they toss it and leave it And I pull up quick to retrieve it So Cosmo says you're fat Well I ain't down with that! 'Cause your waste is small and your curves are kickin' And I'm thinkin' bout stickin' To the beanpole dames in the magazines: You ain't it, Miss Thing! Give me a sista, I can't resist her Red beans and rice didn't miss her Some knucklehead tried to dis 'Cause his girls are on my list He had game but he chose to hit 'em And I pull up quick to get wit 'em So ladies, if the butt is round, And you want a triple X throw down, Dial 1-900-MIXALOT And kick them nasty thoughts Baby got back!

# %% [markdown]
# ### Test with top 10

# %%
df_1992_top_10 = df_1992[df_1992['Place'] <= 10].reset_index(drop=True)
df_1992_top_10
# Out:
#    Year  Place                                  Title                 Artist  \
# 0  1992      1                        End of the Road            Boyz II Men
# 1  1992      2                          Baby Got Back          Sir Mix-a-Lot
# 2  1992      3                                   Jump             Kris Kross
# 3  1992      4                 Save the Best for Last       Vanessa Williams
# 4  1992      5                         Baby-Baby-Baby                    TLC
# 5  1992      6                        Tears in Heaven           Eric Clapton
# 6  1992      7  My Lovin' (You're Never Gonna Get It)               En Vogue
# 7  1992      8                       Under the Bridge  Red Hot Chili Peppers
# 8  1992      9                             All 4 Love          Color Me Badd
# 9  1992     10                       Just Another Day             Jon Secada
#
#   Featuring                                        Title_url  Released  \
# 0       NaN         /wiki/End_of_the_Road_(Boyz_II_Men_song)    1992.0
# 1       NaN                              /wiki/Baby_Got_Back    1992.0
# 2       NaN                     /wiki/Jump_(Kris_Kross_song)    1992.0
# 3       NaN                     /wiki/Save_the_Best_for_Last    1992.0
# 4       NaN                             /wiki/Baby-Baby-Baby    1992.0
# 5       NaN                            /wiki/Tears_in_Heaven    1992.0
# 6       NaN  /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)    1992.0
# 7       NaN                           /wiki/Under_the_Bridge    1992.0
# 8       NaN                                 /wiki/All_4_Love    1991.0
# 9       NaN         /wiki/Just_Another_Day_(Jon_Secada_song)    1992.0
#
#             Genre 1         Genre 2     Genre 3 Length         Label  \
# 0               R&b             NaN         NaN   5:48        LaFace
# 1           Hip hop       Dirty rap  Miami bass   4:21  Def American
# 2           Hip hop             NaN         NaN   5:09     Ruffhouse
# 3               Pop            Soul         NaN   3:40          Wing
# 4               NaN             NaN         NaN   5:15        LaFace
# 5         Soft rock             NaN         NaN   4:36  Warner Bros.
# 6         Dance-pop  New jack swing         R&b   4:42      EastWest
# 7  Alternative rock             NaN         NaN   4:24  Warner Bros.
# 8    New jack swing             NaN         NaN   3:30         Giant
# 9         Dance-pop       Latin pop         R&b   5:27           SBK
#
#    Total Labels                    Writer 1                  Writer 2  \
# 0           3.0  Kenneth "Babyface" Edmonds       Antonio "L.A." Reid
# 1           2.0               Sir Mix-a-Lot                       NaN
# 2           2.0              Jermaine Dupri  Joe "The Butcher" Nicolo
# 3           2.0               Phil Galdston             Wendy Waldman
# 4           2.0             Kenneth Edmonds              Antonio Reid
# 5           1.0                Eric Clapton             Will Jennings
# 6           1.0               Denzil Foster            Thomas McElroy
# 7           1.0              Anthony Kiedis                      Flea
# 8           2.0                Bryan Abrams             Mark Calderon
# 9           1.0                  Jon Secada         Miguel A. Morejon
#
#                                        Youtube
# 0  https://www.youtube.com/watch?v=zDKO6XYXioc
# 1  https://www.youtube.com/watch?v=X53ZSxkQ3Ho
# 2  https://www.youtube.com/watch?v=010KyIQjkTk
# 3  https://www.youtube.com/watch?v=5EdmHSTwmWY
# 4                                          NaN
# 5  https://www.youtube.com/watch?v=JxPj3GAYYZ0
# 6  https://www.youtube.com/watch?v=JIuYQ_4TcXg
# 7  https://www.youtube.com/watch?v=lwlogyj7nFE
# 8                                          NaN
# 9                                          NaN

# %%
titles_and_artists = df_1992_top_10[['Title', 'Artist']]
titles_and_artists
# Out:
#                                    Title                 Artist
# 0                        End of the Road            Boyz II Men
# 1                          Baby Got Back          Sir Mix-a-Lot
# 2                                   Jump             Kris Kross
# 3                 Save the Best for Last       Vanessa Williams
# 4                         Baby-Baby-Baby                    TLC
# 5                        Tears in Heaven           Eric Clapton
# 6  My Lovin' (You're Never Gonna Get It)               En Vogue
# 7                       Under the Bridge  Red Hot Chili Peppers
# 8                             All 4 Love          Color Me Badd
# 9                       Just Another Day             Jon Secada

# %%
new_dict = dict()

for index, row in titles_and_artists.iterrows():
    name = f'{row["Title"]} {row["Artist"]}'.replace(" ", "_")
    #print(name)
    new_dict[name] = get_lyrics_via_search(row["Title"], row["Artist"])
# Out:
# End+of+the+Road+Boyz+II+Men
# song-9347-end-of-the-road.html
# Baby+Got+Back+Sir+Mix-a-Lot
# song-38519-baby-got-back.html
# Jump+Kris+Kross
# No Result!
# Save+the+Best+for+Last+Vanessa+Williams
# Single search result.
# Baby-Baby-Baby+TLC
# Single search result.
# Tears+in+Heaven+Eric+Clapton
# song-34823-tears-in-heaven.html
# My+Lovin'+(You're+Never+Gonna+Get+It)+En+Vogue
# Splitting the title!
# My+Lovin'++En+Vogue
# song-89506-my-lovin-you-re-never-gonna-get-it.html
# Under+the+Bridge+Red+Hot+Chili+Peppers
# Single search result.
# All+4+Love+Color+Me+Badd
# Single search result.
# Just+Another+Day+Jon+Secada
# Single search result.

# %%
#new_dict

# %% [markdown]
# ## Practicing Dataframes and Apply method

# %%
import pandas as pd

df1 = pd.DataFrame(
    [
        (1, 'Hello', 158, True, 12.8),
        (2, 'Hey', 567, False, 74.2),
        (3, 'Hi', 123, False, 1.1),
        (4, 'Howdy', 578, True, 45.8),
        (5, 'Hello', 418, True, 21.1),
        (6, 'Hi', 98, False, 98.1),
    ],
    columns=['colA', 'colB', 'colC', 'colD', 'colE']
)
print(df1)
# Out:
#    colA   colB  colC   colD  colE
# 0     1  Hello   158   True  12.8
# 1     2    Hey   567  False  74.2
# 2     3     Hi   123  False   1.1
# 3     4  Howdy   578   True  45.8
# 4     5  Hello   418   True  21.1
# 5     6     Hi    98  False  98.1

# %%
def categorise(row):  
    if row['colC'] > 0 and row['colC'] <= 99:
        return 'A'
    elif row['colC'] > 100 and row['colC'] <= 199:
        return 'B'
    elif row['colC'] > 200  and row['colC'] <= 299:
        return 'C'
    return 'D'

# %%
df1['colF'] = df1.apply(lambda row: categorise(row), axis=1)

# %%
df1
# Out:
#    colA   colB  colC   colD  colE colF
# 0     1  Hello   158   True  12.8    B
# 1     2    Hey   567  False  74.2    D
# 2     3     Hi   123  False   1.1    B
# 3     4  Howdy   578   True  45.8    D
# 4     5  Hello   418   True  21.1    D
# 5     6     Hi    98  False  98.1    A

# %% [markdown]
# ## Use Apply Method

# %%
titles_and_artists
# Out:
#                                    Title                 Artist
# 0                        End of the Road            Boyz II Men
# 1                          Baby Got Back          Sir Mix-a-Lot
# 2                                   Jump             Kris Kross
# 3                 Save the Best for Last       Vanessa Williams
# 4                         Baby-Baby-Baby                    TLC
# 5                        Tears in Heaven           Eric Clapton
# 6  My Lovin' (You're Never Gonna Get It)               En Vogue
# 7                       Under the Bridge  Red Hot Chili Peppers
# 8                             All 4 Love          Color Me Badd
# 9                       Just Another Day             Jon Secada

# %%
def categorise(row):  
    title = row['Title']
    artist = row['Artist']
    
    return get_lyrics_via_search(title, artist)

# %%
titles_and_artists['Lyrics'] = titles_and_artists.apply(lambda row: categorise(row), axis=1)
# Out:
# End+of+the+Road+Boyz+II+Men
# song-9347-end-of-the-road.html
# Baby+Got+Back+Sir+Mix-a-Lot
# song-38519-baby-got-back.html
# Jump+Kris+Kross
# No Result!
# Save+the+Best+for+Last+Vanessa+Williams
# Single search result.
# Baby-Baby-Baby+TLC
# Single search result.
# Tears+in+Heaven+Eric+Clapton
# song-34823-tears-in-heaven.html
# My+Lovin'+(You're+Never+Gonna+Get+It)+En+Vogue
# Splitting the title!
# My+Lovin'++En+Vogue
# song-89506-my-lovin-you-re-never-gonna-get-it.html
# Under+the+Bridge+Red+Hot+Chili+Peppers
# Single search result.
# All+4+Love+Color+Me+Badd
# Single search result.
# Just+Another+Day+Jon+Secada
# Single search result.
# /tmp/ipykernel_5862/629196545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titles_and_artists['Lyrics'] = titles_and_artists.apply(lambda row: categorise(row), axis=1)

# %%
titles_and_artists
# Out:
#                                    Title                 Artist  \
# 0                        End of the Road            Boyz II Men
# 1                          Baby Got Back          Sir Mix-a-Lot
# 2                                   Jump             Kris Kross
# 3                 Save the Best for Last       Vanessa Williams
# 4                         Baby-Baby-Baby                    TLC
# 5                        Tears in Heaven           Eric Clapton
# 6  My Lovin' (You're Never Gonna Get It)               En Vogue
# 7                       Under the Bridge  Red Hot Chili Peppers
# 8                             All 4 Love          Color Me Badd
# 9                       Just Another Day             Jon Secada
#
#                                               Lyrics
# 0  [spoken]\nGirl you know we belong together \nI...
# 1  [Intro]\nOh, my, god. Becky, look at her butt....
# 2
# 3  Sometimes the snow comes down in June\n      S...
# 4  And you want my love\nWell that's alright\nWel...
# 5  Would you know my name\nIf I saw you in heaven...
# 6  I remember how it used to be You never were th...
# 7  Sometimes I feel\nLike I don't have a partner\...
# 8  I'm so glad you're my girl\nI'll do anything f...
# 9  Morning alone\nWhen you come home\nI breath a ...

# %%
titles_and_artists.to_csv ('data/Lyrics/first_test.csv', index = False, header=True)

# %%
import pandas as pd

titles_and_artists = pd.read_csv('data/Lyrics/first_test.csv')

titles_and_artists
# Out:
#                                    Title                 Artist  \
# 0                        End of the Road            Boyz II Men
# 1                          Baby Got Back          Sir Mix-a-Lot
# 2                                   Jump             Kris Kross
# 3                 Save the Best for Last       Vanessa Williams
# 4                         Baby-Baby-Baby                    TLC
# 5                        Tears in Heaven           Eric Clapton
# 6  My Lovin' (You're Never Gonna Get It)               En Vogue
# 7                       Under the Bridge  Red Hot Chili Peppers
# 8                             All 4 Love          Color Me Badd
# 9                       Just Another Day             Jon Secada
#
#                                               Lyrics
# 0  [spoken]\nGirl you know we belong together \nI...
# 1  [Intro]\nOh, my, god. Becky, look at her butt....
# 2                                                NaN
# 3  Sometimes the snow comes down in June\n      S...
# 4  And you want my love\nWell that's alright\nWel...
# 5  Would you know my name\nIf I saw you in heaven...
# 6  I remember how it used to be You never were th...
# 7  Sometimes I feel\nLike I don't have a partner\...
# 8  I'm so glad you're my girl\nI'll do anything f...
# 9  Morning alone\nWhen you come home\nI breath a ...

# %% [markdown]
# ## Test with the whole year 1992

# %%
titles_and_artists_1992 = df_1992[['Title', 'Artist']]

# %%
titles_and_artists_1992
# Out:
#                        Title            Artist
# 0            End of the Road       Boyz II Men
# 1              Baby Got Back     Sir Mix-a-Lot
# 2                       Jump        Kris Kross
# 3     Save the Best for Last  Vanessa Williams
# 4             Baby-Baby-Baby               TLC
# ..                       ...               ...
# 95       I Will Remember You         Amy Grant
# 96       We Got a Love Thang     CeCe Peniston
# 97          Let's Get Rocked       Def Leppard
# 98             They Want EFX           Das EFX
# 99  I Can't Make You Love Me      Bonnie Raitt
#
# [100 rows x 2 columns]

# %%
titles_and_artists_1992['Lyrics'] = titles_and_artists_1992.apply(lambda row: categorise(row), axis=1)
# Out:
# No Result!
# Splitting the title!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# Splitting the title!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# No Result!
# /tmp/ipykernel_218/1480868743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titles_and_artists_1992['Lyrics'] = titles_and_artists_1992.apply(lambda row: categorise(row), axis=1)

# %%
titles_and_artists_1992
# Out:
#                        Title            Artist  \
# 0            End of the Road       Boyz II Men
# 1              Baby Got Back     Sir Mix-a-Lot
# 2                       Jump        Kris Kross
# 3     Save the Best for Last  Vanessa Williams
# 4             Baby-Baby-Baby               TLC
# ..                       ...               ...
# 95       I Will Remember You         Amy Grant
# 96       We Got a Love Thang     CeCe Peniston
# 97          Let's Get Rocked       Def Leppard
# 98             They Want EFX           Das EFX
# 99  I Can't Make You Love Me      Bonnie Raitt
#
#                                                Lyrics
# 0   Girl you know we belong together  I have no ti...
# 1   Oh, my, god. Becky, look at her butt.  It is s...
# 2
# 3   Sometimes the snow comes down in June       So...
# 4   And you want my love Well that's alright Well ...
# ..                                                ...
# 95  I will be walking one day Down a street far aw...
# 96
# 97  Do ya wanna get rocked   Let's get, let's get,...
# 98  Bum stiggedy bum stiggedy bum, hon, I got the ...
# 99  Turn down the lights, turn down the bed  Turn ...
#
# [100 rows x 3 columns]

# %%
titles_and_artists_1992.to_csv ('data/Lyrics/1992.csv', index = False, header=True)

# %%
songs_without_lyrics = titles_and_artists_1992[titles_and_artists_1992['Lyrics'] == ""]
songs_without_lyrics
# Out:
#                                     Title                          Artist  \
# 2                                    Jump                      Kris Kross
# 10                      I Love Your Smile                         Shanice
# 15                          I'll Be There                    Mariah Carey
# 17                      Life Is a Highway                    Tom Cochrane
# 19                                Finally                   CeCe Peniston
# 24                    Diamonds and Pearls                          Prince
# 26                            Masterpiece                  Atlantic Starr
# 29                         Live and Learn                      Joe Public
# 30                    Come and Talk to Me                          Jodeci
# 34         Tell Me What You Want Me to Do                  Tevin Campbell
# 37                              Move This                    Technotronic
# 40       The Best Things in Life Are Free                 Luther Vandross
# 45                         2 Legit 2 Quit                          Hammer
# 46                        Please Don't Go                             KWS
# 47  Breakin' My Heart (Pretty Brown Eyes)                  Mint Condition
# 48                      Wishing on a Star                 The Cover Girls
# 49              She's Playing Hard to Get                         Hi-Five
# 50                    I'd Die Without You                       P.M. Dawn
# 58            How Do You Talk to an Angel                     The Heights
# 60                        Keep on Walkin'                   CeCe Peniston
# 62               The Way I Feel About You                     Karyn White
# 64                             Warm It Up                      Kris Kross
# 68                               Wildside  Marky Mark and the Funky Bunch
# 75                          Addams Groove                          Hammer
# 77                      Back to the Hotel                          N2Deep
# 78                     Everything Changes                  Kathy Troccoli
# 82                       I Wanna Love You                            Jade
# 85                  Justified and Ancient                         The KLF
# 93                         Keep It Comin'                     Keith Sweat
# 96                    We Got a Love Thang                   CeCe Peniston
#
#    Lyrics
# 2
# 10
# 15
# 17
# 19
# 24
# 26
# 29
# 30
# 34
# 37
# 40
# 45
# 46
# 47
# 48
# 49
# 50
# 58
# 60
# 62
# 64
# 68
# 75
# 77
# 78
# 82
# 85
# 93
# 96

# %% [markdown]
# ## Filewriter and saving without /n

# %%
text = "[Intro]\nOh, my, god. Becky, look at her butt. \nIt is so big. *scoff* She looks like, \none of those rap guys' girlfriends. \nBut, y'know, who understands those rap guys *scoff* \nThey only talk to her, because, \nshe looks like a total prostitute, 'kay \nI mean, her butt, is just so big. *scoff* \nI can't believe it's just so round, it's like, \nout there, I mean - gross. Look! \nShe's just so ... black!\n\n[Sir Mix-a-Lot]\nI like big butts and I can not lie\nYou other brothers can't deny\nThat when a girl walks in with an itty bitty waste\nAnd a round thing in your face\nYou get sprung, wanna pull up tough\n'Cause you notice that butt was stuffed\nDeep in the jeans she's wearing\nI'm hooked and I can't stop staring\nOh baby, I wanna get wit'cha \nAnd take your picture\nMy homeboys tried to warn me\nBut with that butt you got makes \nOoh, Rump-o'-smooth-skin\nYou say you wanna get in my Benz\nWell, use me, use me \n'Cause you ain't that average groupy\nI've seen them dancin' \nThe hell with romancin'\nShe's wet, wet, \nGot it goin' like a turbo 'Vette\nI'm tired of magazines\nSayin' flat butts are the thing\nTake the average black man and ask him that\nShe gotta pack much back\nSo, fellas! (Yeah!) Fellas! (Yeah!)\nHas your girlfriend got the butt (Hell yeah!)\nTell 'em to shake it! (Shake it!) Shake it! (Shake it!)\nShake that healthy butt!\nBaby got back!\n\n(LA face with Oakland booty)\nBaby got back!\n\n[Sir Mix-a-Lot]\nI like 'em round, and big\nAnd when I'm throwin' a gig\nI just can't help myself, I'm actin' like an animal\nNow here's my scandal\nI wanna get you home\nAnd ugh, double-up, ugh, ugh\nI ain't talkin' bout Playboy\n'Cause silicone parts are made for toys\nI want 'em real thick and juicy\nSo find that juicy double\nMix-a-Lot's in trouble\nBeggin' for a piece of that bubble\nSo I'm lookin' at rock videos\nWatchin' these bimbos walkin' like hoes\nYou can have them bimbos\nI'll keep my women like Flo Jo\nA word to the thick soul sistas, I wanna get with ya\nI won't cuss or hit ya\nBut I gotta be straight when I say I wanna *fuck*\nTil the break of dawn\nBaby got it goin' on\nA lot of simps won't like this song\n'Cause them punks like to hit it and quit it\nAnd I'd rather stay and play\n'Cause I'm long, and I'm strong\nAnd I'm down to get the friction on\nSo, ladies! {Yeah!} Ladies! {Yeah}\nIf you wanna role in my Mercedes {Yeah!}\nThen turn around! Stick it out!\nEven white boys got to shout\nBaby got back!\n\nBaby got back!\nYeah, baby ... when it comes to females, Cosmo ain't got nothin' \nto do with my selection. 36-24-36 Ha ha, only if she's 5'3 quot;.\n\n[Sir Mix-a-Lot]\nSo your girlfriend rolls a Honda, playin' workout tapes by Fonda\nBut Fonda ain't got a motor in the back of her Honda\nMy anaconda don't want none \nUnless you've got buns, hon\nYou can do side bends or sit-ups, \nBut please don't lose that butt\nSome brothers wanna play that quot;hard quot; role \nAnd tell you that the butt ain't go\nSo they toss it and leave it\nAnd I pull up quick to retrieve it\nSo Cosmo says you're fat\nWell I ain't down with that!\n'Cause your waste is small and your curves are kickin'\nAnd I'm thinkin' bout stickin'\nTo the beanpole dames in the magazines:\nYou ain't it, Miss Thing!\nGive me a sista, I can't resist her\nRed beans and rice didn't miss her\nSome knucklehead tried to dis\n'Cause his girls are on my list\nHe had game but he chose to hit 'em\nAnd I pull up quick to get wit 'em\nSo ladies, if the butt is round,\nAnd you want a triple X throw down,\nDial 1-900-MIXALOT\nAnd kick them nasty thoughts\nBaby got back!\n\n(Little in the middle but she got much back) [4x]"

# %%
text = get_lyrics_via_search("Halo","Beyonce")
text
# Out:
# "Remember those walls I built? Well, baby they're tumbling down And they didn't even put up a fight They didn't even make a sound I found a way to let you in But, I never really had a doubt Standing in the light of your halo I got my angel now  It's like I've been awakened Every rule I had you breakin' It's the risk that I'm taking I ain't never gonna shut you out!  Everywhere I'm looking now I'm surrounded by your embrace Baby, I can see your halo You know you're my saving grace You're everything I need and more It's written all over your face Baby, I can feel your halo Pray it won't fade away  I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh ooh.....  Hit me like a ray of sun Burning through my darkest night You're the only one that I want Think I'm addicted to your light I swore I'd never fall again But this don't even feel like falling Gravity can't forget To pull me back to the ground again  It's like I've been awakened Every rule I had you breakin' It's the risk that I'm taking I'm never gonna shut you out!  Everywhere I'm looking now I'm surrounded by your embrace Baby, I can see your halo You know you're my saving grace You're everything I need and more It's written all over your face Baby, I can feel your halo I pray it won't fade away  I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh ooh..... I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh ooh..... Halo, ooh ooh..... Halo, ooh ooh, oh........  Everywhere I'm looking now I'm surrounded by your embrace Baby, I can see your halo You know you're my saving grace You're everything I need and more It's written all over your face Baby, I can feel your halo I pray it won't fade away  I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh oh....... I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh oh......."

# %%
splitted = text.split('\n')
#splitted = [x for x in splitted if '[' not in x ]
splitted
# Out:
# ['Remember those walls I built?',
#  "Well, baby they're tumbling down",
#  "And they didn't even put up a fight",
#  "They didn't even make a sound",
#  'I found a way to let you in',
#  'But, I never really had a doubt',
#  'Standing in the light of your halo',
#  'I got my angel now',
#  '',
#  "It's like I've been awakened",
#  "Every rule I had you breakin'",
#  "It's the risk that I'm taking",
#  "I ain't never gonna shut you out!",
#  '',
#  "Everywhere I'm looking now",
#  "I'm surrounded by your embrace",
#  'Baby, I can see your halo',
#  "You know you're my saving grace",
#  "You're everything I need and more",
#  "It's written all over your face",
#  'Baby, I can feel your halo',
#  "Pray it won't fade away",
#  '',
#  'I can feel your halo',
#  'I can see your halo',
#  'I can feel your halo',
#  'I can see your halo',
#  'Halo, ooh ooh.....',
#  '',
#  'Hit me like a ray of sun',
#  'Burning through my darkest night',
#  "You're the only one that I want",
#  "Think I'm addicted to your light",
#  "I swore I'd never fall again",
#  "But this don't even feel like falling",
#  "Gravity can't forget",
#  'To pull me back to the ground again',
#  '',
#  "It's like I've been awakened",
#  "Every rule I had you breakin'",
#  "It's the risk that I'm taking",
#  "I'm never gonna shut you out!",
#  '',
#  "Everywhere I'm looking now",
#  "I'm surrounded by your embrace",
#  'Baby, I can see your halo',
#  "You know you're my saving grace",
#  "You're everything I need and more",
#  "It's written all over your face",
#  'Baby, I can feel your halo',
#  "I pray it won't fade away",
#  '',
#  'I can feel your halo',
#  'I can see your halo',
#  'I can feel your halo',
#  'I can see your halo',
#  'Halo, ooh ooh.....',
#  'I can feel your halo',
#  'I can see your halo',
#  'I can feel your halo',
#  'I can see your halo',
#  'Halo, ooh ooh.....',
#  'Halo, ooh ooh.....',
#  'Halo, ooh ooh, oh........',
#  '',
#  "Everywhere I'm looking now",
#  "I'm surrounded by your embrace",
#  'Baby, I can see your halo',
#  "You know you're my saving grace",
#  "You're everything I need and more",
#  "It's written all over your face",
#  'Baby, I can feel your halo',
#  "I pray it won't fade away",
#  '',
#  'I can feel your halo',
#  'I can see your halo',
#  'I can feel your halo',
#  'I can see your halo',
#  'Halo, ooh oh.......',
#  'I can feel your halo',
#  'I can see your halo',
#  'I can feel your halo',
#  'I can see your halo',
#  'Halo, ooh oh.......']

# %%
' '.join(splitted)
# Out:
# "Remember those walls I built? Well, baby they're tumbling down And they didn't even put up a fight They didn't even make a sound I found a way to let you in But, I never really had a doubt Standing in the light of your halo I got my angel now  It's like I've been awakened Every rule I had you breakin' It's the risk that I'm taking I ain't never gonna shut you out!  Everywhere I'm looking now I'm surrounded by your embrace Baby, I can see your halo You know you're my saving grace You're everything I need and more It's written all over your face Baby, I can feel your halo Pray it won't fade away  I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh ooh.....  Hit me like a ray of sun Burning through my darkest night You're the only one that I want Think I'm addicted to your light I swore I'd never fall again But this don't even feel like falling Gravity can't forget To pull me back to the ground again  It's like I've been awakened Every rule I had you breakin' It's the risk that I'm taking I'm never gonna shut you out!  Everywhere I'm looking now I'm surrounded by your embrace Baby, I can see your halo You know you're my saving grace You're everything I need and more It's written all over your face Baby, I can feel your halo I pray it won't fade away  I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh ooh..... I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh ooh..... Halo, ooh ooh..... Halo, ooh ooh, oh........  Everywhere I'm looking now I'm surrounded by your embrace Baby, I can see your halo You know you're my saving grace You're everything I need and more It's written all over your face Baby, I can feel your halo I pray it won't fade away  I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh oh....... I can feel your halo I can see your halo I can feel your halo I can see your halo Halo, ooh oh......."

# %%
# Out:
# [Errno 17] File exists: 'data/lyrics/1992'
