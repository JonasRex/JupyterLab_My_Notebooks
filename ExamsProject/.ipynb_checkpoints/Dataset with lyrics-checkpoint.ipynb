# %%
import pandas as pd
df = pd.read_csv('data/Lyrics/tcc_ceds_music.csv')

df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
df = df[["artist_name", "track_name","release_date","lyrics"]]

# %%
df_lyrics = df[df['release_date'] == 2009].reset_index(drop=True)
df_lyrics = df_lyrics[:100]

# %%
df_lyrics
# Out:
#            artist_name                               track_name  release_date  \
# 0          wiz khalifa                               this plane          2009
# 1          demi lovato                                 catch me          2009
# 2             kid cudi  enter galactic (love connection part i)          2009
# 3             fabolous                                  my time          2009
# 4            glee cast     somebody to love (glee cast version)          2009
# ..                 ...                                      ...           ...
# 95         young money                            steady mobbin          2009
# 96   a day to remember                 if it means a lot to you          2009
# 97           green day                                  21 guns          2009
# 98  the avett brothers                          january wedding          2009
# 99   twenty one pilots                  a car, a torch, a death          2009
#
# ...

# %%
#titles = df_old["Title"].tolist()

#titles = [x.lower() for x in sorted(titles)]
#titles

# %%
titles2 = df_lyrics["track_name"].tolist()
titles2 = [x.lower() for x in sorted(titles2)]
len(titles2)
# Out:
# 597

# %%
from Modules import LyricsWebscraper as lyrics

def get_year(year):
    df_lyrics = df[df['release_date'] == year].reset_index(drop=True)
    get_lyrics(df_lyrics[:100])

def get_lyrics(df):
    for index, row in df.iterrows():
        year = row['release_date']
        artist = row['artist_name']
        title = row['track_name']
        lyric = row['lyrics']
        #print(title, artist, year)
        #print(lyric[:50])
        #if(track in titles):
        #    print(track)
        lyrics.save_lyrics(title, artist, year, lyric)

# %%
get_year(2021)
