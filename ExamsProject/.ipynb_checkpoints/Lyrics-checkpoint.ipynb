# %% [markdown]
# # Fetch all the lyrics

# %%
from Modules import AdditionalSongData as additional_data
from Modules import LyricsWebscraper as lyrics_scraper

# %%
df = additional_data.load_from_csv("data_1989_2008")
df.head()
# Out:
#    Year  Place                     Title         Artist Featuring  \
# 0  1989      1                 Look Away        Chicago       NaN
# 1  1989      2            My Prerogative    Bobby Brown       NaN
# 2  1989      3  Every Rose Has Its Thorn         Poison       NaN
# 3  1989      4               Straight Up    Paula Abdul       NaN
# 4  1989      5             Miss You Much  Janet Jackson       NaN
#
#                               Title_url  Released         Genre 1  \
# 0                       /wiki/Look_Away    1988.0            Rock
# 1                  /wiki/My_Prerogative    1988.0  New jack swing
# 2        /wiki/Every_Rose_Has_Its_Thorn    1988.0      Glam metal
# 3  /wiki/Straight_Up_(Paula_Abdul_song)    1988.0       Dance-pop
# 4                   /wiki/Miss_You_Much    1989.0       Dance-pop
#
#           Genre 2        Genre 3 Length      Label  Total Labels  \
# 0             NaN            NaN   4:02  Full Moon           2.0
# ...

# %% [markdown]
# # Scraping 1989 - 1991 (Already had the other lyrics)

# %%
import os

try:
    for year in range(1989,1992):
        os.mkdir('data/lyrics/'+str(year))
except Exception as e:
    print(e)

# %%
#for year in range(1989,1992):
#    lyrics_scraper.fetch_lyrics_year(df, year)
# Out:
# Songs without or too short lyrics in 1989: 38
# Songs without or too short lyrics in 1990: 43
# Songs without or too short lyrics in 1991: 32

# %% [markdown]
# # Apply lyrics into the dataframe (And remove features that isn't needed)

# %%
df_lyrics = lyrics_scraper.apply_lyrics_to_df(df)
df_lyrics
# Out:
#       Year  Place                     Title         Artist         Genre 1  \
# 0     1989      1                 Look Away        Chicago            Rock
# 1     1989      2            My Prerogative    Bobby Brown  New jack swing
# 2     1989      3  Every Rose Has Its Thorn         Poison      Glam metal
# 3     1989      4               Straight Up    Paula Abdul       Dance-pop
# 4     1989      5             Miss You Much  Janet Jackson       Dance-pop
# ...    ...    ...                       ...            ...             ...
# 1995  2008     96             The Way I Are      Timbaland     Electro-pop
# 1996  2008     97                  Addicted    Saving Abel       Hard rock
# 1997  2008     98            Into the Night        Santana    Chicano rock
# 1998  2008     99               Heaven Sent   Keyshia Cole             R&b
# 1999  2008    100                She Got It      2 Pistols             NaN
#
#                                                  Lyrics
# ...

# %% [markdown]
# # Remove empty Lyrics

# %%
df_lyrics = df_lyrics[df_lyrics["Lyrics"] != ""].reset_index(drop=True)
df_lyrics
# Out:
#       Year  Place                     Title         Artist           Genre 1  \
# 0     1989      1                 Look Away        Chicago              Rock
# 1     1989      2            My Prerogative    Bobby Brown    New jack swing
# 2     1989      3  Every Rose Has Its Thorn         Poison        Glam metal
# 3     1989      4               Straight Up    Paula Abdul         Dance-pop
# 4     1989      5             Miss You Much  Janet Jackson         Dance-pop
# ...    ...    ...                       ...            ...               ...
# 1555  2008     91              Mrs. Officer      Lil Wayne         Dirty rap
# 1556  2008     92                  7 Things    Miley Cyrus          Pop-punk
# 1557  2008     95        Feels Like Tonight       Daughtry  Alternative rock
# 1558  2008     96             The Way I Are      Timbaland       Electro-pop
# 1559  2008     99               Heaven Sent   Keyshia Cole               R&b
#
# ...

# %% [markdown]
# # Save

# %%
lyrics_scraper.save_as_csv(df_lyrics, "df_lyrics_89_08")
# Out:
# 'df_lyrics_89_08.csv Saved!'

# %%
df_lyrics = lyrics_scraper.load_from_csv("df_lyrics_89_08")
df_lyrics
# Out:
#       Year  Place                     Title         Artist           Genre 1  \
# 0     1989      1                 Look Away        Chicago              Rock
# 1     1989      2            My Prerogative    Bobby Brown    New jack swing
# 2     1989      3  Every Rose Has Its Thorn         Poison        Glam metal
# 3     1989      4               Straight Up    Paula Abdul         Dance-pop
# 4     1989      5             Miss You Much  Janet Jackson         Dance-pop
# ...    ...    ...                       ...            ...               ...
# 1555  2008     91              Mrs. Officer      Lil Wayne         Dirty rap
# 1556  2008     92                  7 Things    Miley Cyrus          Pop-punk
# 1557  2008     95        Feels Like Tonight       Daughtry  Alternative rock
# 1558  2008     96             The Way I Are      Timbaland       Electro-pop
# 1559  2008     99               Heaven Sent   Keyshia Cole               R&b
#
# ...
